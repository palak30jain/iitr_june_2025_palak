# %%
## Word Count Using Dictionary

### Explanation:

When you have a huge block of text, sometimes you want to know how many times each word appears. 
For example, in a book or an article, some words occur many times (like *the*, *and*), 
while others occur only once.

We can solve this problem by using a **dictionary** in Python:

* The *keys* of the dictionary will be the words.
* The *values* will be how many times each word appears in the text.

For example, in the text `"hello world hello"`,
the dictionary would look like:
`{"hello": 2, "world": 1}`

This is called a **word count**.

### Exercise:

Write a function `word_count(text)` that:

* Takes a string `text` as input.
* Splits the text into words (you can use `split()`).
* Counts how many times each word appears using a dictionary.
* Returns the dictionary of word counts.

💡 **Hint**: You can test your function using the large file provided:

```python
txt = open('/cxldata/big.txt').read()
```

### Example:

```python
word_count("hello world hello")
# Output: {'hello': 2, 'world': 1}

word_count("apple orange apple banana orange")
# Output: {'apple': 2, 'orange': 2, 'banana': 1}
```
---

# %%
def word_count(text):
    dictionary = {}
    
    word_list = text.split(" ")
    for w in word_list:
        if w in dictionary:
            dictionary[w] = dictionary[w] + 1
        else:
            dictionary[w] = 1
            
    return dictionary

# %%
word_count("hello world hello")
# Out:
# {'hello': 2, 'world': 1}

# %%
word_count("apple orange apple banana orange")
# Out:
# {'apple': 2, 'orange': 2, 'banana': 1}

# %%
txt = open('/cxldata/big.txt').read()
word_count(txt)
# Out:
# {'The': 3793,
#  'Project': 157,
#  'Gutenberg': 64,
#  'EBook': 5,
#  'of': 34754,
#  'Adventures': 2,
#  'Sherlock': 69,
#  'Holmes\nby': 1,
#  'Sir': 30,
#  'Arthur': 16,
#  'Conan': 3,
#  'Doyle\n(#15': 1,
#  'in': 17459,
#  'our': 848,
#  'series': 79,
#  'by': 5597,
#  'Doyle)\n\nCopyright': 1,
#  'laws': 141,
#  'are': 2948,
#  'changing': 32,
#  'all': 2951,
#  'over': 1021,
#  'the': 61197,
#  'world.': 36,
#  'Be': 18,
#  'sure': 92,
#  'to': 24888,
#  'check': 28,
#  'the\ncopyright': 2,
#  'for': 5634,
#  'your': 1021,
#  'country': 191,
#  'before': 872,
#  'downloading': 3,
#  'or': 4478,
#  'redistributing\nthis': 2,
#  'any': 984,
#  'other': 1088,
#  'eBook.\n\nThis': 2,
#  'header': 5,
#  'should': 1077,
#  'be': 5192,
#  'first': 889,
#  'thing': 186,
#  'seen': 329,
#  'when': 1675,
#  'viewing': 4,
#  'this': 2547,
#  'Project\nGutenberg': 8,
#  'file.': 4,
#  '': 34449,
#  'Please': 12,
#  'do': 1012,
#  'not': 5464,
#  'remove': 41,
#  'it.': 462,
#  'Do': 73,
#  'change': 102,
#  'edit': 3,
#  'the\nheader': 2,
#  'without': 741,
#  'written': 88,
#  'permission.\n\nPlease': 2,
#  'read': 157,
#  '"legal': 2,
#  'small': 371,
#  'print,"': 2,
#  'and': 30996,
#  'information': 38,
#  'about': 1162,
#  'the\neBook': 2,
#  'at': 5636,
#  'bottom': 20,
#  'Included': 2,
#  'is\nimportant': 4,
#  'specific': 24,
#  'rights': 88,
#  'restrictions': 17,
#  'in\nhow': 2,
#  'file': 12,
#  'may': 2176,
#  'used.': 9,
#  'You': 369,
#  'can': 726,
#  'also': 578,
#  'find': 253,
#  'out': 1526,
#  'how': 786,
#  'make': 429,
#  'a\ndonation': 2,
#  'Gutenberg,': 2,
#  'get': 401,
#  'involved.\n\n\n**Welcome': 2,
#  'To': 266,
#  'World': 47,
#  'Free': 13,
#  'Plain': 3,
#  'Vanilla': 6,
#  'Electronic': 2,
#  'Texts**\n\n**eBooks': 2,
#  'Readable': 2,
#  'By': 139,
#  'Both': 34,
#  'Humans': 2,
#  'Computers,': 2,
#  'Since': 19,
#  '1971**\n\n*****These': 2,
#  'eBooks': 28,
#  'Were': 8,
#  'Prepared': 4,
#  'Thousands': 10,
#  'Volunteers!*****\n\n\nTitle:': 2,
#  'Holmes\n\nAuthor:': 1,
#  'Doyle\n\nRelease': 1,
#  'Date:': 4,
#  'March,': 20,
#  '1999': 3,
#  '[EBook': 4,
#  '#1661]\n[Most': 1,
#  'recently': 22,
#  'updated:': 2,
#  'November': 12,
#  '29,': 5,
#  '2002]\n\nEdition:': 1,
#  '12\n\nLanguage:': 1,
#  'English\n\nCharacter': 4,
#  'set': 261,
#  'encoding:': 4,
#  'ASCII\n\n***': 1,
#  'START': 4,
#  'OF': 200,
#  'THE': 178,
#  'PROJECT': 23,
#  'GUTENBERG': 11,
#  'EBOOK,': 4,
#  'ADVENTURES': 3,
#  'SHERLOCK': 4,
#  'HOLMES': 2,
#  '***\n\n\n\n\n(Additional': 1,
#  'editing': 4,
#  'Jose': 1,
#  'Menendez)\n\n\n\nTHE': 1,
#  'OF\nSHERLOCK': 1,
#  'HOLMES\n\nBY\n\nSIR': 1,
#  'ARTHUR': 1,
#  'CONAN': 1,
#  'DOYLE\n\nCONTENTS\n\nI.\tA': 1,
#  'Scandal': 2,
#  'Bohemia\nII.\tThe': 1,
#  'Red-Headed': 1,
#  'League\nIII.\tA': 1,
#  'Case': 1,
#  'Identity\nIV.\tThe': 1,
#  'Boscombe': 14,
#  'Valley': 27,
#  'Mystery\nV.\tThe': 1,
#  'Five': 13,
#  'Orange': 1,
#  'Pips\nVI.\tThe': 1,
#  'Man': 3,
#  'with': 8122,
#  'Twisted': 1,
#  'Lip\nVII.\tThe': 1,
#  'Adventure': 6,
#  'Blue': 2,
#  'Carbuncle\nVIII.\tThe': 1,
#  'Speckled': 1,
#  'Band\nIX.\tThe': 1,
#  "Engineer's": 1,
#  'Thumb\nX.\tThe': 1,
#  'Noble': 1,
#  'Bachelor\nXI.\tThe': 1,
#  'Beryl': 2,
#  'Coronet\nXII.\tThe': 1,
#  'Copper': 8,
#  'Beeches\n\n\nADVENTURE': 1,
#  'I.': 28,
#  'A': 537,
#  'SCANDAL': 1,
#  'IN': 48,
#  'BOHEMIA\n\nI.\n\n\nTo': 1,
#  'Holmes': 173,
#  'she': 2521,
#  'is': 8260,
#  'always': 481,
#  'woman.': 22,
#  'I': 5463,
#  'have': 3030,
#  'seldom': 62,
#  'heard': 483,
#  'him': 2737,
#  'mention': 27,
#  'her': 3751,
#  'under': 744,
#  'name.': 8,
#  'In': 1234,
#  'his': 8220,
#  'eyes': 499,
#  'eclipses': 2,
#  'predominates': 1,
#  'whole': 585,
#  'sex.': 2,
#  'It': 1301,
#  'was': 9753,
#  'that': 9842,
#  'he': 8366,
#  'felt': 566,
#  'emotion': 12,
#  'akin': 12,
#  'love': 312,
#  'Irene': 13,
#  'Adler.': 2,
#  'All': 222,
#  'emotions,': 2,
#  'one': 2379,
#  'particularly,': 3,
#  'were': 3547,
#  'abhorrent': 1,
#  'cold,': 45,
#  'precise': 8,
#  'but': 3654,
#  'admirably': 6,
#  'balanced': 3,
#  'mind.': 31,
#  'He': 1632,
#  'was,': 91,
#  'take': 507,
#  'it,': 441,
#  'most': 715,
#  'perfect': 26,
#  'reasoning': 18,
#  'observing': 14,
#  'machine': 25,
#  'world': 116,
#  'has': 1376,
#  'seen,': 13,
#  'as': 6592,
#  'a': 17581,
#  'lover': 11,
#  'would': 1651,
#  'placed': 153,
#  'himself': 673,
#  'false': 37,
#  'position.': 29,
#  'never': 459,
#  'spoke': 162,
#  'softer': 6,
#  'passions,': 5,
#  'save': 93,
#  'gibe': 1,
#  'sneer.': 2,
#  'They': 579,
#  'admirable': 8,
#  'things': 194,
#  'observer--excellent': 1,
#  'drawing': 187,
#  'veil': 10,
#  'from': 4664,
#  "men's": 23,
#  'motives': 10,
#  'actions.': 5,
#  'But': 705,
#  'trained': 16,
#  'reasoner': 3,
#  'admit': 50,
#  'such': 1146,
#  'intrusions': 1,
#  'into': 1833,
#  'own': 596,
#  'delicate': 35,
#  'finely': 8,
#  'adjusted': 14,
#  'temperament': 2,
#  'introduce': 18,
#  'distracting': 1,
#  'factor': 31,
#  'which': 3898,
#  'might': 444,
#  'throw': 39,
#  'doubt': 105,
#  'upon': 999,
#  'mental': 28,
#  'results.': 17,
#  'Grit': 1,
#  'sensitive': 18,
#  'instrument,': 2,
#  'crack': 10,
#  'high-power': 1,
#  'lenses,': 1,
#  'more': 1500,
#  'disturbing': 8,
#  'than': 1031,
#  'strong': 116,
#  'nature': 113,
#  'his.': 5,
#  'And': 669,
#  'yet': 339,
#  'there': 1621,
#  'woman': 139,
#  'him,': 677,
#  'late': 85,
#  'Adler,': 5,
#  'dubious': 1,
#  'questionable': 2,
#  'memory.\n\nI': 1,
#  'had': 6325,
#  'little': 804,
#  'lately.': 5,
#  'My': 92,
#  'marriage': 49,
#  'drifted': 5,
#  'us': 426,
#  'away': 472,
#  'each': 306,
#  'other.': 38,
#  'complete': 81,
#  'happiness,': 15,
#  'home-centred': 1,
#  'interests': 57,
#  'rise': 172,
#  'up': 1736,
#  'around': 175,
#  'man': 965,
#  'who': 2371,
#  'finds': 19,
#  'master': 44,
#  'establishment,': 1,
#  'sufficient': 54,
#  'absorb': 2,
#  'my': 1868,
#  'attention,': 12,
#  'while': 497,
#  'Holmes,': 123,
#  'loathed': 1,
#  'every': 474,
#  'form': 382,
#  'society': 68,
#  'Bohemian': 6,
#  'soul,': 13,
#  'remained': 171,
#  'lodgings': 8,
#  'Baker': 34,
#  'Street,': 23,
#  'buried': 17,
#  'among': 330,
#  'old': 888,
#  'books,': 12,
#  'alternating': 2,
#  'week': 54,
#  'between': 512,
#  'cocaine': 4,
#  'ambition,': 2,
#  'drowsiness': 2,
#  'drug,': 5,
#  'fierce': 10,
#  'energy': 23,
#  'keen': 22,
#  'nature.': 10,
#  'still,': 17,
#  'ever,': 13,
#  'deeply': 50,
#  'attracted': 26,
#  'study': 75,
#  'crime,': 7,
#  'occupied': 88,
#  'immense': 59,
#  'faculties': 7,
#  'extraordinary': 49,
#  'powers': 97,
#  'observation': 22,
#  'following': 149,
#  'those': 921,
#  'clues,': 1,
#  'clearing': 20,
#  'mysteries': 4,
#  'been': 2187,
#  'abandoned': 42,
#  'hopeless': 11,
#  'official': 64,
#  'police.': 8,
#  'From': 147,
#  'time': 942,
#  'some': 1200,
#  'vague': 32,
#  'account': 114,
#  'doings:': 1,
#  'summons': 7,
#  'Odessa': 1,
#  'case': 275,
#  'Trepoff': 1,
#  'murder,': 4,
#  'singular': 34,
#  'tragedy': 4,
#  'Atkinson': 1,
#  'brothers': 7,
#  'Trincomalee,': 1,
#  'finally': 87,
#  'mission': 18,
#  'accomplished': 19,
#  'so': 2082,
#  'delicately': 3,
#  'successfully': 12,
#  'reigning': 3,
#  'family': 100,
#  'Holland.': 1,
#  'Beyond': 13,
#  'these': 791,
#  'signs': 77,
#  'activity,': 16,
#  'however,': 286,
#  'merely': 158,
#  'shared': 18,
#  'readers': 4,
#  'daily': 30,
#  'press,': 13,
#  'knew': 410,
#  'former': 129,
#  'friend': 115,
#  'companion.\n\nOne': 1,
#  'night--it': 2,
#  'on': 5082,
#  'twentieth': 14,
#  '1888--I': 1,
#  'returning': 57,
#  'journey': 31,
#  'patient': 244,
#  '(for': 10,
#  'now': 939,
#  'returned': 150,
#  'civil': 64,
#  'practice),': 1,
#  'way': 547,
#  'led': 181,
#  'me': 1015,
#  'through': 660,
#  'Street.': 12,
#  'As': 356,
#  'passed': 288,
#  'well-remembered': 1,
#  'door,': 76,
#  'must': 842,
#  'associated': 147,
#  'mind': 187,
#  'wooing,': 1,
#  'dark': 113,
#  'incidents': 8,
#  'Study': 4,
#  'Scarlet,': 3,
#  'seized': 95,
#  'desire': 73,
#  'see': 741,
#  'again,': 92,
#  'know': 686,
#  'employing': 4,
#  'powers.': 8,
#  'His': 304,
#  'rooms': 43,
#  'brilliantly': 3,
#  'lit,': 3,
#  'and,': 491,
#  'even': 697,
#  'looked': 658,
#  'up,': 159,
#  'saw': 528,
#  'tall,': 24,
#  'spare': 20,
#  'figure': 68,
#  'pass': 101,
#  'twice': 53,
#  'silhouette': 1,
#  'against': 525,
#  'blind.': 3,
#  'pacing': 22,
#  'room': 393,
#  'swiftly,': 4,
#  'eagerly,': 4,
#  'head': 415,
#  'sunk': 21,
#  'chest': 44,
#  'hands': 234,
#  'clasped': 11,
#  'behind': 279,
#  'him.': 508,
#  'me,': 241,
#  'mood': 35,
#  'habit,': 11,
#  'attitude': 41,
#  'manner': 75,
#  'told': 414,
#  'their': 2328,
#  'story.': 12,
#  'work': 221,
#  'again.': 51,
#  'risen': 23,
#  'drug-created': 1,
#  'dreams': 11,
#  'hot': 63,
#  'scent': 10,
#  'new': 586,
#  'problem.': 5,
#  'rang': 24,
#  'bell': 25,
#  'shown': 94,
#  'chamber': 19,
#  'formerly': 42,
#  'part': 518,
#  'own.\n\nHis': 1,
#  'effusive.': 1,
#  'was;': 2,
#  'glad,': 9,
#  'think,': 56,
#  'me.': 142,
#  'With': 137,
#  'hardly': 144,
#  'word': 193,
#  'spoken,': 4,
#  'kindly': 47,
#  'eye,': 11,
#  'waved': 28,
#  'an': 2803,
#  'armchair,': 14,
#  'threw': 87,
#  'across': 180,
#  'cigars,': 3,
#  'indicated': 49,
#  'spirit': 100,
#  'gasogene': 1,
#  'corner.': 9,
#  'Then': 217,
#  'stood': 314,
#  'fire': 131,
#  'introspective': 2,
#  'fashion.\n\n"Wedlock': 1,
#  'suits': 8,
#  'you,"': 90,
#  'remarked.': 14,
#  '"I': 412,
#  'Watson,': 40,
#  'you': 3316,
#  'put': 380,
#  'seven': 87,
#  'half': 203,
#  'pounds': 14,
#  'since': 187,
#  'you."\n\n"Seven!"': 1,
#  'answered.\n\n"Indeed,': 1,
#  'thought': 616,
#  'more.': 42,
#  'Just': 54,
#  'trifle': 7,
#  'more,': 44,
#  'fancy,': 6,
#  'Watson.': 10,
#  'practice': 60,
#  'observe.': 3,
#  'did': 1604,
#  'tell': 396,
#  'intended': 45,
#  'go': 581,
#  'harness."\n\n"Then,': 1,
#  'know?"\n\n"I': 2,
#  'deduce': 13,
#  'How': 183,
#  'getting': 72,
#  'yourself': 83,
#  'very': 1112,
#  'wet': 39,
#  'lately,': 5,
#  'clumsy': 4,
#  'careless': 9,
#  'servant': 30,
#  'girl?"\n\n"My': 1,
#  'dear': 259,
#  'Holmes,"': 11,
#  'said': 2682,
#  'I,': 68,
#  '"this': 10,
#  'too': 315,
#  'much.': 17,
#  'certainly': 79,
#  'burned,': 10,
#  'lived': 89,
#  'few': 381,
#  'centuries': 11,
#  'ago.': 19,
#  'true': 107,
#  'walk': 47,
#  'Thursday': 2,
#  'came': 856,
#  'home': 159,
#  'dreadful': 44,
#  'mess,': 1,
#  'changed': 95,
#  'clothes': 31,
#  "can't": 159,
#  'imagine': 60,
#  'Mary': 372,
#  'Jane,': 1,
#  'incorrigible,': 1,
#  'wife': 161,
#  'given': 282,
#  'notice,': 7,
#  'there,': 110,
#  'fail': 24,
#  'it': 5882,
#  'out."\n\nHe': 3,
#  'chuckled': 6,
#  'rubbed': 28,
#  'long,': 41,
#  'nervous': 36,
#  'together.\n\n"It': 1,
#  'simplicity': 11,
#  'itself,"': 2,
#  'he;': 11,
#  '"my': 14,
#  'inside': 28,
#  'left': 621,
#  'shoe,': 2,
#  'just': 557,
#  'where': 695,
#  'firelight': 2,
#  'strikes': 10,
#  'leather': 18,
#  'scored': 3,
#  'six': 117,
#  'almost': 240,
#  'parallel': 12,
#  'cuts.': 1,
#  'Obviously': 3,
#  'they': 2547,
#  'caused': 86,
#  'someone': 98,
#  'carelessly': 6,
#  'scraped': 11,
#  'round': 390,
#  'edges': 47,
#  'sole': 49,
#  'order': 249,
#  'crusted': 2,
#  'mud': 13,
#  'Hence,': 2,
#  'see,': 65,
#  'double': 34,
#  'deduction': 8,
#  'vile': 8,
#  'weather,': 6,
#  'particularly': 118,
#  'malignant': 44,
#  'boot-slitting': 1,
#  'specimen': 7,
#  'London': 33,
#  'slavey.': 1,
#  'practice,': 7,
#  'if': 1461,
#  'gentleman': 49,
#  'walks': 7,
#  'smelling': 2,
#  'iodoform,': 2,
#  'black': 144,
#  'mark': 22,
#  'nitrate': 7,
#  'silver': 75,
#  'right': 396,
#  'forefinger,': 3,
#  'bulge': 2,
#  'side': 323,
#  'top-hat': 3,
#  'show': 165,
#  'secreted': 2,
#  'stethoscope,': 1,
#  'dull,': 14,
#  'indeed,': 21,
#  'pronounce': 7,
#  'active': 57,
#  'member': 38,
#  'medical': 17,
#  'profession."\n\nI': 1,
#  'could': 1470,
#  'help': 171,
#  'laughing': 50,
#  'ease': 18,
#  'explained': 46,
#  'process': 160,
#  'deduction.': 1,
#  '"When': 12,
#  'hear': 148,
#  'give': 402,
#  'reasons,"': 1,
#  'remarked,': 23,
#  '"the': 142,
#  'appears': 84,
#  'ridiculously': 1,
#  'simple': 82,
#  'easily': 76,
#  'myself,': 23,
#  'though': 390,
#  'successive': 11,
#  'instance': 13,
#  'am': 652,
#  'baffled': 5,
#  'until': 265,
#  'explain': 73,
#  'process.': 9,
#  'believe': 139,
#  'good': 402,
#  'yours."\n\n"Quite': 1,
#  'so,"': 19,
#  'answered,': 15,
#  'lighting': 12,
#  'cigarette,': 1,
#  'throwing': 36,
#  'down': 834,
#  'armchair.': 3,
#  '"You': 110,
#  'distinction': 13,
#  'clear.': 8,
#  'For': 173,
#  'example,': 163,
#  'frequently': 153,
#  'steps': 125,
#  'lead': 102,
#  'hall': 38,
#  'room."\n\n"Frequently."\n\n"How': 1,
#  'often?"\n\n"Well,': 1,
#  'hundreds': 35,
#  'times."\n\n"Then': 1,
#  'many': 453,
#  'there?"\n\n"How': 1,
#  'many?': 1,
#  "don't": 374,
#  'know."\n\n"Quite': 1,
#  'so!': 6,
#  'observed.': 8,
#  'seen.': 25,
#  'That': 189,
#  'point.': 18,
#  'Now,': 33,
#  'seventeen': 7,
#  'steps,': 17,
#  'because': 469,
#  'both': 382,
#  'way,': 102,
#  'interested': 42,
#  'problems,': 7,
#  'enough': 110,
#  'chronicle': 4,
#  'two': 802,
#  'trifling': 8,
#  'experiences,': 1,
#  'this."': 4,
#  'sheet': 23,
#  'thick,': 9,
#  'pink-tinted': 1,
#  'notepaper': 1,
#  'lying': 91,
#  'open': 203,
#  'table.': 40,
#  '"It': 93,
#  'last': 424,
#  'post,"': 1,
#  'he.': 105,
#  '"Read': 1,
#  'aloud."\n\nThe': 1,
#  'note': 62,
#  'undated,': 1,
#  'either': 218,
#  'signature': 7,
#  'address.\n\n"There': 1,
#  'will': 1258,
#  'call': 153,
#  'to-night,': 5,
#  'quarter': 32,
#  'eight': 70,
#  'o\'clock,"': 2,
#  'said,': 258,
#  '"a': 44,
#  'desires': 11,
#  'consult': 15,
#  'matter': 205,
#  'deepest': 14,
#  'moment.': 33,
#  'Your': 74,
#  'recent': 40,
#  'services': 19,
#  'royal': 68,
#  'houses': 46,
#  'Europe': 64,
#  'safely': 9,
#  'trusted': 12,
#  'matters': 68,
#  'importance': 59,
#  'exaggerated.': 2,
#  'This': 448,
#  'we': 1201,
#  'quarters': 35,
#  'received.': 5,
#  'then': 738,
#  'hour,': 18,
#  'amiss': 4,
#  'visitor': 33,
#  'wear': 23,
#  'mask."\n\n"This': 1,
#  'indeed': 36,
#  'mystery,"': 2,
#  '"What': 88,
#  'means?"\n\n"I': 1,
#  'no': 1557,
#  'data': 4,
#  'yet.': 10,
#  'capital': 83,
#  'mistake': 22,
#  'theorise': 1,
#  'data.': 4,
#  'Insensibly': 1,
#  'begins': 33,
#  'twist': 10,
#  'facts': 46,
#  'suit': 21,
#  'theories,': 2,
#  'instead': 97,
#  'theories': 10,
#  'facts.': 5,
#  'itself.': 22,
#  'What': 412,
#  'it?"\n\nI': 1,
#  'carefully': 50,
#  'examined': 37,
#  'writing,': 7,
#  'paper': 108,
#  'written.\n\n"The': 1,
#  'wrote': 116,
#  'presumably': 6,
#  'well': 381,
#  'do,"': 12,
#  'endeavouring': 8,
#  'imitate': 4,
#  "companion's": 6,
#  'processes.': 3,
#  '"Such': 5,
#  'bought': 43,
#  'crown': 23,
#  'packet.': 2,
#  'peculiarly': 9,
#  'stiff."\n\n"Peculiar--that': 1,
#  'word,"': 3,
#  'Holmes.': 53,
#  'English': 137,
#  'all.': 72,
#  'Hold': 1,
#  'light."\n\nI': 1,
#  'so,': 76,
#  'large': 369,
#  '"E"': 1,
#  '"g,"': 1,
#  '"P,"': 1,
#  '"G"': 1,
#  '"t"': 1,
#  'woven': 4,
#  'texture': 4,
#  'paper.\n\n"What': 1,
#  'that?"': 25,
#  'asked': 548,
#  'Holmes.\n\n"The': 1,
#  'name': 163,
#  'maker,': 1,
#  'doubt;': 1,
#  'monogram,': 1,
#  'rather."\n\n"Not': 1,
#  "'G'": 1,
#  "'t'": 1,
#  'stands': 17,
#  "'Gesellschaft,'": 1,
#  'German': 108,
#  "'Company.'": 1,
#  'customary': 16,
#  'contraction': 33,
#  'like': 824,
#  "'Co.'": 1,
#  "'P,'": 1,
#  'course,': 56,
#  "'Papier.'": 1,
#  'Now': 96,
#  "'Eg.'": 1,
#  'Let': 61,
#  'glance': 64,
#  'Continental': 20,
#  'Gazetteer."': 1,
#  'took': 499,
#  'heavy': 98,
#  'brown': 35,
#  'volume': 18,
#  'shelves.': 1,
#  '"Eglow,': 1,
#  'Eglonitz--here': 1,
#  'are,': 49,
#  'Egria.': 1,
#  'German-speaking': 1,
#  'country--in': 1,
#  'Bohemia,': 5,
#  'far': 290,
#  'Carlsbad.': 1,
#  "'Remarkable": 1,
#  'being': 737,
#  'scene': 33,
#  'death': 146,
#  'Wallenstein,': 1,
#  'its': 1323,
#  'numerous': 35,
#  'glass-factories': 1,
#  "paper-mills.'": 1,
#  'Ha,': 8,
#  'ha,': 10,
#  'boy,': 31,
#  'what': 1786,
#  'sparkled,': 1,
#  'sent': 256,
#  'great': 505,
#  'blue': 83,
#  'triumphant': 10,
#  'cloud': 20,
#  'cigarette.\n\n"The': 1,
#  'made': 833,
#  'Bohemia,"': 1,
#  'said.\n\n"Precisely.': 1,
#  'German.': 5,
#  'peculiar': 67,
#  'construction': 15,
#  "sentence--'This": 1,
#  "received.'": 1,
#  'Frenchman': 53,
#  'Russian': 329,
#  'that.': 48,
#  'uncourteous': 1,
#  'verbs.': 1,
#  'only': 1445,
#  'remains,': 5,
#  'therefore,': 39,
#  'discover': 24,
#  'wanted': 159,
#  'writes': 12,
#  'prefers': 1,
#  'wearing': 68,
#  'mask': 7,
#  'showing': 77,
#  'face.': 68,
#  'here': 265,
#  'comes,': 3,
#  'mistaken,': 6,
#  'resolve': 11,
#  'doubts."\n\nAs': 2,
#  'sharp': 58,
#  'sound': 157,
#  "horses'": 11,
#  'hoofs': 14,
#  'grating': 7,
#  'wheels': 29,
#  'curb,': 1,
#  'followed': 254,
#  'pull': 13,
#  'bell.': 5,
#  'whistled.\n\n"A': 1,
#  'pair,': 1,
#  'sound,"': 1,
#  '"Yes,"': 3,
#  'continued,': 41,
#  'glancing': 81,
#  'window.': 17,
#  '"A': 24,
#  'nice': 29,
#  'brougham': 3,
#  'pair': 35,
#  'beauties.': 1,
#  'hundred': 174,
#  'fifty': 45,
#  'guineas': 2,
#  'apiece.': 4,
#  "There's": 17,
#  'money': 180,
#  'case,': 47,
#  'nothing': 384,
#  'else."\n\n"I': 3,
#  'think': 408,
#  'better': 186,
#  'go,': 51,
#  'Holmes."\n\n"Not': 2,
#  'bit,': 15,
#  'Doctor.': 1,
#  'Stay': 1,
#  'are.': 16,
#  'lost': 133,
#  'Boswell.': 1,
#  'promises': 13,
#  'interesting.': 7,
#  'pity': 47,
#  'miss': 13,
#  'it."\n\n"But': 5,
#  'client--"\n\n"Never': 1,
#  'want': 249,
#  'help,': 11,
#  'Here': 48,
#  ...}

# %%
# if we wat everything in lower cases


def word_count_lower(text):
    dictionary = {}
    
    word_list = text.split(" ")
    for word in word_list:
        w = word.lower()
        
        if w in dictionary:
            dictionary[w] = dictionary[w] + 1
        else:
            dictionary[w] = 1
            
    return dictionary

# %%
txt = open('/cxldata/big.txt').read()
word_count_lower(txt)
# Out:
# {'the': 65168,
#  'project': 201,
#  'gutenberg': 76,
#  'ebook': 53,
#  'of': 35009,
#  'adventures': 12,
#  'sherlock': 73,
#  'holmes\nby': 1,
#  'sir': 31,
#  'arthur': 18,
#  'conan': 4,
#  'doyle\n(#15': 1,
#  'in': 18741,
#  'our': 895,
#  'series': 79,
#  'by': 5745,
#  'doyle)\n\ncopyright': 1,
#  'laws': 144,
#  'are': 2976,
#  'changing': 33,
#  'all': 3173,
#  'over': 1025,
#  'world.': 42,
#  'be': 5212,
#  'sure': 92,
#  'to': 25176,
#  'check': 28,
#  'the\ncopyright': 2,
#  'for': 5824,
#  'your': 1095,
#  'country': 195,
#  'before': 915,
#  'downloading': 3,
#  'or': 4516,
#  'redistributing\nthis': 2,
#  'any': 1020,
#  'other': 1111,
#  'ebook.\n\nthis': 2,
#  'header': 5,
#  'should': 1089,
#  'first': 914,
#  'thing': 186,
#  'seen': 329,
#  'when': 2148,
#  'viewing': 5,
#  'this': 3007,
#  'project\ngutenberg': 8,
#  'file.': 4,
#  '': 34449,
#  'please': 63,
#  'do': 1085,
#  'not': 5543,
#  'remove': 41,
#  'it.': 462,
#  'change': 104,
#  'edit': 3,
#  'the\nheader': 2,
#  'without': 764,
#  'written': 89,
#  'permission.\n\nplease': 2,
#  'read': 166,
#  '"legal': 2,
#  'small': 385,
#  'print,"': 2,
#  'and': 31776,
#  'information': 46,
#  'about': 1182,
#  'the\nebook': 2,
#  'at': 5913,
#  'bottom': 20,
#  'included': 29,
#  'is\nimportant': 4,
#  'specific': 24,
#  'rights': 96,
#  'restrictions': 17,
#  'in\nhow': 2,
#  'file': 12,
#  'may': 2211,
#  'used.': 9,
#  'you': 3711,
#  'can': 753,
#  'also': 581,
#  'find': 254,
#  'out': 1537,
#  'how': 969,
#  'make': 432,
#  'a\ndonation': 2,
#  'gutenberg,': 2,
#  'get': 411,
#  'involved.\n\n\n**welcome': 2,
#  'world': 173,
#  'free': 290,
#  'plain': 65,
#  'vanilla': 6,
#  'electronic': 41,
#  'texts**\n\n**ebooks': 2,
#  'readable': 9,
#  'both': 416,
#  'humans': 2,
#  'computers,': 2,
#  'since': 206,
#  '1971**\n\n*****these': 2,
#  'ebooks': 28,
#  'were': 3555,
#  'prepared': 105,
#  'thousands': 68,
#  'volunteers!*****\n\n\ntitle:': 2,
#  'holmes\n\nauthor:': 1,
#  'doyle\n\nrelease': 1,
#  'date:': 4,
#  'march,': 35,
#  '1999': 3,
#  '[ebook': 4,
#  '#1661]\n[most': 1,
#  'recently': 23,
#  'updated:': 2,
#  'november': 13,
#  '29,': 5,
#  '2002]\n\nedition:': 1,
#  '12\n\nlanguage:': 1,
#  'english\n\ncharacter': 4,
#  'set': 264,
#  'encoding:': 4,
#  'ascii\n\n***': 1,
#  'start': 42,
#  'ebook,': 12,
#  'holmes': 176,
#  '***\n\n\n\n\n(additional': 1,
#  'editing': 4,
#  'jose': 1,
#  'menendez)\n\n\n\nthe': 1,
#  'of\nsherlock': 1,
#  'holmes\n\nby\n\nsir': 1,
#  'doyle\n\ncontents\n\ni.\ta': 1,
#  'scandal': 12,
#  'bohemia\nii.\tthe': 1,
#  'red-headed': 19,
#  'league\niii.\ta': 1,
#  'case': 277,
#  'identity\niv.\tthe': 1,
#  'boscombe': 15,
#  'valley': 40,
#  'mystery\nv.\tthe': 1,
#  'five': 182,
#  'orange': 14,
#  'pips\nvi.\tthe': 1,
#  'man': 969,
#  'with': 8268,
#  'twisted': 16,
#  'lip\nvii.\tthe': 1,
#  'adventure': 19,
#  'blue': 86,
#  'carbuncle\nviii.\tthe': 1,
#  'speckled': 5,
#  'band\nix.\tthe': 1,
#  "engineer's": 2,
#  'thumb\nx.\tthe': 1,
#  'noble': 33,
#  'bachelor\nxi.\tthe': 1,
#  'beryl': 3,
#  'coronet\nxii.\tthe': 1,
#  'copper': 16,
#  'beeches\n\n\nadventure': 1,
#  'i.': 28,
#  'a': 18118,
#  'bohemia\n\ni.\n\n\nto': 1,
#  'she': 3140,
#  'is': 8314,
#  'always': 483,
#  'woman.': 22,
#  'i': 5466,
#  'have': 3066,
#  'seldom': 64,
#  'heard': 483,
#  'him': 2746,
#  'mention': 28,
#  'her': 3818,
#  'under': 787,
#  'name.': 8,
#  'his': 8528,
#  'eyes': 499,
#  'eclipses': 2,
#  'predominates': 1,
#  'whole': 587,
#  'sex.': 2,
#  'it': 7185,
#  'was': 9780,
#  'that': 10035,
#  'he': 9998,
#  'felt': 566,
#  'emotion': 12,
#  'akin': 12,
#  'love': 316,
#  'irene': 14,
#  'adler.': 2,
#  'emotions,': 2,
#  'one': 2532,
#  'particularly,': 3,
#  'abhorrent': 1,
#  'cold,': 45,
#  'precise': 8,
#  'but': 4365,
#  'admirably': 6,
#  'balanced': 3,
#  'mind.': 31,
#  'was,': 91,
#  'take': 517,
#  'it,': 441,
#  'most': 735,
#  'perfect': 26,
#  'reasoning': 18,
#  'observing': 14,
#  'machine': 25,
#  'has': 1385,
#  'seen,': 13,
#  'as': 6950,
#  'lover': 11,
#  'would': 1661,
#  'placed': 153,
#  'himself': 673,
#  'false': 37,
#  'position.': 29,
#  'never': 470,
#  'spoke': 162,
#  'softer': 6,
#  'passions,': 5,
#  'save': 94,
#  'gibe': 1,
#  'sneer.': 2,
#  'they': 3126,
#  'admirable': 8,
#  'things': 195,
#  'observer--excellent': 1,
#  'drawing': 190,
#  'veil': 10,
#  'from': 4813,
#  "men's": 23,
#  'motives': 10,
#  'actions.': 5,
#  'trained': 16,
#  'reasoner': 3,
#  'admit': 50,
#  'such': 1204,
#  'intrusions': 1,
#  'into': 1839,
#  'own': 599,
#  'delicate': 36,
#  'finely': 8,
#  'adjusted': 14,
#  'temperament': 2,
#  'introduce': 18,
#  'distracting': 1,
#  'factor': 31,
#  'which': 3903,
#  'might': 449,
#  'throw': 40,
#  'doubt': 105,
#  'upon': 1002,
#  'mental': 28,
#  'results.': 17,
#  'grit': 1,
#  'sensitive': 18,
#  'instrument,': 2,
#  'crack': 10,
#  'high-power': 1,
#  'lenses,': 1,
#  'more': 1527,
#  'disturbing': 8,
#  'than': 1031,
#  'strong': 119,
#  'nature': 114,
#  'his.': 5,
#  'yet': 378,
#  'there': 2001,
#  'woman': 146,
#  'him,': 682,
#  'late': 86,
#  'adler,': 5,
#  'dubious': 1,
#  'questionable': 2,
#  'memory.\n\ni': 1,
#  'had': 6358,
#  'little': 818,
#  'lately.': 5,
#  'my': 1960,
#  'marriage': 50,
#  'drifted': 5,
#  'us': 428,
#  'away': 474,
#  'each': 329,
#  'other.': 38,
#  'complete': 84,
#  'happiness,': 15,
#  'home-centred': 1,
#  'interests': 60,
#  'rise': 193,
#  'up': 1738,
#  'around': 181,
#  'who': 2414,
#  'finds': 19,
#  'master': 52,
#  'establishment,': 1,
#  'sufficient': 54,
#  'absorb': 2,
#  'attention,': 12,
#  'while': 565,
#  'holmes,': 123,
#  'loathed': 1,
#  'every': 524,
#  'form': 383,
#  'society': 70,
#  'bohemian': 7,
#  'soul,': 13,
#  'remained': 171,
#  'lodgings': 8,
#  'baker': 35,
#  'street,': 36,
#  'buried': 17,
#  'among': 356,
#  'old': 938,
#  'books,': 12,
#  'alternating': 2,
#  'week': 54,
#  'between': 538,
#  'cocaine': 4,
#  'ambition,': 2,
#  'drowsiness': 3,
#  'drug,': 5,
#  'fierce': 10,
#  'energy': 24,
#  'keen': 23,
#  'nature.': 10,
#  'still,': 28,
#  'ever,': 13,
#  'deeply': 51,
#  'attracted': 26,
#  'study': 79,
#  'crime,': 7,
#  'occupied': 88,
#  'immense': 60,
#  'faculties': 7,
#  'extraordinary': 50,
#  'powers': 103,
#  'observation': 22,
#  'following': 157,
#  'those': 960,
#  'clues,': 1,
#  'clearing': 21,
#  'mysteries': 5,
#  'been': 2188,
#  'abandoned': 42,
#  'hopeless': 11,
#  'official': 64,
#  'police.': 9,
#  'time': 946,
#  'some': 1287,
#  'vague': 32,
#  'account': 122,
#  'doings:': 1,
#  'summons': 8,
#  'odessa': 1,
#  'trepoff': 1,
#  'murder,': 4,
#  'singular': 34,
#  'tragedy': 4,
#  'atkinson': 1,
#  'brothers': 16,
#  'trincomalee,': 1,
#  'finally': 99,
#  'mission': 20,
#  'accomplished': 19,
#  'so': 2228,
#  'delicately': 3,
#  'successfully': 12,
#  'reigning': 3,
#  'family': 101,
#  'holland.': 1,
#  'beyond': 169,
#  'these': 921,
#  'signs': 78,
#  'activity,': 16,
#  'however,': 303,
#  'merely': 158,
#  'shared': 18,
#  'readers': 4,
#  'daily': 32,
#  'press,': 14,
#  'knew': 410,
#  'former': 129,
#  'friend': 115,
#  'companion.\n\none': 1,
#  'night--it': 2,
#  'on': 5419,
#  'twentieth': 14,
#  '1888--i': 1,
#  'returning': 60,
#  'journey': 31,
#  'patient': 244,
#  '(for': 10,
#  'now': 1035,
#  'returned': 151,
#  'civil': 146,
#  'practice),': 1,
#  'way': 547,
#  'led': 181,
#  'me': 1016,
#  'through': 678,
#  'street.': 28,
#  'passed': 290,
#  'well-remembered': 1,
#  'door,': 76,
#  'must': 846,
#  'associated': 150,
#  'mind': 189,
#  'wooing,': 1,
#  'dark': 114,
#  'incidents': 9,
#  'scarlet,': 3,
#  'seized': 95,
#  'desire': 74,
#  'see': 760,
#  'again,': 95,
#  'know': 686,
#  'employing': 4,
#  'powers.': 8,
#  'rooms': 43,
#  'brilliantly': 3,
#  'lit,': 3,
#  'and,': 501,
#  'even': 784,
#  'looked': 658,
#  'up,': 159,
#  'saw': 529,
#  'tall,': 24,
#  'spare': 20,
#  'figure': 68,
#  'pass': 101,
#  'twice': 65,
#  'silhouette': 1,
#  'against': 531,
#  'blind.': 3,
#  'pacing': 22,
#  'room': 393,
#  'swiftly,': 4,
#  'eagerly,': 4,
#  'head': 420,
#  'sunk': 21,
#  'chest': 44,
#  'hands': 239,
#  'clasped': 11,
#  'behind': 296,
#  'him.': 510,
#  'me,': 241,
#  'mood': 35,
#  'habit,': 11,
#  'attitude': 44,
#  'manner': 75,
#  'told': 424,
#  'their': 2379,
#  'story.': 12,
#  'work': 222,
#  'again.': 51,
#  'risen': 23,
#  'drug-created': 1,
#  'dreams': 11,
#  'hot': 63,
#  'scent': 10,
#  'new': 978,
#  'problem.': 5,
#  'rang': 24,
#  'bell': 28,
#  'shown': 94,
#  'chamber': 20,
#  'formerly': 47,
#  'part': 521,
#  'own.\n\nhis': 1,
#  'effusive.': 1,
#  'was;': 2,
#  'glad,': 9,
#  'think,': 56,
#  'me.': 142,
#  'hardly': 152,
#  'word': 194,
#  'spoken,': 4,
#  'kindly': 53,
#  'eye,': 12,
#  'waved': 28,
#  'an': 2888,
#  'armchair,': 14,
#  'threw': 87,
#  'across': 181,
#  'cigars,': 3,
#  'indicated': 49,
#  'spirit': 108,
#  'gasogene': 1,
#  'corner.': 9,
#  'then': 955,
#  'stood': 314,
#  'fire': 134,
#  'introspective': 2,
#  'fashion.\n\n"wedlock': 1,
#  'suits': 8,
#  'you,"': 90,
#  'remarked.': 14,
#  '"i': 412,
#  'watson,': 40,
#  'put': 381,
#  'seven': 91,
#  'half': 213,
#  'pounds': 14,
#  'you."\n\n"seven!"': 1,
#  'answered.\n\n"indeed,': 1,
#  'thought': 617,
#  'more.': 42,
#  'just': 611,
#  'trifle': 7,
#  'more,': 44,
#  'fancy,': 6,
#  'watson.': 10,
#  'practice': 60,
#  'observe.': 3,
#  'did': 1630,
#  'tell': 420,
#  'intended': 45,
#  'go': 617,
#  'harness."\n\n"then,': 1,
#  'know?"\n\n"i': 2,
#  'deduce': 13,
#  'getting': 74,
#  'yourself': 83,
#  'very': 1134,
#  'wet': 39,
#  'lately,': 5,
#  'clumsy': 4,
#  'careless': 9,
#  'servant': 30,
#  'girl?"\n\n"my': 1,
#  'dear': 267,
#  'holmes,"': 11,
#  'said': 2682,
#  'i,': 69,
#  '"this': 41,
#  'too': 320,
#  'much.': 17,
#  'certainly': 82,
#  'burned,': 10,
#  'lived': 89,
#  'few': 385,
#  'centuries': 11,
#  'ago.': 19,
#  'true': 108,
#  'walk': 47,
#  'thursday': 3,
#  'came': 857,
#  'home': 160,
#  'dreadful': 44,
#  'mess,': 1,
#  'changed': 95,
#  'clothes': 31,
#  "can't": 163,
#  'imagine': 60,
#  'mary': 373,
#  'jane,': 1,
#  'incorrigible,': 1,
#  'wife': 161,
#  'given': 282,
#  'notice,': 7,
#  'there,': 119,
#  'fail': 24,
#  'out."\n\nhe': 3,
#  'chuckled': 6,
#  'rubbed': 28,
#  'long,': 41,
#  'nervous': 37,
#  'together.\n\n"it': 1,
#  'simplicity': 12,
#  'itself,"': 2,
#  'he;': 11,
#  '"my': 39,
#  'inside': 29,
#  'left': 627,
#  'shoe,': 2,
#  'where': 742,
#  'firelight': 2,
#  'strikes': 11,
#  'leather': 18,
#  'scored': 3,
#  'six': 123,
#  'almost': 247,
#  'parallel': 12,
#  'cuts.': 1,
#  'obviously': 27,
#  'caused': 86,
#  'someone': 104,
#  'carelessly': 6,
#  'scraped': 11,
#  'round': 396,
#  'edges': 47,
#  'sole': 54,
#  'order': 263,
#  'crusted': 2,
#  'mud': 13,
#  'hence,': 3,
#  'see,': 68,
#  'double': 35,
#  'deduction': 8,
#  'vile': 8,
#  'weather,': 6,
#  'particularly': 120,
#  'malignant': 53,
#  'boot-slitting': 1,
#  'specimen': 7,
#  'london': 34,
#  'slavey.': 1,
#  'practice,': 7,
#  'if': 1854,
#  'gentleman': 50,
#  'walks': 7,
#  'smelling': 2,
#  'iodoform,': 2,
#  'black': 151,
#  'mark': 24,
#  'nitrate': 7,
#  'silver': 80,
#  'right': 402,
#  'forefinger,': 3,
#  'bulge': 2,
#  'side': 324,
#  'top-hat': 3,
#  'show': 181,
#  'secreted': 2,
#  'stethoscope,': 1,
#  'dull,': 14,
#  'indeed,': 34,
#  'pronounce': 7,
#  'active': 59,
#  'member': 38,
#  'medical': 20,
#  'profession."\n\ni': 1,
#  'could': 1480,
#  'help': 173,
#  'laughing': 50,
#  'ease': 18,
#  'explained': 46,
#  'process': 163,
#  'deduction.': 1,
#  '"when': 17,
#  'hear': 149,
#  'give': 445,
#  'reasons,"': 1,
#  'remarked,': 23,
#  '"the': 258,
#  'appears': 84,
#  'ridiculously': 1,
#  'simple': 83,
#  'easily': 76,
#  'myself,': 23,
#  'though': 466,
#  'successive': 11,
#  'instance': 13,
#  'am': 660,
#  'baffled': 5,
#  'until': 271,
#  'explain': 105,
#  'process.': 9,
#  'believe': 141,
#  'good': 408,
#  'yours."\n\n"quite': 1,
#  'so,"': 19,
#  'answered,': 15,
#  'lighting': 12,
#  'cigarette,': 1,
#  'throwing': 36,
#  'down': 837,
#  'armchair.': 3,
#  '"you': 137,
#  'distinction': 13,
#  'clear.': 8,
#  'example,': 163,
#  'frequently': 156,
#  'steps': 126,
#  'lead': 105,
#  'hall': 41,
#  'room."\n\n"frequently."\n\n"how': 1,
#  'often?"\n\n"well,': 1,
#  'hundreds': 39,
#  'times."\n\n"then': 1,
#  'many': 496,
#  'there?"\n\n"how': 1,
#  'many?': 1,
#  "don't": 429,
#  'know."\n\n"quite': 1,
#  'so!': 7,
#  'observed.': 8,
#  'seen.': 25,
#  'point.': 19,
#  'now,': 182,
#  'seventeen': 7,
#  'steps,': 17,
#  'because': 475,
#  'way,': 102,
#  'interested': 42,
#  'problems,': 7,
#  'enough': 110,
#  'chronicle': 5,
#  'two': 863,
#  'trifling': 8,
#  'experiences,': 1,
#  'this."': 4,
#  'sheet': 23,
#  'thick,': 9,
#  'pink-tinted': 1,
#  'notepaper': 1,
#  'lying': 93,
#  'open': 203,
#  'table.': 40,
#  '"it': 119,
#  'last': 430,
#  'post,"': 1,
#  'he.': 105,
#  '"read': 1,
#  'aloud."\n\nthe': 1,
#  'note': 66,
#  'undated,': 1,
#  'either': 224,
#  'signature': 7,
#  'address.\n\n"there': 1,
#  'will': 1272,
#  'call': 156,
#  'to-night,': 5,
#  'quarter': 32,
#  'eight': 74,
#  'o\'clock,"': 2,
#  'said,': 258,
#  '"a': 68,
#  'desires': 11,
#  'consult': 15,
#  'matter': 205,
#  'deepest': 14,
#  'moment.': 33,
#  'recent': 41,
#  'services': 20,
#  'royal': 85,
#  'houses': 50,
#  'europe': 65,
#  'safely': 9,
#  'trusted': 12,
#  'matters': 68,
#  'importance': 59,
#  'exaggerated.': 2,
#  'we': 1437,
#  'quarters': 35,
#  'received.': 5,
#  'hour,': 18,
#  'amiss': 4,
#  'visitor': 33,
#  'wear': 23,
#  'mask."\n\n"this': 1,
#  'indeed': 44,
#  'mystery,"': 2,
#  '"what': 97,
#  'means?"\n\n"i': 1,
#  'no': 1645,
#  'data': 4,
#  'yet.': 10,
#  'capital': 84,
#  'mistake': 22,
#  'theorise': 1,
#  'data.': 4,
#  'insensibly': 2,
#  'begins': 34,
#  'twist': 10,
#  'facts': 46,
#  'suit': 21,
#  'theories,': 2,
#  'instead': 108,
#  'theories': 12,
#  'facts.': 5,
#  'itself.': 22,
#  'what': 2198,
#  'it?"\n\ni': 1,
#  'carefully': 51,
#  'examined': 37,
#  'writing,': 7,
#  'paper': 110,
#  'written.\n\n"the': 1,
#  'wrote': 116,
#  'presumably': 6,
#  'well': 390,
#  'do,"': 12,
#  'endeavouring': 8,
#  'imitate': 4,
#  "companion's": 6,
#  'processes.': 3,
#  '"such': 6,
#  'bought': 43,
#  'crown': 33,
#  'packet.': 2,
#  'peculiarly': 9,
#  'stiff."\n\n"peculiar--that': 1,
#  'word,"': 3,
#  'holmes.': 53,
#  'english': 139,
#  'all.': 73,
#  'hold': 88,
#  'light."\n\ni': 1,
#  'so,': 82,
#  'large': 376,
#  '"e"': 1,
#  '"g,"': 1,
#  '"p,"': 1,
#  '"g"': 1,
#  '"t"': 1,
#  'woven': 4,
#  'texture': 4,
#  'paper.\n\n"what': 1,
#  'that?"': 25,
#  'asked': 548,
#  'holmes.\n\n"the': 1,
#  'name': 168,
#  'maker,': 1,
#  'doubt;': 1,
#  'monogram,': 1,
#  'rather."\n\n"not': 1,
#  "'g'": 1,
#  "'t'": 1,
#  'stands': 17,
#  "'gesellschaft,'": 1,
#  'german': 110,
#  "'company.'": 1,
#  'customary': 16,
#  'contraction': 35,
#  'like': 850,
#  "'co.'": 1,
#  "'p,'": 1,
#  'course,': 56,
#  "'papier.'": 1,
#  "'eg.'": 1,
#  'let': 396,
#  'glance': 64,
#  'continental': 33,
#  'gazetteer."': 1,
#  'took': 499,
#  'heavy': 102,
#  'brown': 39,
#  'volume': 20,
#  'shelves.': 1,
#  '"eglow,': 1,
#  'eglonitz--here': 1,
#  'are,': 49,
#  'egria.': 1,
#  'german-speaking': 1,
#  'country--in': 1,
#  'bohemia,': 5,
#  'far': 328,
#  'carlsbad.': 1,
#  "'remarkable": 1,
#  'being': 741,
#  'scene': 33,
#  'death': 152,
#  'wallenstein,': 1,
#  'its': 1371,
#  'numerous': 35,
#  'glass-factories': 1,
#  "paper-mills.'": 1,
#  'ha,': 18,
#  'boy,': 31,
#  'sparkled,': 1,
#  'sent': 257,
#  'great': 611,
#  'triumphant': 10,
#  'cloud': 20,
#  'cigarette.\n\n"the': 1,
#  'made': 835,
#  'bohemia,"': 1,
#  'said.\n\n"precisely.': 1,
#  'german.': 5,
#  'peculiar': 67,
#  'construction': 16,
#  "sentence--'this": 1,
#  "received.'": 1,
#  'frenchman': 54,
#  'russian': 330,
#  'that.': 48,
#  'uncourteous': 1,
#  'verbs.': 1,
#  'only': 1541,
#  'remains,': 5,
#  'therefore,': 40,
#  'discover': 24,
#  'wanted': 159,
#  'writes': 12,
#  'prefers': 1,
#  'wearing': 68,
#  'mask': 7,
#  'showing': 78,
#  'face.': 68,
#  'here': 313,
#  'comes,': 3,
#  'mistaken,': 6,
#  'resolve': 11,
#  'doubts."\n\nas': 2,
#  'sharp': 58,
#  'sound': 160,
#  "horses'": 11,
#  'hoofs': 14,
#  'grating': 7,
#  'wheels': 30,
#  'curb,': 1,
#  'followed': 255,
#  'pull': 15,
#  'bell.': 6,
#  'whistled.\n\n"a': 1,
#  'pair,': 1,
#  'sound,"': 1,
#  '"yes,"': 3,
#  'continued,': 41,
#  'glancing': 83,
#  'window.': 17,
#  'nice': 29,
#  'brougham': 3,
#  'pair': 35,
#  'beauties.': 1,
#  'hundred': 174,
#  'fifty': 46,
#  'guineas': 2,
#  'apiece.': 4,
#  "there's": 67,
#  'money': 186,
#  'case,': 47,
#  'nothing': 405,
#  'else."\n\n"i': 3,
#  'think': 414,
#  'better': 189,
#  'go,': 54,
#  'holmes."\n\n"not': 2,
#  'bit,': 15,
#  'doctor.': 6,
#  'stay': 56,
#  'are.': 16,
#  'lost': 134,
#  'boswell.': 1,
#  'promises': 13,
#  'interesting.': 7,
#  'pity': 48,
#  'miss': 93,
#  'it."\n\n"but': 5,
#  'client--"\n\n"never': 1,
#  'want': 249,
#  'help,': 11,
#  'comes.': 1,
#  'sit': 68,
#  'doctor,': 35,
#  'best': 204,
#  'attention."\n\na': 1,
#  'slow': 43,
#  'step,': 17,
#  'stairs': 13,
#  'passage,': 16,
#  'paused': 33,
#  'immediately': 109,
#  'outside': 70,
#  'door.': 53,
#  'loud': 43,
#  'authoritative': 2,
#  'tap.\n\n"come': 1,
#  'in!"': 4,
#  'holmes.\n\na': 2,
#  'entered': 197,
#  'less': 304,
#  'feet': 100,
#  'inches': 12,
#  'height,': 7,
#  'limbs': 35,
#  'hercules.': 1,
#  'dress': 66,
#  'rich': 62,
#  'richness': 1,
#  'would,': 15,
#  'england,': 60,
#  'bad': 93,
#  'taste.': 2,
#  'bands': 16,
#  'astrakhan': 1,
#  'slashed': 3,
#  'sleeves': 20,
#  'fronts': 1,
#  'double-breasted': 1,
#  'coat,': 36,
#  'deep': 150,
#  'cloak': 23,
#  'thrown': 78,
#  'shoulders': 48,
#  'lined': 20,
#  'flame-coloured': 2,
#  'silk': 25,
#  'secured': 35,
#  'neck': 88,
#  'brooch': 1,
#  'consisted': 34,
#  ...}

# %%
## Find Anagrams in a Text

### Explanation:

An **anagram** is a word formed by rearranging the letters of another word.
For example:

* `"listen"` and `"silent"` are anagrams.
* `"evil"` and `"vile"` are also anagrams.

To find anagrams in a large text, one useful trick is to use a **dictionary (hash map)**:

* We can sort the letters of each word to form a *key*.

  * Example: `"listen"` → `"eilnst"`, `"silent"` → `"eilnst"`.
* All words that share the same sorted key are anagrams of each other.
* We group words together in the dictionary using these keys.

This method is very efficient, even for huge texts.

---

### Exercise:

Write a function `find_anagrams(text)` that:

1. Splits the given text into words.
2. Uses a dictionary to group words that are anagrams of each other.
3. Returns a dictionary where:

   * The key is the sorted letters (like `"eilnst"`).
   * The value is a list of words that are anagrams.

You can test your function using a big text file:

```python
txt = open('/cxldata/big.txt').read()
```

---

### Example:

```python
find_anagrams("listen silent enlist inlets hello world")
# Possible Output:
# {
#   'eilnst': ['listen', 'silent', 'enlist', 'inlets'],
#   'ehllo': ['hello'],
#   'dlorw': ['world']
# }
```

```python
find_anagrams("evil vile live veil")
# Output:
# {
#   'eilv': ['evil', 'vile', 'live', 'veil']
# }
```

---

# %%
def find_anagrams(text):
    dictionary = {}
    
    word_list = text.split(" ")
    for w in word_list:
        sorted_w = "".join(sorted(w))
        if sorted_w in dictionary:
            list_word = dictionary[sorted_w]
            if w not in list_word:
                list_word.append(w)
            dictionary[sorted_w] = list_word
        else:
            dictionary[sorted_w] = [w]
            
    return dictionary

# %%
find_anagrams("listen silent enlist inlets hello world")
# Out:
# {'eilnst': ['listen', 'silent', 'enlist', 'inlets'],
#  'ehllo': ['hello'],
#  'dlorw': ['world']}

# %%
find_anagrams("evil vile live veil")
# Out:
# {'eilv': ['evil', 'vile', 'live', 'veil']}

# %%
txt = open('/cxldata/big.txt').read()
find_anagrams(txt)
# Out:
# {'Teh': ['The'],
#  'Pcejort': ['Project'],
#  'Gbeegnrtu': ['Gutenberg'],
#  'BEkoo': ['EBook'],
#  'fo': ['of'],
#  'Adeenrstuv': ['Adventures'],
#  'Scehklor': ['Sherlock'],
#  '\nHbelmosy': ['Holmes\nby'],
#  'Sir': ['Sir'],
#  'Ahrrtu': ['Arthur'],
#  'Canno': ['Conan'],
#  '\n#(15Deloy': ['Doyle\n(#15'],
#  'in': ['in', 'ni'],
#  'oru': ['our'],
#  'eeirss': ['series'],
#  'by': ['by'],
#  '\n\n)CDeghilooprtyy': ['Doyle)\n\nCopyright'],
#  'alsw': ['laws'],
#  'aer': ['are', 'ear', 'era'],
#  'acgghinn': ['changing'],
#  'all': ['all'],
#  'eorv': ['over'],
#  'eht': ['the'],
#  '.dlorw': ['world.'],
#  'Be': ['Be'],
#  'ersu': ['sure', 'ruse', 'user'],
#  'ot': ['to'],
#  'ccehk': ['check'],
#  '\nceghhioprtty': ['the\ncopyright'],
#  'for': ['for', 'fro'],
#  'oruy': ['your'],
#  'cnortuy': ['country'],
#  'beefor': ['before'],
#  'addgilnnoow': ['downloading'],
#  'or': ['or'],
#  '\nbdeghiiiinrrsstttu': ['redistributing\nthis'],
#  'any': ['any'],
#  'ehort': ['other'],
#  '\n\n.BTehikoos': ['eBook.\n\nThis'],
#  'adeehr': ['header', 'adhere'],
#  'dhlosu': ['should'],
#  'be': ['be'],
#  'first': ['first', 'rifts'],
#  'ghint': ['thing', 'night'],
#  'eens': ['seen'],
#  'ehnw': ['when', 'hewn'],
#  'egiinvw': ['viewing'],
#  'hist': ['this', 'hits'],
#  '\nGPbceeegjnorrttu': ['Project\nGutenberg'],
#  '.efil': ['file.', 'life.'],
#  '': [''],
#  'Paeels': ['Please'],
#  'do': ['do'],
#  'not': ['not', 'ton', 'ont'],
#  'eemorv': ['remove'],
#  '.it': ['it.'],
#  'Do': ['Do'],
#  'aceghn': ['change'],
#  'deit': ['edit', 'tide', 'tied', 'diet'],
#  '\nadeeehhrt': ['the\nheader'],
#  'hiottuw': ['without'],
#  'einrttw': ['written'],
#  '\n\n.Paeeeiilmnoprsss': ['permission.\n\nPlease'],
#  'ader': ['read', 'dear', 'dare'],
#  '"aegll': ['"legal'],
#  'allms': ['small'],
#  '",inprt': ['print,"'],
#  'adn': ['and', 'dan'],
#  'afiimnnoort': ['information'],
#  'abotu': ['about'],
#  '\nBeehkoot': ['the\neBook'],
#  'at': ['at', 'ta'],
#  'bmoott': ['bottom'],
#  'Icddelnu': ['Included'],
#  '\naiimnoprstt': ['is\nimportant'],
#  'ccefiips': ['specific'],
#  'ghirst': ['rights', 'girths'],
#  'ceiinorrsstt': ['restrictions'],
#  '\nhinow': ['in\nhow'],
#  'efil': ['file', 'life'],
#  'amy': ['may', 'amy'],
#  '.desu': ['used.', 'dues.'],
#  'You': ['You'],
#  'acn': ['can'],
#  'alos': ['also'],
#  'dfin': ['find'],
#  'otu': ['out'],
#  'how': ['how', 'who'],
#  'aekm': ['make'],
#  '\naadinnoot': ['a\ndonation'],
#  ',Gbeegnrtu': ['Gutenberg,'],
#  'egt': ['get'],
#  '\n\n\n**.Wcdeeeillmnoovv': ['involved.\n\n\n**Welcome'],
#  'To': ['To'],
#  'Wdlor': ['World'],
#  'Feer': ['Free'],
#  'Pailn': ['Plain'],
#  'Vaailln': ['Vanilla'],
#  'Ecceilnort': ['Electronic'],
#  '\n\n****BTeekoosstx': ['Texts**\n\n**eBooks'],
#  'Raabdeel': ['Readable'],
#  'By': ['By'],
#  'Bhot': ['Both'],
#  'Hamnsu': ['Humans'],
#  ',Cemoprstu': ['Computers,'],
#  'Scein': ['Since'],
#  '\n\n*******1179Teehs': ['1971**\n\n*****These'],
#  'Bekoos': ['eBooks'],
#  'Weer': ['Were'],
#  'Padeeprr': ['Prepared'],
#  'Tadhnossu': ['Thousands'],
#  '\n\n\n!*****:TVeeeillnorsttu': ['Volunteers!*****\n\n\nTitle:'],
#  '\n\n:AHehlmoorstu': ['Holmes\n\nAuthor:'],
#  '\n\nDRaeeeellosy': ['Doyle\n\nRelease'],
#  ':Daet': ['Date:'],
#  ',Machr': ['March,'],
#  '1999': ['1999'],
#  'BE[koo': ['[EBook'],
#  '\n#1166M[]ost': ['#1661]\n[Most'],
#  'ceelnrty': ['recently'],
#  ':addeptu': ['updated:'],
#  'Nbeemorv': ['November'],
#  ',29': ['29,', '92,'],
#  '\n\n0022:E]diinot': ['2002]\n\nEdition:'],
#  '\n\n12:Laaeggnu': ['12\n\nLanguage:'],
#  '\n\nCEaaceghhilnrrst': ['English\n\nCharacter'],
#  'est': ['set', 'est'],
#  ':cdeginno': ['encoding:'],
#  '\n\n***ACIIS': ['ASCII\n\n***'],
#  'ARSTT': ['START'],
#  'FO': ['OF'],
#  'EHT': ['THE'],
#  'CEJOPRT': ['PROJECT'],
#  'BEEGGNRTU': ['GUTENBERG'],
#  ',BEKOO': ['EBOOK,'],
#  'ADEENRSTUV': ['ADVENTURES'],
#  'CEHKLORS': ['SHERLOCK'],
#  'EHLMOS': ['HOLMES'],
#  '\n\n\n\n\n(***Aaddiilnot': ['***\n\n\n\n\n(Additional'],
#  'degiint': ['editing'],
#  'Jeos': ['Jose'],
#  '\n\n\n\n)EHMTdeeennz': ['Menendez)\n\n\n\nTHE'],
#  '\nCEFHKLOORS': ['OF\nSHERLOCK'],
#  '\n\n\n\nBEHILMORSSY': ['HOLMES\n\nBY\n\nSIR'],
#  'AHRRTU': ['ARTHUR'],
#  'ACNNO': ['CONAN'],
#  '\t\n\n\n\n.ACDEEILNNOOSTTY': ['DOYLE\n\nCONTENTS\n\nI.\tA'],
#  'Saacdln': ['Scandal'],
#  '\t\n.BIITaeehhimo': ['Bohemia\nII.\tThe'],
#  '-HRadddeee': ['Red-Headed'],
#  '\t\n.AIIILaeegu': ['League\nIII.\tA'],
#  'Caes': ['Case'],
#  '\t\n.IITVdeehintty': ['Identity\nIV.\tThe'],
#  'Bbcemoos': ['Boscombe'],
#  'Vaelly': ['Valley'],
#  '\t\n.MTVeehrstyy': ['Mystery\nV.\tThe'],
#  'Feiv': ['Five'],
#  'Oaegnr': ['Orange'],
#  '\t\n.IPTVehips': ['Pips\nVI.\tThe'],
#  'Man': ['Man'],
#  'hitw': ['with', 'whit'],
#  'Tdeistw': ['Twisted'],
#  '\t\n.IILTVehip': ['Lip\nVII.\tThe'],
#  'Adeenrtuv': ['Adventure'],
#  'Belu': ['Blue'],
#  '\t\n.CIIITVabceehlnru': ['Carbuncle\nVIII.\tThe'],
#  'Scdeeklp': ['Speckled'],
#  '\t\n.BITXadehn': ['Band\nIX.\tThe'],
#  "'Eeeginnrs": ["Engineer's"],
#  '\t\n.TTXbehhmu': ['Thumb\nX.\tThe'],
#  'Nbelo': ['Noble'],
#  '\t\n.BITXaceehhlor': ['Bachelor\nXI.\tThe'],
#  'Belry': ['Beryl'],
#  '\t\n.CIITXeehnoort': ['Coronet\nXII.\tThe'],
#  'Ceoppr': ['Copper'],
#  '\n\n\nABDEENRTUVceeehs': ['Beeches\n\n\nADVENTURE'],
#  '.I': ['I.'],
#  'A': ['A'],
#  'AACDLNS': ['SCANDAL'],
#  'IN': ['IN'],
#  '\n\n\n\n\n.ABEHIIMOTo': ['BOHEMIA\n\nI.\n\n\nTo'],
#  'Helmos': ['Holmes'],
#  'ehs': ['she'],
#  'is': ['is', 'si'],
#  'aalswy': ['always'],
#  '.amnow': ['woman.'],
#  'I': ['I'],
#  'aehv': ['have'],
#  'delmos': ['seldom'],
#  'adehr': ['heard'],
#  'him': ['him'],
#  'eimnnot': ['mention'],
#  'ehr': ['her'],
#  'denru': ['under'],
#  '.aemn': ['name.', 'mean.'],
#  'In': ['In'],
#  'his': ['his'],
#  'eesy': ['eyes'],
#  'ceeilpss': ['eclipses'],
#  'adeeimnoprst': ['predominates'],
#  'ehlow': ['whole'],
#  '.esx': ['sex.'],
#  'It': ['It'],
#  'asw': ['was', 'saw'],
#  'ahtt': ['that'],
#  'eh': ['he', 'eh'],
#  'eflt': ['felt', 'left'],
#  'eimnoot': ['emotion'],
#  'aikn': ['akin'],
#  'elov': ['love'],
#  'Ieenr': ['Irene'],
#  '.Adelr': ['Adler.'],
#  'All': ['All'],
#  ',eimnoost': ['emotions,'],
#  'eno': ['one'],
#  ',aacillprrtuy': ['particularly,'],
#  'eerw': ['were'],
#  'abehnorrt': ['abhorrent'],
#  ',cdlo': ['cold,'],
#  'ceeiprs': ['precise'],
#  'btu': ['but', 'tub'],
#  'aabdilmry': ['admirably'],
#  'aabcdeln': ['balanced'],
#  '.dimn': ['mind.'],
#  'He': ['He'],
#  ',asw': ['was,', 'saw,'],
#  'aekt': ['take', 'kate'],
#  ',it': ['it,'],
#  'most': ['most'],
#  'ceefprt': ['perfect', 'prefect'],
#  'aeginnors': ['reasoning'],
#  'beginorsv': ['observing'],
#  'acehimn': ['machine'],
#  'dlorw': ['world'],
#  'ahs': ['has', 'ash'],
#  ',eens': ['seen,'],
#  'as': ['as', 'sa'],
#  'a': ['a'],
#  'elorv': ['lover'],
#  'dlouw': ['would'],
#  'acdelp': ['placed'],
#  'efhilms': ['himself'],
#  'aefls': ['false', 'fleas'],
#  '.iinoopst': ['position.'],
#  'eenrv': ['never', 'nerve'],
#  'ekops': ['spoke'],
#  'eforst': ['softer', 'foster', 'forest'],
#  ',ainopsss': ['passions,'],
#  'aesv': ['save', 'vase'],
#  'begi': ['gibe'],
#  '.eenrs': ['sneer.'],
#  'Tehy': ['They'],
#  'aabdeilmr': ['admirable'],
#  'ghinst': ['things', 'nights'],
#  '--bceeeeellnorrstvx': ['observer--excellent'],
#  'adginrw': ['drawing', 'warding'],
#  'eilv': ['veil', 'vile', 'evil', 'live'],
#  'fmor': ['from', 'form'],
#  "'emns": ["men's"],
#  'eimostv': ['motives'],
#  '.acinost': ['actions.'],
#  'Btu': ['But'],
#  'adeinrt': ['trained'],
#  'aeenorrs': ['reasoner'],
#  'adimt': ['admit'],
#  'chsu': ['such'],
#  'iinnorsstu': ['intrusions'],
#  'inot': ['into'],
#  'now': ['own', 'now', 'won'],
#  'acdeeilt': ['delicate'],
#  'efilny': ['finely'],
#  'addejstu': ['adjusted'],
#  'aeeemmnprtt': ['temperament'],
#  'cdeinortu': ['introduce', 'reduction'],
#  'acdgiinrstt': ['distracting'],
#  'acfort': ['factor'],
#  'chhiw': ['which'],
#  'ghimt': ['might'],
#  'hortw': ['throw', 'worth'],
#  'bdotu': ['doubt'],
#  'nopu': ['upon'],
#  'aelmnt': ['mental', 'lament', 'mantle'],
#  '.elrsstu': ['results.', 'sutlers.'],
#  'Girt': ['Grit'],
#  'eeiinsstv': ['sensitive'],
#  ',eimnnrsttu': ['instrument,'],
#  'acckr': ['crack'],
#  '-eghhioprw': ['high-power'],
#  ',eelnss': ['lenses,'],
#  'emor': ['more', 'rome'],
#  'bdgiinrstu': ['disturbing'],
#  'ahnt': ['than'],
#  'gnorst': ['strong'],
#  'aenrtu': ['nature'],
#  '.his': ['his.'],
#  'Adn': ['And'],
#  'ety': ['yet', 'ety'],
#  'eehrt': ['there', 'three', 'ether'],
#  'amnow': ['woman'],
#  ',him': ['him,'],
#  'aelt': ['late', 'tale', 'alte'],
#  ',Adelr': ['Adler,'],
#  'bdiosuu': ['dubious'],
#  'abeeilnoqstu': ['questionable'],
#  '\n\n.Iemmory': ['memory.\n\nI'],
#  'adh': ['had'],
#  'eilltt': ['little'],
#  '.aellty': ['lately.'],
#  'My': ['My'],
#  'aaegimrr': ['marriage'],
#  'ddefirt': ['drifted'],
#  'su': ['us'],
#  'aawy': ['away'],
#  'aceh': ['each', 'ache'],
#  '.ehort': ['other.'],
#  'ceelmopt': ['complete'],
#  ',aehinppss': ['happiness,'],
#  '-cdeeehmnort': ['home-centred'],
#  'eeinrsstt': ['interests'],
#  'eirs': ['rise', 'sire'],
#  'pu': ['up'],
#  'adnoru': ['around'],
#  'amn': ['man'],
#  'dfins': ['finds'],
#  'aemrst': ['master', 'stream'],
#  ',abeehilmnsstt': ['establishment,'],
#  'ceffiinstu': ['sufficient'],
#  'abbors': ['absorb'],
#  'my': ['my'],
#  ',aeinnottt': ['attention,'],
#  'ehilw': ['while'],
#  ',Helmos': ['Holmes,'],
#  'adehlot': ['loathed'],
#  'eervy': ['every'],
#  'ceiosty': ['society'],
#  'Baehimno': ['Bohemian'],
#  ',losu': ['soul,'],
#  'adeeimnr': ['remained'],
#  'dggilnos': ['lodgings'],
#  'Baekr': ['Baker'],
#  ',Seertt': ['Street,'],
#  'bdeiru': ['buried'],
#  'agmno': ['among'],
#  'dlo': ['old'],
#  ',bkoos': ['books,'],
#  'aaegilnnrtt': ['alternating'],
#  'eekw': ['week'],
#  'beeentw': ['between'],
#  'acceino': ['cocaine'],
#  ',abiimnot': ['ambition,'],
#  'deinorsssw': ['drowsiness'],
#  ',dgru': ['drug,'],
#  'ceefir': ['fierce'],
#  'eegnry': ['energy'],
#  'eekn': ['keen', 'knee'],
#  '.aenrtu': ['nature.'],
#  ',illst': ['still,'],
#  ',eerv': ['ever,'],
#  'deelpy': ['deeply'],
#  'aacderttt': ['attracted'],
#  'dstuy': ['study', 'dusty'],
#  ',ceimr': ['crime,', 'merci,'],
#  'ccdeiopu': ['occupied'],
#  'eeimmns': ['immense'],
#  'acefilstu': ['faculties'],
#  'aadeinorrrtxy': ['extraordinary'],
#  'eoprsw': ['powers'],
#  'abeinoorstv': ['observation'],
#  'fgillnoow': ['following'],
#  'ehost': ['those'],
#  ',celsu': ['clues,'],
#  'acegilnr': ['clearing'],
#  'eeimrssty': ['mysteries'],
#  'been': ['been'],
#  'aabddenno': ['abandoned'],
#  'eehlopss': ['hopeless'],
#  'acffiilo': ['official'],
#  '.ceilop': ['police.'],
#  'Fmor': ['From', 'Form'],
#  'eimt': ['time', 'item', 'emit'],
#  'emos': ['some'],
#  'aeguv': ['vague'],
#  'accnotu': ['account'],
#  ':dginos': ['doings:'],
#  'mmnossu': ['summons'],
#  'Oadess': ['Odessa'],
#  'aces': ['case'],
#  'Teffopr': ['Trepoff'],
#  ',demrru': ['murder,'],
#  'agilnrsu': ['singular'],
#  'adegrty': ['tragedy'],
#  'Aiknnost': ['Atkinson'],
#  'behorrst': ['brothers'],
#  ',Taceeilmnor': ['Trincomalee,'],
#  'afillny': ['finally'],
#  'iimnoss': ['mission'],
#  'accdehilmops': ['accomplished'],
#  'os': ['so', 'os'],
#  'acdeeillty': ['delicately'],
#  'ccefllsssuuy': ['successfully'],
#  'eggiinnr': ['reigning'],
#  'afilmy': ['family'],
#  '.Hadllno': ['Holland.'],
#  'Bdenoy': ['Beyond'],
#  'eehst': ['these', 'sheet'],
#  'ginss': ['signs', 'sings'],
#  ',aciittvy': ['activity,'],
#  ',eehorvw': ['however,'],
#  'eelmry': ['merely'],
#  'adehrs': ['shared'],
#  'adeerrs': ['readers'],
#  'adily': ['daily', 'lydia'],
#  ',eprss': ['press,'],
#  'eknw': ['knew'],
#  'efmorr': ['former', 'reform'],
#  'definr': ['friend', 'finder'],
#  '\n\n.Oaceimnnnoop': ['companion.\n\nOne'],
#  '--ghiintt': ['night--it'],
#  'no': ['on', 'no'],
#  'eehintttw': ['twentieth'],
#  '--1888I': ['1888--I'],
#  'eginnrrtu': ['returning'],
#  'ejnoruy': ['journey'],
#  'aeinptt': ['patient'],
#  '(for': ['(for'],
#  'deenrrtu': ['returned'],
#  'ciilv': ['civil'],
#  '),acceiprt': ['practice),'],
#  'awy': ['way'],
#  'del': ['led', 'del'],
#  'em': ['me'],
#  'ghhortu': ['through'],
#  '.Seertt': ['Street.'],
#  'As': ['As'],
#  'adepss': ['passed', 'spades'],
#  '-bdeeeeellmmrrw': ['well-remembered'],
#  ',door': ['door,'],
#  'mstu': ['must'],
#  'aacdeiosst': ['associated'],
#  'dimn': ['mind'],
#  ',ginoow': ['wooing,'],
#  'adkr': ['dark'],
#  'cdeiinnst': ['incidents'],
#  'Sdtuy': ['Study'],
#  ',Sacelrt': ['Scarlet,'],
#  'deeisz': ['seized'],
#  'deeirs': ['desire', 'reside'],
#  'ees': ['see'],
#  ',aagin': ['again,'],
#  'know': ['know'],
#  'egilmnopy': ['employing'],
#  '.eoprsw': ['powers.'],
#  'His': ['His'],
#  'moors': ['rooms'],
#  'abiilllnrty': ['brilliantly'],
#  ',ilt': ['lit,'],
#  ',adn': ['and,'],
#  'eenv': ['even'],
#  'dekloo': ['looked'],
#  ',pu': ['up,'],
#  ',allt': ['tall,'],
#  'aeprs': ['spare', 'spear'],
#  'efgiru': ['figure'],
#  'apss': ['pass', 'spas'],
#  'ceitw': ['twice'],
#  'eehilosttu': ['silhouette'],
#  'aaginst': ['against'],
#  '.bdiln': ['blind.'],
#  'acginp': ['pacing'],
#  'moor': ['room', 'moor'],
#  ',filstwy': ['swiftly,'],
#  ',aeeglry': ['eagerly,'],
#  'adeh': ['head', 'deah', 'dahe'],
#  'knsu': ['sunk'],
#  'cehst': ['chest'],
#  'adhns': ['hands'],
#  'acdelps': ['clasped'],
#  'bdehin': ['behind'],
#  '.him': ['him.'],
#  ',em': ['me,'],
#  'dmoo': ['mood', 'doom'],
#  ',abhit': ['habit,'],
#  'adeitttu': ['attitude'],
#  'aemnnr': ['manner'],
#  'dlot': ['told'],
#  'ehirt': ['their'],
#  '.orsty': ['story.'],
#  'korw': ['work'],
#  '.aagin': ['again.'],
#  'einrs': ['risen', 'reins'],
#  '-acddeegrrtu': ['drug-created'],
#  'ademrs': ['dreams'],
#  'hot': ['hot'],
#  'censt': ['scent', 'cents'],
#  'enw': ['new', 'wen'],
#  '.belmopr': ['problem.'],
#  'agnr': ['rang'],
#  'bell': ['bell'],
#  'hnosw': ['shown'],
#  'abcehmr': ['chamber'],
#  'eflmorry': ['formerly'],
#  'aprt': ['part', 'trap', 'rapt'],
#  '\n\n.Hinosw': ['own.\n\nHis'],
#  '.eeffisuv': ['effusive.'],
#  ';asw': ['was;'],
#  ',adgl': ['glad,'],
#  ',hiknt': ['think,'],
#  '.em': ['me.'],
#  'Whit': ['With'],
#  'adhlry': ['hardly'],
#  'dorw': ['word'],
#  ',eknops': ['spoken,'],
#  'diklny': ['kindly'],
#  ',eey': ['eye,'],
#  'adevw': ['waved'],
#  'an': ['an', 'na'],
#  ',aachimrr': ['armchair,'],
#  'ehrtw': ['threw'],
#  'acorss': ['across'],
#  ',acgirs': ['cigars,'],
#  'acddeiint': ['indicated'],
#  'iiprst': ['spirit'],
#  'aeeggnos': ['gasogene'],
#  '.cenorr': ['corner.'],
#  'Tehn': ['Then'],
#  'doost': ['stood'],
#  'efir': ['fire', 'rife'],
#  'ceeiinoprsttv': ['introspective'],
#  '\n\n".Wacdefhiklnoos': ['fashion.\n\n"Wedlock'],
#  'isstu': ['suits'],
#  '",ouy': ['you,"'],
#  '.adeekmrr': ['remarked.'],
#  '"I': ['"I', 'I"'],
#  ',Wanost': ['Watson,'],
#  'ouy': ['you'],
#  'ptu': ['put'],
#  'eensv': ['seven'],
#  'afhl': ['half'],
#  'dnopsu': ['pounds'],
#  'ceins': ['since'],
#  '\n\n!""".Seenouvy': ['you."\n\n"Seven!"'],
#  '\n\n",.Iadddeeeennrsw': ['answered.\n\n"Indeed,'],
#  'ghhottu': ['thought'],
#  '.emor': ['more.'],
#  'Jstu': ['Just'],
#  'efilrt': ['trifle', 'filter'],
#  ',emor': ['more,'],
#  ',acfny': ['fancy,'],
#  '.Wanost': ['Watson.'],
#  'acceiprt': ['practice'],
#  '.beeorsv': ['observe.'],
#  'ddi': ['did'],
#  'ellt': ['tell'],
#  'ddeeinnt': ['intended'],
#  'go': ['go'],
#  '\n\n"",.Taeehhnnrss': ['harness."\n\n"Then,'],
#  '\n\n""?Iknow': ['know?"\n\n"I'],
#  'cddeeu': ['deduce'],
#  'How': ['How'],
#  'eggintt': ['getting'],
#  'eflorsuy': ['yourself'],
#  'ervy': ['very'],
#  'etw': ['wet'],
#  ',aellty': ['lately,'],
#  'clmsuy': ['clumsy'],
#  'aceelrss': ['careless'],
#  'aenrstv': ['servant', 'taverns'],
#  '\n\n""?Mgilry': ['girl?"\n\n"My'],
#  '",Helmos': ['Holmes,"'],
#  'adis': ['said', 'aids'],
#  ',I': ['I,'],
#  '"hist': ['"this'],
#  'oot': ['too'],
#  '.chmu': ['much.'],
#  'aceilnrty': ['certainly'],
#  ',bdenru': ['burned,', 'burden,'],
#  'deilv': ['lived', 'devil'],
#  'efw': ['few'],
#  'ceeinrstu': ['centuries'],
#  '.ago': ['ago.'],
#  'ertu': ['true'],
#  'aklw': ['walk'],
#  'Tadhrsuy': ['Thursday'],
#  'acem': ['came', 'acme'],
#  'ehmo': ['home'],
#  'addeflru': ['dreadful'],
#  ',emss': ['mess,'],
#  'acdeghn': ['changed'],
#  'cehlost': ['clothes'],
#  "'acnt": ["can't"],
#  'aegiimn': ['imagine'],
#  'Mary': ['Mary'],
#  ',Jaen': ['Jane,'],
#  ',bcegiiilnorr': ['incorrigible,'],
#  'efiw': ['wife', 'fiew'],
#  'eginv': ['given'],
#  ',ceinot': ['notice,'],
#  ',eehrt': ['there,', 'three,', 'ether,'],
#  'afil': ['fail'],
#  'it': ['it', 'ti'],
#  '\n\n".Heotu': ['out."\n\nHe'],
#  'ccdehklu': ['chuckled'],
#  'bbderu': ['rubbed'],
#  ',glno': ['long,'],
#  'enorsuv': ['nervous'],
#  '\n\n".Ieeghorttt': ['together.\n\n"It'],
#  'ciiilmpsty': ['simplicity'],
#  '",efilst': ['itself,"'],
#  ';eh': ['he;'],
#  '"my': ['"my'],
#  'deiins': ['inside', 'indies'],
#  ',ehos': ['shoe,'],
#  'jstu': ['just'],
#  'eehrw': ['where'],
#  'efghiilrt': ['firelight'],
#  'eikrsst': ['strikes'],
#  'aeehlrt': ['leather'],
#  'cdeors': ['scored'],
#  'isx': ['six'],
#  'almost': ['almost'],
#  'aaelllpr': ['parallel'],
#  '.cstu': ['cuts.'],
#  'Obilosuvy': ['Obviously'],
#  'ehty': ['they'],
#  'acdesu': ['caused'],
#  'eemnoos': ['someone'],
#  'aceellrssy': ['carelessly'],
#  'acdeprs': ['scraped'],
#  'dnoru': ['round'],
#  'deegs': ['edges'],
#  'elos': ['sole', 'lose'],
#  'deorr': ['order', 'ordre'],
#  'cderstu': ['crusted', 'crudest'],
#  'dmu': ['mud'],
#  ',Hceen': ['Hence,'],
#  ',ees': ['see,'],
#  'bdelou': ['double'],
#  'cddeinotu': ['deduction'],
#  ',aeehrtw': ['weather,'],
#  'aacillprrtuy': ['particularly'],
#  'aagilmnnt': ['malignant'],
#  '-bgiilnoosttt': ['boot-slitting'],
#  'ceeimnps': ['specimen'],
#  'Ldnnoo': ['London'],
#  '.aelsvy': ['slavey.'],
#  ',acceiprt': ['practice,'],
#  'fi': ['if'],
#  'aeeglmnnt': ['gentleman'],
#  'aklsw': ['walks'],
#  'egillmns': ['smelling'],
#  ',dfimooor': ['iodoform,'],
#  'abckl': ['black'],
#  'akmr': ['mark'],
#  'aeinrtt': ['nitrate'],
#  'eilrsv': ['silver'],
#  'ghirt': ['right', 'girth'],
#  ',eeffginorr': ['forefinger,'],
#  'beglu': ['bulge', 'bugle'],
#  'deis': ['side', 'dies'],
#  '-ahoptt': ['top-hat'],
#  'hosw': ['show'],
#  'cdeeerst': ['secreted', 'resected'],
#  ',ceehoopsstt': ['stethoscope,'],
#  ',dllu': ['dull,'],
#  ',ddeein': ['indeed,'],
#  'cennoopru': ['pronounce'],
#  'aceitv': ['active'],
#  'beemmr': ['member'],
#  'acdeilm': ['medical', 'claimed'],
#  '\n\n".Iefinooprss': ['profession."\n\nI'],
#  'cdlou': ['could', 'cloud'],
#  'ehlp': ['help'],
#  'agghilnu': ['laughing'],
#  'aees': ['ease'],
#  'adeeilnpx': ['explained'],
#  'ceoprss': ['process', 'corpses'],
#  '.cddeinotu': ['deduction.'],
#  '"Wehn': ['"When'],
#  'aehr': ['hear', 'hare'],
#  'egiv': ['give'],
#  '",aenorss': ['reasons,"'],
#  ',adeekmrr': ['remarked,'],
#  '"eht': ['"the'],
#  'aaepprs': ['appears'],
#  'cdiillorsuuy': ['ridiculously'],
#  'eilmps': ['simple', 'impels'],
#  'aeilsy': ['easily'],
#  ',eflmsy': ['myself,'],
#  'ghhotu': ['though'],
#  'cceeisssuv': ['successive'],
#  'aceinnst': ['instance', 'ancients'],
#  'am': ['am', 'ma'],
#  'abdeffl': ['baffled'],
#  'ilntu': ['until'],
#  'aeilnpx': ['explain'],
#  '.ceoprss': ['process.'],
#  'beeeilv': ['believe'],
#  'dgoo': ['good'],
#  '\n\n"".Qeiorstuuy': ['yours."\n\n"Quite'],
#  '",os': ['so,"'],
#  ',adeenrsw': ['answered,'],
#  'gghiilnt': ['lighting'],
#  ',aceegirtt': ['cigarette,'],
#  'ghinortw': ['throwing', 'ingrowth'],
#  'dnow': ['down'],
#  '.aachimrr': ['armchair.'],
#  '"You': ['"You'],
#  'cdiiinnostt': ['distinction'],
#  '.acelr': ['clear.'],
#  'For': ['For'],
#  ',aeelmpx': ['example,'],
#  'eeflnqrtuy': ['frequently'],
#  'epsst': ['steps'],
#  'adel': ['lead', 'deal'],
#  'ahll': ['hall'],
#  '\n\n\n\n""""..FHeelmnoooqrrtuwy': ['room."\n\n"Frequently."\n\n"How'],
#  '\n\n"",?Weefllnot': ['often?"\n\n"Well,'],
#  'ddehnrsu': ['hundreds'],
#  '\n\n"".Teehimnst': ['times."\n\n"Then'],
#  'amny': ['many'],
#  '\n\n""?Heehortw': ['there?"\n\n"How'],
#  '?amny': ['many?'],
#  "'dnot": ["don't"],
#  '\n\n"".Qeiknotuw': ['know."\n\n"Quite'],
#  '!os': ['so!'],
#  '.bdeeorsv': ['observed.'],
#  '.eens': ['seen.'],
#  'Taht': ['That'],
#  '.inopt': ['point.'],
#  ',Now': ['Now,'],
#  'eeeennstv': ['seventeen'],
#  ',epsst': ['steps,'],
#  'abceesu': ['because'],
#  'bhot': ['both'],
#  ',awy': ['way,'],
#  'deeeinrstt': ['interested'],
#  ',belmoprs': ['problems,'],
#  'eghnou': ['enough'],
#  'ccehilnor': ['chronicle'],
#  'otw': ['two', 'tow'],
#  'fgiilnrt': ['trifling', 'flirting'],
#  ',ceeeeinprsx': ['experiences,'],
#  '".hist': ['this."'],
#  ',chikt': ['thick,'],
#  '-deiiknnptt': ['pink-tinted'],
#  'aeenopprt': ['notepaper'],
#  'gilny': ['lying'],
#  'enop': ['open'],
#  '.abelt': ['table.'],
#  '"It': ['"It'],
#  'alst': ['last', 'salt'],
#  '",opst': ['post,"', 'spot,"'],
#  '.eh': ['he.'],
#  '"Rade': ['"Read'],
#  '\n\n".Tadehlou': ['aloud."\n\nThe'],
#  'enot': ['note', 'tone'],
#  ',addentu': ['undated,'],
#  'eehirt': ['either'],
#  'aeginrstu': ['signature'],
#  '\n\n".Taddeeehrrss': ['address.\n\n"There'],
#  'illw': ['will'],
#  'acll': ['call'],
#  ',-ghinott': ['to-night,'],
#  'aeqrrtu': ['quarter'],
#  'eghit': ['eight'],
#  '"\',cckloo': ['o\'clock,"'],
#  ',adis': ['said,'],
#  '"a': ['"a'],
#  'deeirss': ['desires'],
#  'clnostu': ['consult'],
#  'aemrtt': ['matter'],
#  'deeepst': ['deepest'],
#  '.emmnot': ['moment.'],
#  'Yoru': ['Your'],
#  'ceenrt': ['recent', 'centre', 'center'],
#  'ceeirssv': ['services'],
#  'alory': ['royal'],
#  'ehossu': ['houses'],
#  'Eeopru': ['Europe'],
#  'aeflsy': ['safely'],
#  'dersttu': ['trusted'],
#  'aemrstt': ['matters'],
#  'aceimnoprt': ['importance'],
#  '.aadeeeggrtx': ['exaggerated.'],
#  'This': ['This'],
#  'ew': ['we'],
#  'aeqrrstu': ['quarters'],
#  '.cdeeeirv': ['received.'],
#  'ehnt': ['then'],
#  ',horu': ['hour,'],
#  'aimss': ['amiss'],
#  'iiorstv': ['visitor'],
#  'aerw': ['wear', 'ware'],
#  '\n\n"".Tahikmss': ['mask."\n\n"This'],
#  'ddeein': ['indeed', 'denied'],
#  '",emrstyy': ['mystery,"'],
#  '"Waht': ['"What'],
#  '\n\n""?Iaemns': ['means?"\n\n"I'],
#  'aadt': ['data'],
#  '.ety': ['yet.'],
#  'aacilpt': ['capital'],
#  'aeikmst': ['mistake'],
#  'eehiorst': ['theorise', 'theories'],
#  '.aadt': ['data.'],
#  'Ibeilnnssy': ['Insensibly'],
#  'begins': ['begins', 'beings'],
#  'isttw': ['twist'],
#  'acfst': ['facts'],
#  'istu': ['suit'],
#  ',eehiorst': ['theories,'],
#  'adeinst': ['instead', 'stained'],
#  '.acfst': ['facts.'],
#  '.efilst': ['itself.'],
#  'Waht': ['What'],
#  '\n\n"?Iit': ['it?"\n\nI'],
#  'acefllruy': ['carefully'],
#  'adeeimnx': ['examined'],
#  ',giinrtw': ['writing,'],
#  'aeppr': ['paper'],
#  '\n\n".Teehinrttw': ['written.\n\n"The'],
#  'eortw': ['wrote', 'tower'],
#  'abelmprsuy': ['presumably'],
#  'ellw': ['well'],
#  '",do': ['do,"'],
#  'adeeginnoruv': ['endeavouring'],
#  'aeiimtt': ['imitate'],
#  "'acimnnoops": ["companion's", "companions'"],
#  '.ceeoprsss': ['processes.'],
#  '"Schu': ['"Such'],
#  'bghotu': ['bought'],
#  'cnorw': ['crown'],
#  '.acekpt': ['packet.'],
#  'aceillpruy': ['peculiarly'],
#  '\n\n""--.Paaceffhiilrstttu': ['stiff."\n\n"Peculiar--that'],
#  '",dorw': ['word,"'],
#  '.Helmos': ['Holmes.'],
#  'Eghilns': ['English'],
#  '.all': ['all.'],
#  'Hdlo': ['Hold'],
#  '\n\n".Ighilt': ['light."\n\nI'],
#  ',os': ['so,'],
#  'aeglr': ['large', 'glare', 'regal'],
#  '""E': ['"E"'],
#  '"",g': ['"g,"'],
#  '"",P': ['"P,"'],
#  '""G': ['"G"'],
#  '""t': ['"t"'],
#  'enovw': ['woven'],
#  'eerttux': ['texture'],
#  '\n\n".Waaehpprt': ['paper.\n\n"What'],
#  '"?ahtt': ['that?"'],
#  'adeks': ['asked'],
#  '\n\n".HTeehlmos': ['Holmes.\n\n"The'],
#  'aemn': ['name', 'mean', 'mane'],
#  ',aekmr': ['maker,'],
#  ';bdotu': ['doubt;'],
#  ',agmmnoor': ['monogram,'],
#  '\n\n"".Naehorrtt': ['rather."\n\n"Not'],
#  "''G": ["'G'"],
#  "''t": ["'t'"],
#  'adnsst': ['stands'],
#  "'',Gaceefhllsst": ["'Gesellschaft,'"],
#  'Gaemnr': ['German'],
#  "''.Camnopy": ["'Company.'"],
#  'acmorstuy': ['customary'],
#  'accinnoortt': ['contraction'],
#  'eikl': ['like'],
#  "''.Co": ["'Co.'"],
#  "'',P": ["'P,'"],
#  ',ceorsu': ['course,'],
#  "''.Paeipr": ["'Papier.'"],
#  'Now': ['Now'],
#  "''.Eg": ["'Eg.'"],
#  'Let': ['Let'],
#  'acegln': ['glance'],
#  'Caeilnnnott': ['Continental'],
#  '".Gaeeerttz': ['Gazetteer."'],
#  'koot': ['took'],
#  'aehvy': ['heavy'],
#  'bnorw': ['brown'],
#  'elmouv': ['volume'],
#  '.eehlssv': ['shelves.'],
#  '",Eglow': ['"Eglow,'],
#  '--Eeeghilnortz': ['Eglonitz--here'],
#  ',aer': ['are,', 'ear,', 'era,'],
#  '.Eagir': ['Egria.'],
#  '-Gaaeegikmnnprs': ['German-speaking'],
#  '--cinnortuy': ['country--in'],
#  ',Baehimo': ['Bohemia,'],
#  'afr': ['far'],
#  '.Caabdlrs': ['Carlsbad.'],
#  "'Raabeeklmr": ["'Remarkable"],
#  'begin': ['being', 'begin'],
#  'ceens': ['scene'],
#  'adeht': ['death', 'hated'],
#  ',Waeeillnnst': ['Wallenstein,'],
#  'ist': ['its', 'sit', 'ist'],
#  'emnorsuu': ['numerous'],
#  '-aacefgilorssst': ['glass-factories'],
#  "'-.aeillmpprs": ["paper-mills.'"],
#  ',Ha': ['Ha,'],
#  ',ah': ['ha,', 'ah,'],
#  ',boy': ['boy,'],
#  'ahtw': ['what', 'thaw'],
#  ',adeklprs': ['sparkled,'],
#  'enst': ['sent', 'nest', 'tens', 'nets'],
#  'aegrt': ['great', 'grate'],
#  'belu': ['blue'],
#  'ahimnprttu': ['triumphant'],
#  '\n\n".Taceeeghirtt': ['cigarette.\n\n"The'],
#  'adem': ['made', 'mead', 'dame'],
#  '",Baehimo': ['Bohemia,"'],
#  '\n\n"..Pacdeeiilrssy': ['said.\n\n"Precisely.'],
#  '.Gaemnr': ['German.'],
#  'aceilpru': ['peculiar'],
#  'ccinnoorsttu': ['construction'],
#  "'--Tceeehinnsst": ["sentence--'This"],
#  "'.cdeeeirv": ["received.'"],
#  'Facehmnnr': ['Frenchman'],
#  'Rainssu': ['Russian'],
#  '.ahtt': ['that.'],
#  'cenoorstuuu': ['uncourteous'],
#  '.bersv': ['verbs.'],
#  'lnoy': ['only'],
#  ',aeimnrs': ['remains,', 'marines,'],
#  ',eeefhorrt': ['therefore,'],
#  'cdeiorsv': ['discover'],
#  'adentw': ['wanted'],
#  'eirstw': ['writes'],
#  'eefprrs': ['prefers'],
#  'aeginrw': ['wearing'],
#  'akms': ['mask'],
#  'ghinosw': ['showing'],
#  '.acef': ['face.'],
#  'eehr': ['here'],
#  ',cemos': ['comes,'],
#  ',aeikmnst': ['mistaken,'],
#  'eelorsv': ['resolve'],
#  '\n\n".Abdosstu': ['doubts."\n\nAs'],
#  'ahprs': ['sharp'],
#  'dnosu': ['sound'],
#  "'ehorss": ["horses'", "horse's"],
#  'fhoos': ['hoofs'],
#  'agginrt': ['grating'],
#  'eehlsw': ['wheels'],
#  ',bcru': ['curb,'],
#  'deflloow': ['followed'],
#  'llpu': ['pull'],
#  '.bell': ['bell.'],
#  '\n\n".Adehilstw': ['whistled.\n\n"A'],
#  ',aipr': ['pair,'],
#  '",dnosu': ['sound,"'],
#  '"",Yes': ['"Yes,"'],
#  ',cdeinnotu': ['continued,', 'unnoticed,'],
#  'acggilnn': ['glancing', 'clanging'],
#  '.dinoww': ['window.'],
#  '"A': ['"A'],
#  'cein': ['nice'],
#  'abghmoru': ['brougham'],
#  'aipr': ['pair'],
#  '.abeeistu': ['beauties.'],
#  'ddehnru': ['hundred'],
#  'ffity': ['fifty'],
#  'aeginsu': ['guineas'],
#  '.aceeip': ['apiece.'],
#  "'Teehrs": ["There's"],
#  'emnoy': ['money'],
#  ',aces': ['case,'],
#  'ghinnot': ['nothing'],
#  '\n\n"".Ieels': ['else."\n\n"I'],
#  'hiknt': ['think'],
#  'beertt': ['better'],
#  ',go': ['go,'],
#  '\n\n"".HNelmoost': ['Holmes."\n\n"Not'],
#  ',bit': ['bit,'],
#  '.Dcoort': ['Doctor.'],
#  'Saty': ['Stay'],
#  '.aer': ['are.', 'ear.', 'era.'],
#  'lost': ['lost', 'lots'],
#  '.Bellosw': ['Boswell.'],
#  'eimoprss': ['promises'],
#  '.eegiinnrstt': ['interesting.'],
#  'ipty': ['pity'],
#  'imss': ['miss'],
#  '\n\n"".Bittu': ['it."\n\n"But'],
#  '\n\n""--Nceeeilnrtv': ['client--"\n\n"Never'],
#  'antw': ['want'],
#  ',ehlp': ['help,'],
#  'Heer': ['Here'],
#  '.cemos': ['comes.'],
#  'Sit': ['Sit'],
#  ',Dcoort': ['Doctor,'],
#  'best': ['best', 'bets'],
#  '\n\n".Aaeinnottt': ['attention."\n\nA'],
#  'losw': ['slow'],
#  ',epst': ['step,'],
#  'airsst': ['stairs'],
#  ',aaegpss': ['passage,'],
#  'adepsu': ['paused'],
#  'adeeiilmmty': ['immediately'],
#  ...}

# %%
## Build an Expense Tracker

### Explanation:

When you spend money, you usually want to keep track of **where the money is going**. 
For example, you might spend on *food*, *rent*, *travel*, and so on. An **expense tracker** 
helps you organize your spending by category (also called *expense head*).

We can build a simple tracker using a **dictionary**:

* The *keys* will be the expense heads (like `"food"`, `"rent"`, `"travel"`).
* The *values* will be the total amount spent under that head.

We will write **two functions**:

1. `update_expenses(expense_list, expenses_dict)` → updates the dictionary with new expenses.

   * `expense_list` is a list of tuples like `[("food", 200), ("rent", 1000)]`.
   * `expenses_dict` is the dictionary where totals are stored.

2. `print_expenses(expenses_dict)` → prints the overall expenses under each head in a clean way.

---

### Exercise:

Write the following functions:

```python
def update_expenses(expense_list, expenses_dict):
    """
    Updates the dictionary with expenses from the list.
    Each element of expense_list is a tuple: (expense_head, amount).
    If the head already exists, add to its total.
    Otherwise, create a new entry.
    """
    pass


def print_expenses(expenses_dict):
    """
    Prints all expense heads and their total amounts.
    Example format:
    food : 500
    rent : 1000
    """
    pass
```

---

### Example Usage:

```python
expenses = {}

update_expenses([("food", 200), ("rent", 1000)], expenses)
update_expenses([("food", 300), ("travel", 150)], expenses)

print_expenses(expenses)
```

**Expected Output:**

```
food : 500
rent : 1000
travel : 150
```

---

# %%
def update_expenses(expense_list, expenses_dict):
    
    for e in expense_list:
        item,cost = e
        if item in expenses_dict:
            expenses_dict[item] = expenses_dict[item] - cost
     
    
    return expenses_dict

def print_expenses(expenses_dict):
    
    for key, value in expenses_dict.items():
        print (key, " : ", value)
    
    
    return

# %%
expenses = {"food": 600, "rent": 1050, "travel":200}

update_expenses([("food", 200), ("rent", 1000)], expenses)
update_expenses([("food", 300), ("travel", 150)], expenses)

print_expenses(expenses)
# Out:
# food  :  100
# rent  :  50
# travel  :  50

# %%
# WORD COUNT WITHOUT DICT

# %%
# txt = !head -500 /cxldata/big.txt
# txt = str(txt)
txt = open('/cxldata/big.txt').read()

# %%
words = txt.split(" ")

# %%
result_words = []
results_counts = []
for i, word in enumerate(words):
    if word in result_words:
        continue
    count = 1
    for w2 in words[i+1:]:
        if w2 == word:
            count += 1
    results_counts.append(count)
    result_words.append(word)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-1af6746c4f23> in <module>
#       5         continue
#       6     count = 1
# ----> 7     for w2 in words[i+1:]:
#       8         if w2 == word:
#       9             count += 1
#
# KeyboardInterrupt:

# %%
list(zip(result_words, results_counts))
# Out:
# [('The', 3793),
#  ('Project', 157),
#  ('Gutenberg', 64),
#  ('EBook', 5),
#  ('of', 34754),
#  ('Adventures', 2),
#  ('Sherlock', 69),
#  ('Holmes\nby', 1),
#  ('Sir', 30),
#  ('Arthur', 16),
#  ('Conan', 3),
#  ('Doyle\n(#15', 1),
#  ('in', 17459),
#  ('our', 848),
#  ('series', 79),
#  ('by', 5597),
#  ('Doyle)\n\nCopyright', 1),
#  ('laws', 141),
#  ('are', 2948),
#  ('changing', 32),
#  ('all', 2951),
#  ('over', 1021),
#  ('the', 61197),
#  ('world.', 36),
#  ('Be', 18),
#  ('sure', 92),
#  ('to', 24888),
#  ('check', 28),
#  ('the\ncopyright', 2),
#  ('for', 5634),
#  ('your', 1021),
#  ('country', 191),
#  ('before', 872),
#  ('downloading', 3),
#  ('or', 4478),
#  ('redistributing\nthis', 2),
#  ('any', 984),
#  ('other', 1088),
#  ('eBook.\n\nThis', 2),
#  ('header', 5),
#  ('should', 1077),
#  ('be', 5192),
#  ('first', 889),
#  ('thing', 186),
#  ('seen', 329),
#  ('when', 1675),
#  ('viewing', 4),
#  ('this', 2547),
#  ('Project\nGutenberg', 8),
#  ('file.', 4),
#  ('', 34449),
#  ('Please', 12),
#  ('do', 1012),
#  ('not', 5464),
#  ('remove', 41),
#  ('it.', 462),
#  ('Do', 73),
#  ('change', 102),
#  ('edit', 3),
#  ('the\nheader', 2),
#  ('without', 741),
#  ('written', 88),
#  ('permission.\n\nPlease', 2),
#  ('read', 157),
#  ('"legal', 2),
#  ('small', 371),
#  ('print,"', 2),
#  ('and', 30996),
#  ('information', 38),
#  ('about', 1162),
#  ('the\neBook', 2),
#  ('at', 5636),
#  ('bottom', 20),
#  ('Included', 2),
#  ('is\nimportant', 4),
#  ('specific', 24),
#  ('rights', 88),
#  ('restrictions', 17),
#  ('in\nhow', 2),
#  ('file', 12),
#  ('may', 2176),
#  ('used.', 9),
#  ('You', 369),
#  ('can', 726),
#  ('also', 578),
#  ('find', 253),
#  ('out', 1526),
#  ('how', 786),
#  ('make', 429),
#  ('a\ndonation', 2),
#  ('Gutenberg,', 2),
#  ('get', 401),
#  ('involved.\n\n\n**Welcome', 2),
#  ('To', 266),
#  ('World', 47),
#  ('Free', 13),
#  ('Plain', 3),
#  ('Vanilla', 6),
#  ('Electronic', 2),
#  ('Texts**\n\n**eBooks', 2),
#  ('Readable', 2),
#  ('By', 139),
#  ('Both', 34),
#  ('Humans', 2),
#  ('Computers,', 2),
#  ('Since', 19),
#  ('1971**\n\n*****These', 2),
#  ('eBooks', 28),
#  ('Were', 8),
#  ('Prepared', 4),
#  ('Thousands', 10),
#  ('Volunteers!*****\n\n\nTitle:', 2),
#  ('Holmes\n\nAuthor:', 1),
#  ('Doyle\n\nRelease', 1),
#  ('Date:', 4),
#  ('March,', 20),
#  ('1999', 3),
#  ('[EBook', 4),
#  ('#1661]\n[Most', 1),
#  ('recently', 22),
#  ('updated:', 2),
#  ('November', 12),
#  ('29,', 5),
#  ('2002]\n\nEdition:', 1),
#  ('12\n\nLanguage:', 1),
#  ('English\n\nCharacter', 4),
#  ('set', 261),
#  ('encoding:', 4),
#  ('ASCII\n\n***', 1),
#  ('START', 4),
#  ('OF', 200),
#  ('THE', 178),
#  ('PROJECT', 23),
#  ('GUTENBERG', 11),
#  ('EBOOK,', 4),
#  ('ADVENTURES', 3),
#  ('SHERLOCK', 4),
#  ('HOLMES', 2),
#  ('***\n\n\n\n\n(Additional', 1),
#  ('editing', 4),
#  ('Jose', 1),
#  ('Menendez)\n\n\n\nTHE', 1),
#  ('OF\nSHERLOCK', 1),
#  ('HOLMES\n\nBY\n\nSIR', 1),
#  ('ARTHUR', 1),
#  ('CONAN', 1),
#  ('DOYLE\n\nCONTENTS\n\nI.\tA', 1),
#  ('Scandal', 2),
#  ('Bohemia\nII.\tThe', 1),
#  ('Red-Headed', 1),
#  ('League\nIII.\tA', 1),
#  ('Case', 1),
#  ('Identity\nIV.\tThe', 1),
#  ('Boscombe', 14),
#  ('Valley', 27),
#  ('Mystery\nV.\tThe', 1),
#  ('Five', 13),
#  ('Orange', 1),
#  ('Pips\nVI.\tThe', 1),
#  ('Man', 3),
#  ('with', 8122),
#  ('Twisted', 1),
#  ('Lip\nVII.\tThe', 1),
#  ('Adventure', 6),
#  ('Blue', 2),
#  ('Carbuncle\nVIII.\tThe', 1),
#  ('Speckled', 1),
#  ('Band\nIX.\tThe', 1),
#  ("Engineer's", 1),
#  ('Thumb\nX.\tThe', 1),
#  ('Noble', 1),
#  ('Bachelor\nXI.\tThe', 1),
#  ('Beryl', 2),
#  ('Coronet\nXII.\tThe', 1),
#  ('Copper', 8),
#  ('Beeches\n\n\nADVENTURE', 1),
#  ('I.', 28),
#  ('A', 537),
#  ('SCANDAL', 1),
#  ('IN', 48),
#  ('BOHEMIA\n\nI.\n\n\nTo', 1),
#  ('Holmes', 173),
#  ('she', 2521),
#  ('is', 8260),
#  ('always', 481),
#  ('woman.', 22),
#  ('I', 5463),
#  ('have', 3030),
#  ('seldom', 62),
#  ('heard', 483),
#  ('him', 2737),
#  ('mention', 27),
#  ('her', 3751),
#  ('under', 744),
#  ('name.', 8),
#  ('In', 1234),
#  ('his', 8220),
#  ('eyes', 499),
#  ('eclipses', 2),
#  ('predominates', 1),
#  ('whole', 585),
#  ('sex.', 2),
#  ('It', 1301),
#  ('was', 9753),
#  ('that', 9842),
#  ('he', 8366),
#  ('felt', 566),
#  ('emotion', 12),
#  ('akin', 12),
#  ('love', 312),
#  ('Irene', 13),
#  ('Adler.', 2),
#  ('All', 222),
#  ('emotions,', 2),
#  ('one', 2379),
#  ('particularly,', 3),
#  ('were', 3547),
#  ('abhorrent', 1),
#  ('cold,', 45),
#  ('precise', 8),
#  ('but', 3654),
#  ('admirably', 6),
#  ('balanced', 3),
#  ('mind.', 31),
#  ('He', 1632),
#  ('was,', 91),
#  ('take', 507),
#  ('it,', 441),
#  ('most', 715),
#  ('perfect', 26),
#  ('reasoning', 18),
#  ('observing', 14),
#  ('machine', 25),
#  ('world', 116),
#  ('has', 1376),
#  ('seen,', 13),
#  ('as', 6592),
#  ('a', 17581),
#  ('lover', 11),
#  ('would', 1651),
#  ('placed', 153),
#  ('himself', 673),
#  ('false', 37),
#  ('position.', 29),
#  ('never', 459),
#  ('spoke', 162),
#  ('softer', 6),
#  ('passions,', 5),
#  ('save', 93),
#  ('gibe', 1),
#  ('sneer.', 2),
#  ('They', 579),
#  ('admirable', 8),
#  ('things', 194),
#  ('observer--excellent', 1),
#  ('drawing', 187),
#  ('veil', 10),
#  ('from', 4664),
#  ("men's", 23),
#  ('motives', 10),
#  ('actions.', 5),
#  ('But', 705),
#  ('trained', 16),
#  ('reasoner', 3),
#  ('admit', 50),
#  ('such', 1146),
#  ('intrusions', 1),
#  ('into', 1833),
#  ('own', 596),
#  ('delicate', 35),
#  ('finely', 8),
#  ('adjusted', 14),
#  ('temperament', 2),
#  ('introduce', 18),
#  ('distracting', 1),
#  ('factor', 31),
#  ('which', 3898),
#  ('might', 444),
#  ('throw', 39),
#  ('doubt', 105),
#  ('upon', 999),
#  ('mental', 28),
#  ('results.', 17),
#  ('Grit', 1),
#  ('sensitive', 18),
#  ('instrument,', 2),
#  ('crack', 10),
#  ('high-power', 1),
#  ('lenses,', 1),
#  ('more', 1500),
#  ('disturbing', 8),
#  ('than', 1031),
#  ('strong', 116),
#  ('nature', 113),
#  ('his.', 5),
#  ('And', 669),
#  ('yet', 339),
#  ('there', 1621),
#  ('woman', 139),
#  ('him,', 677),
#  ('late', 85),
#  ('Adler,', 5),
#  ('dubious', 1),
#  ('questionable', 2),
#  ('memory.\n\nI', 1),
#  ('had', 6325),
#  ('little', 804),
#  ('lately.', 5),
#  ('My', 92),
#  ('marriage', 49),
#  ('drifted', 5),
#  ('us', 426),
#  ('away', 472),
#  ('each', 306),
#  ('other.', 38),
#  ('complete', 81),
#  ('happiness,', 15),
#  ('home-centred', 1),
#  ('interests', 57),
#  ('rise', 172),
#  ('up', 1736),
#  ('around', 175),
#  ('man', 965),
#  ('who', 2371),
#  ('finds', 19),
#  ('master', 44),
#  ('establishment,', 1),
#  ('sufficient', 54),
#  ('absorb', 2),
#  ('my', 1868),
#  ('attention,', 12),
#  ('while', 497),
#  ('Holmes,', 123),
#  ('loathed', 1),
#  ('every', 474),
#  ('form', 382),
#  ('society', 68),
#  ('Bohemian', 6),
#  ('soul,', 13),
#  ('remained', 171),
#  ('lodgings', 8),
#  ('Baker', 34),
#  ('Street,', 23),
#  ('buried', 17),
#  ('among', 330),
#  ('old', 888),
#  ('books,', 12),
#  ('alternating', 2),
#  ('week', 54),
#  ('between', 512),
#  ('cocaine', 4),
#  ('ambition,', 2),
#  ('drowsiness', 2),
#  ('drug,', 5),
#  ('fierce', 10),
#  ('energy', 23),
#  ('keen', 22),
#  ('nature.', 10),
#  ('still,', 17),
#  ('ever,', 13),
#  ('deeply', 50),
#  ('attracted', 26),
#  ('study', 75),
#  ('crime,', 7),
#  ('occupied', 88),
#  ('immense', 59),
#  ('faculties', 7),
#  ('extraordinary', 49),
#  ('powers', 97),
#  ('observation', 22),
#  ('following', 149),
#  ('those', 921),
#  ('clues,', 1),
#  ('clearing', 20),
#  ('mysteries', 4),
#  ('been', 2187),
#  ('abandoned', 42),
#  ('hopeless', 11),
#  ('official', 64),
#  ('police.', 8),
#  ('From', 147),
#  ('time', 942),
#  ('some', 1200),
#  ('vague', 32),
#  ('account', 114),
#  ('doings:', 1),
#  ('summons', 7),
#  ('Odessa', 1),
#  ('case', 275),
#  ('Trepoff', 1),
#  ('murder,', 4),
#  ('singular', 34),
#  ('tragedy', 4),
#  ('Atkinson', 1),
#  ('brothers', 7),
#  ('Trincomalee,', 1),
#  ('finally', 87),
#  ('mission', 18),
#  ('accomplished', 19),
#  ('so', 2082),
#  ('delicately', 3),
#  ('successfully', 12),
#  ('reigning', 3),
#  ('family', 100),
#  ('Holland.', 1),
#  ('Beyond', 13),
#  ('these', 791),
#  ('signs', 77),
#  ('activity,', 16),
#  ('however,', 286),
#  ('merely', 158),
#  ('shared', 18),
#  ('readers', 4),
#  ('daily', 30),
#  ('press,', 13),
#  ('knew', 410),
#  ('former', 129),
#  ('friend', 115),
#  ('companion.\n\nOne', 1),
#  ('night--it', 2),
#  ('on', 5082),
#  ('twentieth', 14),
#  ('1888--I', 1),
#  ('returning', 57),
#  ('journey', 31),
#  ('patient', 244),
#  ('(for', 10),
#  ('now', 939),
#  ('returned', 150),
#  ('civil', 64),
#  ('practice),', 1),
#  ('way', 547),
#  ('led', 181),
#  ('me', 1015),
#  ('through', 660),
#  ('Street.', 12),
#  ('As', 356),
#  ('passed', 288),
#  ('well-remembered', 1),
#  ('door,', 76),
#  ('must', 842),
#  ('associated', 147),
#  ('mind', 187),
#  ('wooing,', 1),
#  ('dark', 113),
#  ('incidents', 8),
#  ('Study', 4),
#  ('Scarlet,', 3),
#  ('seized', 95),
#  ('desire', 73),
#  ('see', 741),
#  ('again,', 92),
#  ('know', 686),
#  ('employing', 4),
#  ('powers.', 8),
#  ('His', 304),
#  ('rooms', 43),
#  ('brilliantly', 3),
#  ('lit,', 3),
#  ('and,', 491),
#  ('even', 697),
#  ('looked', 658),
#  ('up,', 159),
#  ('saw', 528),
#  ('tall,', 24),
#  ('spare', 20),
#  ('figure', 68),
#  ('pass', 101),
#  ('twice', 53),
#  ('silhouette', 1),
#  ('against', 525),
#  ('blind.', 3),
#  ('pacing', 22),
#  ('room', 393),
#  ('swiftly,', 4),
#  ('eagerly,', 4),
#  ('head', 415),
#  ('sunk', 21),
#  ('chest', 44),
#  ('hands', 234),
#  ('clasped', 11),
#  ('behind', 279),
#  ('him.', 508),
#  ('me,', 241),
#  ('mood', 35),
#  ('habit,', 11),
#  ('attitude', 41),
#  ('manner', 75),
#  ('told', 414),
#  ('their', 2328),
#  ('story.', 12),
#  ('work', 221),
#  ('again.', 51),
#  ('risen', 23),
#  ('drug-created', 1),
#  ('dreams', 11),
#  ('hot', 63),
#  ('scent', 10),
#  ('new', 586),
#  ('problem.', 5),
#  ('rang', 24),
#  ('bell', 25),
#  ('shown', 94),
#  ('chamber', 19),
#  ('formerly', 42),
#  ('part', 518),
#  ('own.\n\nHis', 1),
#  ('effusive.', 1),
#  ('was;', 2),
#  ('glad,', 9),
#  ('think,', 56),
#  ('me.', 142),
#  ('With', 137),
#  ('hardly', 144),
#  ('word', 193),
#  ('spoken,', 4),
#  ('kindly', 47),
#  ('eye,', 11),
#  ('waved', 28),
#  ('an', 2803),
#  ('armchair,', 14),
#  ('threw', 87),
#  ('across', 180),
#  ('cigars,', 3),
#  ('indicated', 49),
#  ('spirit', 100),
#  ('gasogene', 1),
#  ('corner.', 9),
#  ('Then', 217),
#  ('stood', 314),
#  ('fire', 131),
#  ('introspective', 2),
#  ('fashion.\n\n"Wedlock', 1),
#  ('suits', 8),
#  ('you,"', 90),
#  ('remarked.', 14),
#  ('"I', 412),
#  ('Watson,', 40),
#  ('you', 3316),
#  ('put', 380),
#  ('seven', 87),
#  ('half', 203),
#  ('pounds', 14),
#  ('since', 187),
#  ('you."\n\n"Seven!"', 1),
#  ('answered.\n\n"Indeed,', 1),
#  ('thought', 616),
#  ('more.', 42),
#  ('Just', 54),
#  ('trifle', 7),
#  ('more,', 44),
#  ('fancy,', 6),
#  ('Watson.', 10),
#  ('practice', 60),
#  ('observe.', 3),
#  ('did', 1604),
#  ('tell', 396),
#  ('intended', 45),
#  ('go', 581),
#  ('harness."\n\n"Then,', 1),
#  ('know?"\n\n"I', 2),
#  ('deduce', 13),
#  ('How', 183),
#  ('getting', 72),
#  ('yourself', 83),
#  ('very', 1112),
#  ('wet', 39),
#  ('lately,', 5),
#  ('clumsy', 4),
#  ('careless', 9),
#  ('servant', 30),
#  ('girl?"\n\n"My', 1),
#  ('dear', 259),
#  ('Holmes,"', 11),
#  ('said', 2682),
#  ('I,', 68),
#  ('"this', 10),
#  ('too', 315),
#  ('much.', 17),
#  ('certainly', 79),
#  ('burned,', 10),
#  ('lived', 89),
#  ('few', 381),
#  ('centuries', 11),
#  ('ago.', 19),
#  ('true', 107),
#  ('walk', 47),
#  ('Thursday', 2),
#  ('came', 856),
#  ('home', 159),
#  ('dreadful', 44),
#  ('mess,', 1),
#  ('changed', 95),
#  ('clothes', 31),
#  ("can't", 159),
#  ('imagine', 60),
#  ('Mary', 372),
#  ('Jane,', 1),
#  ('incorrigible,', 1),
#  ('wife', 161),
#  ('given', 282),
#  ('notice,', 7),
#  ('there,', 110),
#  ('fail', 24),
#  ('it', 5882),
#  ('out."\n\nHe', 3),
#  ('chuckled', 6),
#  ('rubbed', 28),
#  ('long,', 41),
#  ('nervous', 36),
#  ('together.\n\n"It', 1),
#  ('simplicity', 11),
#  ('itself,"', 2),
#  ('he;', 11),
#  ('"my', 14),
#  ('inside', 28),
#  ('left', 621),
#  ('shoe,', 2),
#  ('just', 557),
#  ('where', 695),
#  ('firelight', 2),
#  ('strikes', 10),
#  ('leather', 18),
#  ('scored', 3),
#  ('six', 117),
#  ('almost', 240),
#  ('parallel', 12),
#  ('cuts.', 1),
#  ('Obviously', 3),
#  ('they', 2547),
#  ('caused', 86),
#  ('someone', 98),
#  ('carelessly', 6),
#  ('scraped', 11),
#  ('round', 390),
#  ('edges', 47),
#  ('sole', 49),
#  ('order', 249),
#  ('crusted', 2),
#  ('mud', 13),
#  ('Hence,', 2),
#  ('see,', 65),
#  ('double', 34),
#  ('deduction', 8),
#  ('vile', 8),
#  ('weather,', 6),
#  ('particularly', 118),
#  ('malignant', 44),
#  ('boot-slitting', 1),
#  ('specimen', 7),
#  ('London', 33),
#  ('slavey.', 1),
#  ('practice,', 7),
#  ('if', 1461),
#  ('gentleman', 49),
#  ('walks', 7),
#  ('smelling', 2),
#  ('iodoform,', 2),
#  ('black', 144),
#  ('mark', 22),
#  ('nitrate', 7),
#  ('silver', 75),
#  ('right', 396),
#  ('forefinger,', 3),
#  ('bulge', 2),
#  ('side', 323),
#  ('top-hat', 3),
#  ('show', 165),
#  ('secreted', 2),
#  ('stethoscope,', 1),
#  ('dull,', 14),
#  ('indeed,', 21),
#  ('pronounce', 7),
#  ('active', 57),
#  ('member', 38),
#  ('medical', 17),
#  ('profession."\n\nI', 1),
#  ('could', 1470),
#  ('help', 171),
#  ('laughing', 50),
#  ('ease', 18),
#  ('explained', 46),
#  ('process', 160),
#  ('deduction.', 1),
#  ('"When', 12),
#  ('hear', 148),
#  ('give', 402),
#  ('reasons,"', 1),
#  ('remarked,', 23),
#  ('"the', 142),
#  ('appears', 84),
#  ('ridiculously', 1),
#  ('simple', 82),
#  ('easily', 76),
#  ('myself,', 23),
#  ('though', 390),
#  ('successive', 11),
#  ('instance', 13),
#  ('am', 652),
#  ('baffled', 5),
#  ('until', 265),
#  ('explain', 73),
#  ('process.', 9),
#  ('believe', 139),
#  ('good', 402),
#  ('yours."\n\n"Quite', 1),
#  ('so,"', 19),
#  ('answered,', 15),
#  ('lighting', 12),
#  ('cigarette,', 1),
#  ('throwing', 36),
#  ('down', 834),
#  ('armchair.', 3),
#  ('"You', 110),
#  ('distinction', 13),
#  ('clear.', 8),
#  ('For', 173),
#  ('example,', 163),
#  ('frequently', 153),
#  ('steps', 125),
#  ('lead', 102),
#  ('hall', 38),
#  ('room."\n\n"Frequently."\n\n"How', 1),
#  ('often?"\n\n"Well,', 1),
#  ('hundreds', 35),
#  ('times."\n\n"Then', 1),
#  ('many', 453),
#  ('there?"\n\n"How', 1),
#  ('many?', 1),
#  ("don't", 374),
#  ('know."\n\n"Quite', 1),
#  ('so!', 6),
#  ('observed.', 8),
#  ('seen.', 25),
#  ('That', 189),
#  ('point.', 18),
#  ('Now,', 33),
#  ('seventeen', 7),
#  ('steps,', 17),
#  ('because', 469),
#  ('both', 382),
#  ('way,', 102),
#  ('interested', 42),
#  ('problems,', 7),
#  ('enough', 110),
#  ('chronicle', 4),
#  ('two', 802),
#  ('trifling', 8),
#  ('experiences,', 1),
#  ('this."', 4),
#  ('sheet', 23),
#  ('thick,', 9),
#  ('pink-tinted', 1),
#  ('notepaper', 1),
#  ('lying', 91),
#  ('open', 203),
#  ('table.', 40),
#  ('"It', 93),
#  ('last', 424),
#  ('post,"', 1),
#  ('he.', 105),
#  ('"Read', 1),
#  ('aloud."\n\nThe', 1),
#  ('note', 62),
#  ('undated,', 1),
#  ('either', 218),
#  ('signature', 7),
#  ('address.\n\n"There', 1),
#  ('will', 1258),
#  ('call', 153),
#  ('to-night,', 5),
#  ('quarter', 32),
#  ('eight', 70),
#  ('o\'clock,"', 2),
#  ('said,', 258),
#  ('"a', 44),
#  ('desires', 11),
#  ('consult', 15),
#  ('matter', 205),
#  ('deepest', 14),
#  ('moment.', 33),
#  ('Your', 74),
#  ('recent', 40),
#  ('services', 19),
#  ('royal', 68),
#  ('houses', 46),
#  ('Europe', 64),
#  ('safely', 9),
#  ('trusted', 12),
#  ('matters', 68),
#  ('importance', 59),
#  ('exaggerated.', 2),
#  ('This', 448),
#  ('we', 1201),
#  ('quarters', 35),
#  ('received.', 5),
#  ('then', 738),
#  ('hour,', 18),
#  ('amiss', 4),
#  ('visitor', 33),
#  ('wear', 23),
#  ('mask."\n\n"This', 1),
#  ('indeed', 36),
#  ('mystery,"', 2),
#  ('"What', 88),
#  ('means?"\n\n"I', 1),
#  ('no', 1557),
#  ('data', 4),
#  ('yet.', 10),
#  ('capital', 83),
#  ('mistake', 22),
#  ('theorise', 1),
#  ('data.', 4),
#  ('Insensibly', 1),
#  ('begins', 33),
#  ('twist', 10),
#  ('facts', 46),
#  ('suit', 21),
#  ('theories,', 2),
#  ('instead', 97),
#  ('theories', 10),
#  ('facts.', 5),
#  ('itself.', 22),
#  ('What', 412),
#  ('it?"\n\nI', 1),
#  ('carefully', 50),
#  ('examined', 37),
#  ('writing,', 7),
#  ('paper', 108),
#  ('written.\n\n"The', 1),
#  ('wrote', 116),
#  ('presumably', 6),
#  ('well', 381),
#  ('do,"', 12),
#  ('endeavouring', 8),
#  ('imitate', 4),
#  ("companion's", 6),
#  ('processes.', 3),
#  ('"Such', 5),
#  ('bought', 43),
#  ('crown', 23),
#  ('packet.', 2),
#  ('peculiarly', 9),
#  ('stiff."\n\n"Peculiar--that', 1),
#  ('word,"', 3),
#  ('Holmes.', 53),
#  ('English', 137),
#  ('all.', 72),
#  ('Hold', 1),
#  ('light."\n\nI', 1),
#  ('so,', 76),
#  ('large', 369),
#  ('"E"', 1),
#  ('"g,"', 1),
#  ('"P,"', 1),
#  ('"G"', 1),
#  ('"t"', 1),
#  ('woven', 4),
#  ('texture', 4),
#  ('paper.\n\n"What', 1),
#  ('that?"', 25),
#  ('asked', 548),
#  ('Holmes.\n\n"The', 1),
#  ('name', 163),
#  ('maker,', 1),
#  ('doubt;', 1),
#  ('monogram,', 1),
#  ('rather."\n\n"Not', 1),
#  ("'G'", 1),
#  ("'t'", 1),
#  ('stands', 17),
#  ("'Gesellschaft,'", 1),
#  ('German', 108),
#  ("'Company.'", 1),
#  ('customary', 16),
#  ('contraction', 33),
#  ('like', 824),
#  ("'Co.'", 1),
#  ("'P,'", 1),
#  ('course,', 56),
#  ("'Papier.'", 1),
#  ('Now', 96),
#  ("'Eg.'", 1),
#  ('Let', 61),
#  ('glance', 64),
#  ('Continental', 20),
#  ('Gazetteer."', 1),
#  ('took', 499),
#  ('heavy', 98),
#  ('brown', 35),
#  ('volume', 18),
#  ('shelves.', 1),
#  ('"Eglow,', 1),
#  ('Eglonitz--here', 1),
#  ('are,', 49),
#  ('Egria.', 1),
#  ('German-speaking', 1),
#  ('country--in', 1),
#  ('Bohemia,', 5),
#  ('far', 290),
#  ('Carlsbad.', 1),
#  ("'Remarkable", 1),
#  ('being', 737),
#  ('scene', 33),
#  ('death', 146),
#  ('Wallenstein,', 1),
#  ('its', 1323),
#  ('numerous', 35),
#  ('glass-factories', 1),
#  ("paper-mills.'", 1),
#  ('Ha,', 8),
#  ('ha,', 10),
#  ('boy,', 31),
#  ('what', 1786),
#  ('sparkled,', 1),
#  ('sent', 256),
#  ('great', 505),
#  ('blue', 83),
#  ('triumphant', 10),
#  ('cloud', 20),
#  ('cigarette.\n\n"The', 1),
#  ('made', 833),
#  ('Bohemia,"', 1),
#  ('said.\n\n"Precisely.', 1),
#  ('German.', 5),
#  ('peculiar', 67),
#  ('construction', 15),
#  ("sentence--'This", 1),
#  ("received.'", 1),
#  ('Frenchman', 53),
#  ('Russian', 329),
#  ('that.', 48),
#  ('uncourteous', 1),
#  ('verbs.', 1),
#  ('only', 1445),
#  ('remains,', 5),
#  ('therefore,', 39),
#  ('discover', 24),
#  ('wanted', 159),
#  ('writes', 12),
#  ('prefers', 1),
#  ('wearing', 68),
#  ('mask', 7),
#  ('showing', 77),
#  ('face.', 68),
#  ('here', 265),
#  ('comes,', 3),
#  ('mistaken,', 6),
#  ('resolve', 11),
#  ('doubts."\n\nAs', 2),
#  ('sharp', 58),
#  ('sound', 157),
#  ("horses'", 11),
#  ('hoofs', 14),
#  ('grating', 7),
#  ('wheels', 29),
#  ('curb,', 1),
#  ('followed', 254),
#  ('pull', 13),
#  ('bell.', 5),
#  ('whistled.\n\n"A', 1),
#  ('pair,', 1),
#  ('sound,"', 1),
#  ('"Yes,"', 3),
#  ('continued,', 41),
#  ('glancing', 81),
#  ('window.', 17),
#  ('"A', 24),
#  ('nice', 29),
#  ('brougham', 3),
#  ('pair', 35),
#  ('beauties.', 1),
#  ('hundred', 174),
#  ('fifty', 45),
#  ('guineas', 2),
#  ('apiece.', 4),
#  ("There's", 17),
#  ('money', 180),
#  ('case,', 47),
#  ('nothing', 384),
#  ('else."\n\n"I', 3),
#  ('think', 408),
#  ('better', 186),
#  ('go,', 51),
#  ('Holmes."\n\n"Not', 2),
#  ('bit,', 15),
#  ('Doctor.', 1),
#  ('Stay', 1),
#  ('are.', 16),
#  ('lost', 133),
#  ('Boswell.', 1),
#  ('promises', 13),
#  ('interesting.', 7),
#  ('pity', 47),
#  ('miss', 13),
#  ('it."\n\n"But', 5),
#  ('client--"\n\n"Never', 1),
#  ('want', 249),
#  ('help,', 11),
#  ('Here', 48),
#  ...]

# %%
words = txt.split(" ")

# %%
#  Q: Find analgrams in the text=open('/cxldata/big.txt').read()
# 'cat', tac, act
# Use Dictionary or whatever you want
# Expected Output: {'act': {'cat':1,'act':10}}
# key = ''.join(sorted("cat")), key is basicall the sorted letters

# %%
def find_anagrams_2(text):
    dictionary = {}
    
    word_list = text.split(" ")
    for w in word_list:
        w = w.lower()
        sorted_w = "".join(sorted(w))
        if sorted_w in dictionary:
            
            word_dict = dictionary[sorted_w]
            
            if w in word_dict:
                count_w = word_dict[w]
                word_dict[w] = count_w + 1
            else:
                word_dict[w] = 1
            
        else:
            dictionary[sorted_w] = {w:1}
            
    return dictionary

# %%
txt = "listen silent enlist inlets hello world world enlist enlist"
find_anagrams_2(txt)
# Out:
# {'eilnst': {'listen': 1, 'silent': 1, 'enlist': 3, 'inlets': 1},
#  'ehllo': {'hello': 1},
#  'dlorw': {'world': 2}}

# %%
txt = open('/cxldata/big.txt').read()
find_anagrams_2(txt)
# Out:
# {'eht': {'the': 65168},
#  'cejoprt': {'project': 201},
#  'beeggnrtu': {'gutenberg': 76},
#  'bekoo': {'ebook': 53},
#  'fo': {'of': 35009},
#  'adeenrstuv': {'adventures': 12},
#  'cehklors': {'sherlock': 73},
#  '\nbehlmosy': {'holmes\nby': 1},
#  'irs': {'sir': 31, 'irs': 1},
#  'ahrrtu': {'arthur': 18},
#  'acnno': {'conan': 4, 'canon': 1},
#  '\n#(15deloy': {'doyle\n(#15': 1},
#  'in': {'in': 18741, 'ni': 2},
#  'oru': {'our': 895},
#  'eeirss': {'series': 79},
#  'by': {'by': 5745},
#  '\n\n)cdeghilooprtyy': {'doyle)\n\ncopyright': 1},
#  'alsw': {'laws': 144},
#  'aer': {'are': 2976, 'ear': 15, 'era': 5},
#  'acgghinn': {'changing': 33},
#  'all': {'all': 3173},
#  'eorv': {'over': 1025},
#  '.dlorw': {'world.': 42},
#  'be': {'be': 5212},
#  'ersu': {'sure': 92, 'ruse': 3, 'user': 5},
#  'ot': {'to': 25176},
#  'ccehk': {'check': 28},
#  '\nceghhioprtty': {'the\ncopyright': 2},
#  'for': {'for': 5824, 'fro': 10},
#  'oruy': {'your': 1095},
#  'cnortuy': {'country': 195},
#  'beefor': {'before': 915},
#  'addgilnnoow': {'downloading': 3},
#  'or': {'or': 4516},
#  '\nbdeghiiiinrrsstttu': {'redistributing\nthis': 2},
#  'any': {'any': 1020},
#  'ehort': {'other': 1111},
#  '\n\n.behikoost': {'ebook.\n\nthis': 2},
#  'adeehr': {'header': 5, 'adhere': 4},
#  'dhlosu': {'should': 1089},
#  'first': {'first': 914, 'rifts': 1},
#  'ghint': {'thing': 186, 'night': 160},
#  'eens': {'seen': 329},
#  'ehnw': {'when': 2148, 'hewn': 1},
#  'egiinvw': {'viewing': 5},
#  'hist': {'this': 3007, 'hits': 1},
#  '\nbceeeggjnoprrttu': {'project\ngutenberg': 8},
#  '.efil': {'file.': 4, 'life.': 85},
#  '': {'': 34449},
#  'aeelps': {'please': 63, 'elapse': 5, 'asleep': 29},
#  'do': {'do': 1085},
#  'not': {'not': 5543, 'ton': 4, 'ont': 1},
#  'eemorv': {'remove': 41},
#  '.it': {'it.': 462},
#  'aceghn': {'change': 104},
#  'deit': {'edit': 3, 'tide': 26, 'tied': 32, 'diet': 7},
#  '\nadeeehhrt': {'the\nheader': 2},
#  'hiottuw': {'without': 764},
#  'einrttw': {'written': 89},
#  '\n\n.aeeeiilmnopprsss': {'permission.\n\nplease': 2},
#  'ader': {'read': 166, 'dear': 267, 'dare': 39},
#  '"aegll': {'"legal': 2},
#  'allms': {'small': 385},
#  '",inprt': {'print,"': 2},
#  'adn': {'and': 31776, 'dan': 2},
#  'afiimnnoort': {'information': 46},
#  'abotu': {'about': 1182},
#  '\nbeehkoot': {'the\nebook': 2},
#  'at': {'at': 5913, 'ta': 1},
#  'bmoott': {'bottom': 20},
#  'cddeilnu': {'included': 29},
#  '\naiimnoprstt': {'is\nimportant': 4},
#  'ccefiips': {'specific': 24},
#  'ghirst': {'rights': 96, 'girths': 1},
#  'ceiinorrsstt': {'restrictions': 17},
#  '\nhinow': {'in\nhow': 2},
#  'efil': {'file': 12, 'life': 426},
#  'amy': {'may': 2211, 'amy': 1},
#  '.desu': {'used.': 9, 'dues.': 1},
#  'ouy': {'you': 3711},
#  'acn': {'can': 753},
#  'alos': {'also': 581},
#  'dfin': {'find': 254},
#  'otu': {'out': 1537},
#  'how': {'how': 969, 'who': 2414},
#  'aekm': {'make': 432},
#  '\naadinnoot': {'a\ndonation': 2},
#  ',beeggnrtu': {'gutenberg,': 2},
#  'egt': {'get': 411},
#  '\n\n\n**.cdeeeillmnoovvw': {'involved.\n\n\n**welcome': 2},
#  'dlorw': {'world': 173},
#  'eefr': {'free': 290, 'reef': 1},
#  'ailnp': {'plain': 65},
#  'aaillnv': {'vanilla': 6},
#  'cceeilnort': {'electronic': 41},
#  '\n\n****beekoossttx': {'texts**\n\n**ebooks': 2},
#  'aabdeelr': {'readable': 9},
#  'bhot': {'both': 416},
#  'ahmnsu': {'humans': 2},
#  ',cemoprstu': {'computers,': 2},
#  'ceins': {'since': 206},
#  '\n\n*******1179eehst': {'1971**\n\n*****these': 2},
#  'bekoos': {'ebooks': 28},
#  'eerw': {'were': 3555},
#  'adeepprr': {'prepared': 105},
#  'adhnosstu': {'thousands': 68},
#  '\n\n\n!*****:eeeillnorstttuv': {'volunteers!*****\n\n\ntitle:': 2},
#  '\n\n:aehhlmoorstu': {'holmes\n\nauthor:': 1},
#  '\n\nadeeeellorsy': {'doyle\n\nrelease': 1},
#  ':adet': {'date:': 4},
#  ',achmr': {'march,': 35, 'charm,': 1},
#  '1999': {'1999': 3},
#  '[bekoo': {'[ebook': 4},
#  '\n#1166[]most': {'#1661]\n[most': 1},
#  'ceelnrty': {'recently': 23},
#  ':addeptu': {'updated:': 2},
#  'beemnorv': {'november': 13},
#  ',29': {'29,': 5, '92,': 3},
#  '\n\n0022:]deiinot': {'2002]\n\nedition:': 1},
#  '\n\n12:aaegglnu': {'12\n\nlanguage:': 1},
#  '\n\naacceeghhilnrrst': {'english\n\ncharacter': 4},
#  'est': {'set': 264, 'est': 11},
#  ':cdeginno': {'encoding:': 4},
#  '\n\n***aciis': {'ascii\n\n***': 1},
#  'arstt': {'start': 42},
#  ',bekoo': {'ebook,': 12},
#  'ehlmos': {'holmes': 176},
#  '\n\n\n\n\n(***aaddiilnot': {'***\n\n\n\n\n(additional': 1},
#  'degiint': {'editing': 4},
#  'ejos': {'jose': 1},
#  '\n\n\n\n)deeeehmnntz': {'menendez)\n\n\n\nthe': 1},
#  '\ncefhkloors': {'of\nsherlock': 1},
#  '\n\n\n\nbehilmorssy': {'holmes\n\nby\n\nsir': 1},
#  '\t\n\n\n\n.acdeeilnnoostty': {'doyle\n\ncontents\n\ni.\ta': 1},
#  'aacdlns': {'scandal': 12},
#  '\t\n.abeehhiiimot': {'bohemia\nii.\tthe': 1},
#  '-adddeeehr': {'red-headed': 19},
#  '\t\n.aaeegiiilu': {'league\niii.\ta': 1},
#  'aces': {'case': 277},
#  '\t\n.deehiiintttvy': {'identity\niv.\tthe': 1},
#  'bbcemoos': {'boscombe': 15},
#  'aellvy': {'valley': 40},
#  '\t\n.eehmrsttvyy': {'mystery\nv.\tthe': 1},
#  'efiv': {'five': 182},
#  'aegnor': {'orange': 14},
#  '\t\n.ehiippstv': {'pips\nvi.\tthe': 1},
#  'amn': {'man': 969},
#  'hitw': {'with': 8268, 'whit': 3},
#  'deisttw': {'twisted': 16},
#  '\t\n.ehiiilptv': {'lip\nvii.\tthe': 1},
#  'adeenrtuv': {'adventure': 19},
#  'belu': {'blue': 86},
#  '\t\n.abcceehiiilnrtuv': {'carbuncle\nviii.\tthe': 1},
#  'cdeeklps': {'speckled': 5},
#  '\t\n.abdehintx': {'band\nix.\tthe': 1},
#  "'eeeginnrs": {"engineer's": 2},
#  '\t\n.behhmttux': {'thumb\nx.\tthe': 1},
#  'belno': {'noble': 33},
#  '\t\n.abceehhilortx': {'bachelor\nxi.\tthe': 1},
#  'belry': {'beryl': 3},
#  '\t\n.ceehiinoorttx': {'coronet\nxii.\tthe': 1},
#  'ceoppr': {'copper': 16},
#  '\n\n\nabcdeeeeehnrstuv': {'beeches\n\n\nadventure': 1},
#  '.i': {'i.': 28},
#  'a': {'a': 18118},
#  '\n\n\n\n\n.abehiimoot': {'bohemia\n\ni.\n\n\nto': 1},
#  'ehs': {'she': 3140},
#  'is': {'is': 8314, 'si': 2},
#  'aalswy': {'always': 483},
#  '.amnow': {'woman.': 22},
#  'i': {'i': 5466},
#  'aehv': {'have': 3066},
#  'delmos': {'seldom': 64},
#  'adehr': {'heard': 483},
#  'him': {'him': 2746},
#  'eimnnot': {'mention': 28},
#  'ehr': {'her': 3818},
#  'denru': {'under': 787},
#  '.aemn': {'name.': 8, 'mean.': 2},
#  'his': {'his': 8528},
#  'eesy': {'eyes': 499},
#  'ceeilpss': {'eclipses': 2},
#  'adeeimnoprst': {'predominates': 1},
#  'ehlow': {'whole': 587},
#  '.esx': {'sex.': 2},
#  'it': {'it': 7185, 'ti': 1},
#  'asw': {'was': 9780, 'saw': 529},
#  'ahtt': {'that': 10035},
#  'eh': {'he': 9998, 'eh': 1},
#  'eflt': {'felt': 566, 'left': 627},
#  'eimnoot': {'emotion': 12},
#  'aikn': {'akin': 12},
#  'elov': {'love': 316},
#  'eeinr': {'irene': 14},
#  '.adelr': {'adler.': 2},
#  ',eimnoost': {'emotions,': 2},
#  'eno': {'one': 2532},
#  ',aacillprrtuy': {'particularly,': 3},
#  'abehnorrt': {'abhorrent': 1},
#  ',cdlo': {'cold,': 45},
#  'ceeiprs': {'precise': 8},
#  'btu': {'but': 4365, 'tub': 4},
#  'aabdilmry': {'admirably': 6},
#  'aabcdeln': {'balanced': 3},
#  '.dimn': {'mind.': 31},
#  ',asw': {'was,': 91, 'saw,': 11},
#  'aekt': {'take': 517, 'kate': 2},
#  ',it': {'it,': 441},
#  'most': {'most': 735},
#  'ceefprt': {'perfect': 26, 'prefect': 1},
#  'aeginnors': {'reasoning': 18},
#  'beginorsv': {'observing': 14},
#  'acehimn': {'machine': 25},
#  'ahs': {'has': 1385, 'ash': 2},
#  ',eens': {'seen,': 13},
#  'as': {'as': 6950, 'sa': 2},
#  'elorv': {'lover': 11},
#  'dlouw': {'would': 1661},
#  'acdelp': {'placed': 153},
#  'efhilms': {'himself': 673},
#  'aefls': {'false': 37, 'fleas': 1},
#  '.iinoopst': {'position.': 29},
#  'eenrv': {'never': 470, 'nerve': 137},
#  'ekops': {'spoke': 162},
#  'eforst': {'softer': 6, 'foster': 3, 'forest': 42},
#  ',ainopsss': {'passions,': 5},
#  'aesv': {'save': 94, 'vase': 1},
#  'begi': {'gibe': 1},
#  '.eenrs': {'sneer.': 2},
#  'ehty': {'they': 3126},
#  'aabdeilmr': {'admirable': 8},
#  'ghinst': {'things': 195, 'nights': 14},
#  '--bceeeeellnorrstvx': {'observer--excellent': 1},
#  'adginrw': {'drawing': 190, 'warding': 1},
#  'eilv': {'veil': 10, 'vile': 8, 'evil': 36, 'live': 87, 'levi': 1},
#  'fmor': {'from': 4813, 'form': 383},
#  "'emns": {"men's": 23},
#  'eimostv': {'motives': 10},
#  '.acinost': {'actions.': 5},
#  'adeinrt': {'trained': 16},
#  'aeenorrs': {'reasoner': 3},
#  'adimt': {'admit': 50},
#  'chsu': {'such': 1204},
#  'iinnorsstu': {'intrusions': 1},
#  'inot': {'into': 1839},
#  'now': {'own': 599, 'now': 1035, 'won': 28},
#  'acdeeilt': {'delicate': 36},
#  'efilny': {'finely': 8},
#  'addejstu': {'adjusted': 14},
#  'aeeemmnprtt': {'temperament': 2},
#  'cdeinortu': {'introduce': 18, 'reduction': 17},
#  'acdgiinrstt': {'distracting': 1},
#  'acfort': {'factor': 31},
#  'chhiw': {'which': 3903},
#  'ghimt': {'might': 449},
#  'hortw': {'throw': 40, 'worth': 49},
#  'bdotu': {'doubt': 105},
#  'nopu': {'upon': 1002},
#  'aelmnt': {'mental': 28, 'lament': 3, 'mantle': 4},
#  '.elrsstu': {'results.': 17, 'sutlers.': 1},
#  'girt': {'grit': 1, 'girt': 2},
#  'eeiinsstv': {'sensitive': 18},
#  ',eimnnrsttu': {'instrument,': 2},
#  'acckr': {'crack': 10},
#  '-eghhioprw': {'high-power': 1},
#  ',eelnss': {'lenses,': 1},
#  'emor': {'more': 1527, 'rome': 2},
#  'bdgiinrstu': {'disturbing': 8},
#  'ahnt': {'than': 1031},
#  'gnorst': {'strong': 119},
#  'aenrtu': {'nature': 114},
#  '.his': {'his.': 5},
#  'ety': {'yet': 378, 'ety': 1},
#  'eehrt': {'there': 2001, 'three': 418, 'ether': 6},
#  'amnow': {'woman': 146},
#  ',him': {'him,': 682},
#  'aelt': {'late': 86, 'tale': 10, 'alte': 1},
#  ',adelr': {'adler,': 5},
#  'bdiosuu': {'dubious': 1},
#  'abeeilnoqstu': {'questionable': 2},
#  '\n\n.eimmory': {'memory.\n\ni': 1},
#  'adh': {'had': 6358},
#  'eilltt': {'little': 818},
#  '.aellty': {'lately.': 5},
#  'my': {'my': 1960},
#  'aaegimrr': {'marriage': 50},
#  'ddefirt': {'drifted': 5},
#  'su': {'us': 428},
#  'aawy': {'away': 474},
#  'aceh': {'each': 329, 'ache': 1},
#  '.ehort': {'other.': 38},
#  'ceelmopt': {'complete': 84},
#  ',aehinppss': {'happiness,': 15},
#  '-cdeeehmnort': {'home-centred': 1},
#  'eeinrsstt': {'interests': 60},
#  'eirs': {'rise': 193, 'sire': 1},
#  'pu': {'up': 1738},
#  'adnoru': {'around': 181},
#  'dfins': {'finds': 19},
#  'aemrst': {'master': 52, 'stream': 29},
#  ',abeehilmnsstt': {'establishment,': 1},
#  'ceffiinstu': {'sufficient': 54},
#  'abbors': {'absorb': 2},
#  ',aeinnottt': {'attention,': 12},
#  'ehilw': {'while': 565},
#  ',ehlmos': {'holmes,': 123},
#  'adehlot': {'loathed': 1},
#  'eervy': {'every': 524},
#  'ceiosty': {'society': 70},
#  'abehimno': {'bohemian': 7},
#  ',losu': {'soul,': 13},
#  'adeeimnr': {'remained': 171},
#  'dggilnos': {'lodgings': 8},
#  'abekr': {'baker': 35, 'break': 79, 'brake': 1},
#  ',eerstt': {'street,': 36},
#  'bdeiru': {'buried': 17},
#  'agmno': {'among': 356},
#  'dlo': {'old': 938},
#  ',bkoos': {'books,': 12},
#  'aaegilnnrtt': {'alternating': 2},
#  'eekw': {'week': 54},
#  'beeentw': {'between': 538},
#  'acceino': {'cocaine': 4},
#  ',abiimnot': {'ambition,': 2},
#  'deinorsssw': {'drowsiness': 3},
#  ',dgru': {'drug,': 5},
#  'ceefir': {'fierce': 10},
#  'eegnry': {'energy': 24},
#  'eekn': {'keen': 23, 'knee': 58},
#  '.aenrtu': {'nature.': 10},
#  ',illst': {'still,': 28},
#  ',eerv': {'ever,': 13},
#  'deelpy': {'deeply': 51},
#  'aacderttt': {'attracted': 26},
#  'dstuy': {'study': 79, 'dusty': 14},
#  ',ceimr': {'crime,': 7, 'merci,': 1},
#  'ccdeiopu': {'occupied': 88},
#  'eeimmns': {'immense': 60},
#  'acefilstu': {'faculties': 7},
#  'aadeinorrrtxy': {'extraordinary': 50},
#  'eoprsw': {'powers': 103},
#  'abeinoorstv': {'observation': 22},
#  'fgillnoow': {'following': 157},
#  'ehost': {'those': 960},
#  ',celsu': {'clues,': 1},
#  'acegilnr': {'clearing': 21},
#  'eeimrssty': {'mysteries': 5},
#  'been': {'been': 2188},
#  'aabddenno': {'abandoned': 42},
#  'eehlopss': {'hopeless': 11},
#  'acffiilo': {'official': 64},
#  '.ceilop': {'police.': 9},
#  'eimt': {'time': 946, 'item': 3, 'emit': 2},
#  'emos': {'some': 1287},
#  'aeguv': {'vague': 32},
#  'accnotu': {'account': 122},
#  ':dginos': {'doings:': 1},
#  'mmnossu': {'summons': 8},
#  'adeoss': {'odessa': 1},
#  'effoprt': {'trepoff': 1},
#  ',demrru': {'murder,': 4},
#  'agilnrsu': {'singular': 34},
#  'adegrty': {'tragedy': 4},
#  'aiknnost': {'atkinson': 1},
#  'behorrst': {'brothers': 16},
#  ',aceeilmnort': {'trincomalee,': 1},
#  'afillny': {'finally': 99},
#  'iimnoss': {'mission': 20},
#  'accdehilmops': {'accomplished': 19},
#  'os': {'so': 2228, 'os': 3},
#  'acdeeillty': {'delicately': 3},
#  'ccefllsssuuy': {'successfully': 12},
#  'eggiinnr': {'reigning': 3},
#  'afilmy': {'family': 101},
#  '.adhllno': {'holland.': 1},
#  'bdenoy': {'beyond': 169},
#  'eehst': {'these': 921, 'sheet': 23},
#  'ginss': {'signs': 78, 'sings': 3},
#  ',aciittvy': {'activity,': 16},
#  ',eehorvw': {'however,': 303},
#  'eelmry': {'merely': 158},
#  'adehrs': {'shared': 18},
#  'adeerrs': {'readers': 4},
#  'adily': {'daily': 32, 'lydia': 1},
#  ',eprss': {'press,': 14},
#  'eknw': {'knew': 410},
#  'efmorr': {'former': 129, 'reform': 39},
#  'definr': {'friend': 115, 'finder': 1},
#  '\n\n.aceimnnnooop': {'companion.\n\none': 1},
#  '--ghiintt': {'night--it': 2},
#  'no': {'on': 5419, 'no': 1645},
#  'eehintttw': {'twentieth': 14},
#  '--1888i': {'1888--i': 1},
#  'eginnrrtu': {'returning': 60},
#  'ejnoruy': {'journey': 31},
#  'aeinptt': {'patient': 244},
#  '(for': {'(for': 10},
#  'deenrrtu': {'returned': 151},
#  'ciilv': {'civil': 146},
#  '),acceiprt': {'practice),': 1},
#  'awy': {'way': 547},
#  'del': {'led': 181, 'del': 1},
#  'em': {'me': 1016},
#  'ghhortu': {'through': 678},
#  '.eerstt': {'street.': 28},
#  'adepss': {'passed': 290, 'spades': 1},
#  '-bdeeeeellmmrrw': {'well-remembered': 1},
#  ',door': {'door,': 76},
#  'mstu': {'must': 846},
#  'aacdeiosst': {'associated': 150},
#  'dimn': {'mind': 189},
#  ',ginoow': {'wooing,': 1},
#  'adkr': {'dark': 114},
#  'cdeiinnst': {'incidents': 9},
#  ',acelrst': {'scarlet,': 3},
#  'deeisz': {'seized': 95},
#  'deeirs': {'desire': 74, 'reside': 1},
#  'ees': {'see': 760},
#  ',aagin': {'again,': 95},
#  'know': {'know': 686},
#  'egilmnopy': {'employing': 4},
#  '.eoprsw': {'powers.': 8},
#  'moors': {'rooms': 43},
#  'abiilllnrty': {'brilliantly': 3},
#  ',ilt': {'lit,': 3},
#  ',adn': {'and,': 501},
#  'eenv': {'even': 784, 'neve': 1},
#  'dekloo': {'looked': 658},
#  ',pu': {'up,': 159},
#  ',allt': {'tall,': 24},
#  'aeprs': {'spare': 20, 'spear': 3},
#  'efgiru': {'figure': 68},
#  'apss': {'pass': 101, 'spas': 1},
#  'ceitw': {'twice': 65},
#  'eehilosttu': {'silhouette': 1},
#  'aaginst': {'against': 531},
#  '.bdiln': {'blind.': 3},
#  'acginp': {'pacing': 22},
#  'moor': {'room': 393, 'moor': 2},
#  ',filstwy': {'swiftly,': 4},
#  ',aeeglry': {'eagerly,': 4},
#  'adeh': {'head': 420, 'deah': 1, 'dahe': 1},
#  'knsu': {'sunk': 21},
#  'cehst': {'chest': 44},
#  'adhns': {'hands': 239},
#  'acdelps': {'clasped': 11},
#  'bdehin': {'behind': 296},
#  '.him': {'him.': 510},
#  ',em': {'me,': 241},
#  'dmoo': {'mood': 35, 'doom': 4},
#  ',abhit': {'habit,': 11},
#  'adeitttu': {'attitude': 44},
#  'aemnnr': {'manner': 75},
#  'dlot': {'told': 424},
#  'ehirt': {'their': 2379},
#  '.orsty': {'story.': 12},
#  'korw': {'work': 222},
#  '.aagin': {'again.': 51},
#  'einrs': {'risen': 23, 'reins': 13},
#  '-acddeegrrtu': {'drug-created': 1},
#  'ademrs': {'dreams': 11},
#  'hot': {'hot': 63},
#  'censt': {'scent': 10, 'cents': 10},
#  'enw': {'new': 978, 'wen': 1},
#  '.belmopr': {'problem.': 5},
#  'agnr': {'rang': 24},
#  'bell': {'bell': 28},
#  'hnosw': {'shown': 94},
#  'abcehmr': {'chamber': 20},
#  'eflmorry': {'formerly': 47},
#  'aprt': {'part': 521, 'trap': 20, 'rapt': 3},
#  '\n\n.hinosw': {'own.\n\nhis': 1},
#  '.eeffisuv': {'effusive.': 1},
#  ';asw': {'was;': 2},
#  ',adgl': {'glad,': 9},
#  ',hiknt': {'think,': 56},
#  '.em': {'me.': 142},
#  'adhlry': {'hardly': 152},
#  'dorw': {'word': 194},
#  ',eknops': {'spoken,': 4},
#  'diklny': {'kindly': 53},
#  ',eey': {'eye,': 12},
#  'adevw': {'waved': 28},
#  'an': {'an': 2888, 'na': 1},
#  ',aachimrr': {'armchair,': 14},
#  'ehrtw': {'threw': 87},
#  'acorss': {'across': 181},
#  ',acgirs': {'cigars,': 3},
#  'acddeiint': {'indicated': 49},
#  'iiprst': {'spirit': 108},
#  'aeeggnos': {'gasogene': 1},
#  '.cenorr': {'corner.': 9},
#  'ehnt': {'then': 955},
#  'doost': {'stood': 314},
#  'efir': {'fire': 134, 'rife': 1},
#  'ceeiinoprsttv': {'introspective': 2},
#  '\n\n".acdefhiklnoosw': {'fashion.\n\n"wedlock': 1},
#  'isstu': {'suits': 8},
#  '",ouy': {'you,"': 90, '"you,': 1},
#  '.adeekmrr': {'remarked.': 14},
#  '"i': {'"i': 412, 'i"': 2},
#  ',anostw': {'watson,': 40},
#  'ptu': {'put': 381},
#  'eensv': {'seven': 91},
#  'afhl': {'half': 213},
#  'dnopsu': {'pounds': 14},
#  '\n\n!""".eenosuvy': {'you."\n\n"seven!"': 1},
#  '\n\n",.adddeeeeinnrsw': {'answered.\n\n"indeed,': 1},
#  'ghhottu': {'thought': 617},
#  '.emor': {'more.': 42},
#  'jstu': {'just': 611},
#  'efilrt': {'trifle': 7, 'filter': 2},
#  ',emor': {'more,': 44, 'rome,': 5},
#  ',acfny': {'fancy,': 6},
#  '.anostw': {'watson.': 10},
#  'acceiprt': {'practice': 60},
#  '.beeorsv': {'observe.': 3},
#  'ddi': {'did': 1630},
#  'ellt': {'tell': 420},
#  'ddeeinnt': {'intended': 45},
#  'go': {'go': 617},
#  '\n\n"",.aeehhnnrsst': {'harness."\n\n"then,': 1},
#  '\n\n""?iknow': {'know?"\n\n"i': 2},
#  'cddeeu': {'deduce': 13},
#  'eggintt': {'getting': 74},
#  'eflorsuy': {'yourself': 83},
#  'ervy': {'very': 1134},
#  'etw': {'wet': 39},
#  ',aellty': {'lately,': 5},
#  'clmsuy': {'clumsy': 4},
#  'aceelrss': {'careless': 9},
#  'aenrstv': {'servant': 30, 'taverns': 2},
#  '\n\n""?gilmry': {'girl?"\n\n"my': 1},
#  '",ehlmos': {'holmes,"': 11},
#  'adis': {'said': 2682, 'aids': 1},
#  ',i': {'i,': 69},
#  '"hist': {'"this': 41},
#  'oot': {'too': 320},
#  '.chmu': {'much.': 17},
#  'aceilnrty': {'certainly': 82},
#  ',bdenru': {'burned,': 10, 'burden,': 1},
#  'deilv': {'lived': 89, 'devil': 33},
#  'efw': {'few': 385},
#  'ceeinrstu': {'centuries': 11},
#  '.ago': {'ago.': 19},
#  'ertu': {'true': 108},
#  'aklw': {'walk': 47},
#  'adhrstuy': {'thursday': 3},
#  'acem': {'came': 857, 'acme': 2},
#  'ehmo': {'home': 160},
#  'addeflru': {'dreadful': 44},
#  ',emss': {'mess,': 1},
#  'acdeghn': {'changed': 95},
#  'cehlost': {'clothes': 31},
#  "'acnt": {"can't": 163},
#  'aegiimn': {'imagine': 60},
#  'amry': {'mary': 373, 'army': 419},
#  ',aejn': {'jane,': 1},
#  ',bcegiiilnorr': {'incorrigible,': 1},
#  'efiw': {'wife': 161, 'fiew': 1},
#  'eginv': {'given': 282},
#  ',ceinot': {'notice,': 7},
#  ',eehrt': {'there,': 119, 'three,': 7, 'ether,': 2},
#  'afil': {'fail': 24},
#  '\n\n".ehotu': {'out."\n\nhe': 3},
#  'ccdehklu': {'chuckled': 6},
#  'bbderu': {'rubbed': 28},
#  ',glno': {'long,': 41},
#  'enorsuv': {'nervous': 37},
#  '\n\n".eeghiorttt': {'together.\n\n"it': 1},
#  'ciiilmpsty': {'simplicity': 12},
#  '",efilst': {'itself,"': 2},
#  ';eh': {'he;': 11},
#  '"my': {'"my': 39},
#  'deiins': {'inside': 29, 'indies': 7},
#  ',ehos': {'shoe,': 2},
#  'eehrw': {'where': 742},
#  'efghiilrt': {'firelight': 2},
#  'eikrsst': {'strikes': 11},
#  'aeehlrt': {'leather': 18},
#  'cdeors': {'scored': 3},
#  'isx': {'six': 123},
#  'almost': {'almost': 247},
#  'aaelllpr': {'parallel': 12},
#  '.cstu': {'cuts.': 1},
#  'biloosuvy': {'obviously': 27},
#  'acdesu': {'caused': 86},
#  'eemnoos': {'someone': 104},
#  'aceellrssy': {'carelessly': 6},
#  'acdeprs': {'scraped': 11},
#  'dnoru': {'round': 396},
#  'deegs': {'edges': 47},
#  'elos': {'sole': 54, 'lose': 42},
#  'deorr': {'order': 263, 'ordre': 1},
#  'cderstu': {'crusted': 2, 'crudest': 2},
#  'dmu': {'mud': 13},
#  ',ceehn': {'hence,': 3},
#  ',ees': {'see,': 68},
#  'bdelou': {'double': 35},
#  'cddeinotu': {'deduction': 8},
#  ',aeehrtw': {'weather,': 6},
#  'aacillprrtuy': {'particularly': 120},
#  'aagilmnnt': {'malignant': 53},
#  '-bgiilnoosttt': {'boot-slitting': 1},
#  'ceeimnps': {'specimen': 7},
#  'dlnnoo': {'london': 34},
#  '.aelsvy': {'slavey.': 1},
#  ',acceiprt': {'practice,': 7},
#  'fi': {'if': 1854},
#  'aeeglmnnt': {'gentleman': 50},
#  'aklsw': {'walks': 7},
#  'egillmns': {'smelling': 2},
#  ',dfimooor': {'iodoform,': 2},
#  'abckl': {'black': 151},
#  'akmr': {'mark': 24},
#  'aeinrtt': {'nitrate': 7},
#  'eilrsv': {'silver': 80},
#  'ghirt': {'right': 402, 'girth': 7},
#  ',eeffginorr': {'forefinger,': 3},
#  'beglu': {'bulge': 2, 'bugle': 2},
#  'deis': {'side': 324, 'dies': 10},
#  '-ahoptt': {'top-hat': 3},
#  'hosw': {'show': 181},
#  'cdeeerst': {'secreted': 2, 'resected': 7},
#  ',ceehoopsstt': {'stethoscope,': 1},
#  ',dllu': {'dull,': 14},
#  ',ddeein': {'indeed,': 34},
#  'cennoopru': {'pronounce': 7},
#  'aceitv': {'active': 59},
#  'beemmr': {'member': 38},
#  'acdeilm': {'medical': 20, 'claimed': 14},
#  '\n\n".efiinooprss': {'profession."\n\ni': 1},
#  'cdlou': {'could': 1480, 'cloud': 20},
#  'ehlp': {'help': 173},
#  'agghilnu': {'laughing': 50},
#  'aees': {'ease': 18},
#  'adeeilnpx': {'explained': 46},
#  'ceoprss': {'process': 163, 'corpses': 3},
#  '.cddeinotu': {'deduction.': 1},
#  '"ehnw': {'"when': 17},
#  'aehr': {'hear': 149, 'hare': 14},
#  'egiv': {'give': 445},
#  '",aenorss': {'reasons,"': 1},
#  ',adeekmrr': {'remarked,': 23},
#  '"eht': {'"the': 258},
#  'aaepprs': {'appears': 84},
#  'cdiillorsuuy': {'ridiculously': 1},
#  'eilmps': {'simple': 83, 'impels': 1},
#  'aeilsy': {'easily': 76},
#  ',eflmsy': {'myself,': 23},
#  'ghhotu': {'though': 466},
#  'cceeisssuv': {'successive': 11},
#  'aceinnst': {'instance': 13, 'ancients': 9},
#  'am': {'am': 660, 'ma': 11},
#  'abdeffl': {'baffled': 5},
#  'ilntu': {'until': 271},
#  'aeilnpx': {'explain': 105},
#  '.ceoprss': {'process.': 9},
#  'beeeilv': {'believe': 141},
#  'dgoo': {'good': 408},
#  '\n\n"".eioqrstuuy': {'yours."\n\n"quite': 1},
#  '",os': {'so,"': 19},
#  ',adeenrsw': {'answered,': 15},
#  'gghiilnt': {'lighting': 12},
#  ',aceegirtt': {'cigarette,': 1},
#  'ghinortw': {'throwing': 36, 'ingrowth': 2},
#  'dnow': {'down': 837},
#  '.aachimrr': {'armchair.': 3},
#  '"ouy': {'"you': 137, 'you"': 1},
#  'cdiiinnostt': {'distinction': 13},
#  '.acelr': {'clear.': 8},
#  ',aeelmpx': {'example,': 163},
#  'eeflnqrtuy': {'frequently': 156},
#  'epsst': {'steps': 126},
#  'adel': {'lead': 105, 'deal': 47},
#  'ahll': {'hall': 41},
#  '\n\n\n\n""""..eefhlmnoooqrrtuwy': {'room."\n\n"frequently."\n\n"how': 1},
#  '\n\n"",?eefllnotw': {'often?"\n\n"well,': 1},
#  'ddehnrsu': {'hundreds': 39},
#  '\n\n"".eehimnstt': {'times."\n\n"then': 1},
#  'amny': {'many': 496},
#  '\n\n""?eehhortw': {'there?"\n\n"how': 1},
#  '?amny': {'many?': 1},
#  "'dnot": {"don't": 429},
#  '\n\n"".eiknoqtuw': {'know."\n\n"quite': 1},
#  '!os': {'so!': 7},
#  '.bdeeorsv': {'observed.': 8},
#  '.eens': {'seen.': 25},
#  '.inopt': {'point.': 19},
#  ',now': {'now,': 182, 'own,': 27, 'won,': 2},
#  'eeeennstv': {'seventeen': 7},
#  ',epsst': {'steps,': 17},
#  'abceesu': {'because': 475},
#  ',awy': {'way,': 102},
#  'deeeinrstt': {'interested': 42},
#  ',belmoprs': {'problems,': 7},
#  'eghnou': {'enough': 110},
#  'ccehilnor': {'chronicle': 5},
#  'otw': {'two': 863, 'tow': 1},
#  'fgiilnrt': {'trifling': 8, 'flirting': 1},
#  ',ceeeeinprsx': {'experiences,': 1},
#  '".hist': {'this."': 4},
#  ',chikt': {'thick,': 9},
#  '-deiiknnptt': {'pink-tinted': 1},
#  'aeenopprt': {'notepaper': 1},
#  'gilny': {'lying': 93},
#  'enop': {'open': 203},
#  '.abelt': {'table.': 40},
#  '"it': {'"it': 119, 'it"': 1},
#  'alst': {'last': 430, 'salt': 23},
#  '",opst': {'post,"': 1, '"stop,': 1, 'spot,"': 1},
#  '.eh': {'he.': 105},
#  '"ader': {'"read': 1, 'dear"': 2, '"dear': 4},
#  '\n\n".adehlotu': {'aloud."\n\nthe': 1},
#  'enot': {'note': 66, 'eton': 1, 'tone': 101},
#  ',addentu': {'undated,': 1},
#  'eehirt': {'either': 224},
#  'aeginrstu': {'signature': 7},
#  '\n\n".addeeehrrsst': {'address.\n\n"there': 1},
#  'illw': {'will': 1272},
#  'acll': {'call': 156},
#  ',-ghinott': {'to-night,': 5},
#  'aeqrrtu': {'quarter': 32},
#  'eghit': {'eight': 74},
#  '"\',cckloo': {'o\'clock,"': 2},
#  ',adis': {'said,': 258},
#  '"a': {'"a': 68},
#  'deeirss': {'desires': 11},
#  'clnostu': {'consult': 15},
#  'aemrtt': {'matter': 205},
#  'deeepst': {'deepest': 14},
#  '.emmnot': {'moment.': 33},
#  'ceenrt': {'recent': 41, 'centre': 29, 'center': 50},
#  'ceeirssv': {'services': 20},
#  'alory': {'royal': 85},
#  'ehossu': {'houses': 50},
#  'eeopru': {'europe': 65},
#  'aeflsy': {'safely': 9},
#  'dersttu': {'trusted': 12},
#  'aemrstt': {'matters': 68},
#  'aceimnoprt': {'importance': 59},
#  '.aadeeeggrtx': {'exaggerated.': 2},
#  'ew': {'we': 1437},
#  'aeqrrstu': {'quarters': 35},
#  '.cdeeeirv': {'received.': 5},
#  ',horu': {'hour,': 18},
#  'aimss': {'amiss': 4},
#  'iiorstv': {'visitor': 33},
#  'aerw': {'wear': 23, 'ware': 1},
#  '\n\n"".ahikmsst': {'mask."\n\n"this': 1},
#  'ddeein': {'indeed': 44, 'denied': 19},
#  '",emrstyy': {'mystery,"': 2},
#  '"ahtw': {'"what': 97},
#  '\n\n""?aeimns': {'means?"\n\n"i': 1},
#  'aadt': {'data': 4},
#  '.ety': {'yet.': 10},
#  'aacilpt': {'capital': 84},
#  'aeikmst': {'mistake': 22},
#  'eehiorst': {'theorise': 1, 'theories': 12},
#  '.aadt': {'data.': 4},
#  'beiilnnssy': {'insensibly': 2},
#  'begins': {'begins': 34, 'beings': 7},
#  'isttw': {'twist': 10},
#  'acfst': {'facts': 46},
#  'istu': {'suit': 21},
#  ',eehiorst': {'theories,': 2},
#  'adeinst': {'instead': 108, 'stained': 16},
#  '.acfst': {'facts.': 5},
#  '.efilst': {'itself.': 22},
#  'ahtw': {'what': 2198, 'thaw': 1},
#  '\n\n"?iit': {'it?"\n\ni': 1},
#  'acefllruy': {'carefully': 51},
#  'adeeimnx': {'examined': 37},
#  ',giinrtw': {'writing,': 7},
#  'aeppr': {'paper': 110},
#  '\n\n".eehinrtttw': {'written.\n\n"the': 1},
#  'eortw': {'wrote': 116, 'tower': 5},
#  'abelmprsuy': {'presumably': 6},
#  'ellw': {'well': 390},
#  '",do': {'do,"': 12},
#  'adeeginnoruv': {'endeavouring': 8},
#  'aeiimtt': {'imitate': 4},
#  "'acimnnoops": {"companion's": 6, "companions'": 1},
#  '.ceeoprsss': {'processes.': 3},
#  '"chsu': {'"such': 6},
#  'bghotu': {'bought': 43},
#  'cnorw': {'crown': 33},
#  '.acekpt': {'packet.': 2},
#  'aceillpruy': {'peculiarly': 9},
#  '\n\n""--.aaceffhiilprstttu': {'stiff."\n\n"peculiar--that': 1},
#  '",dorw': {'word,"': 3},
#  '.ehlmos': {'holmes.': 53},
#  'eghilns': {'english': 139},
#  '.all': {'all.': 73},
#  'dhlo': {'hold': 88},
#  '\n\n".ghiilt': {'light."\n\ni': 1},
#  ',os': {'so,': 82},
#  'aeglr': {'large': 376, 'glare': 3, 'regal': 1},
#  '""e': {'"e"': 1},
#  '"",g': {'"g,"': 1},
#  '"",p': {'"p,"': 1},
#  '""g': {'"g"': 1},
#  '""t': {'"t"': 1},
#  'enovw': {'woven': 4},
#  'eerttux': {'texture': 4},
#  '\n\n".aaehpprtw': {'paper.\n\n"what': 1},
#  '"?ahtt': {'that?"': 25},
#  'adeks': {'asked': 548},
#  '\n\n".eehhlmost': {'holmes.\n\n"the': 1},
#  'aemn': {'name': 168, 'mean': 46, 'mane': 7},
#  ',aekmr': {'maker,': 1},
#  ';bdotu': {'doubt;': 1},
#  ',agmmnoor': {'monogram,': 1},
#  '\n\n"".aehnorrtt': {'rather."\n\n"not': 1},
#  "''g": {"'g'": 1},
#  "''t": {"'t'": 1},
#  'adnsst': {'stands': 17},
#  "'',aceefghllsst": {"'gesellschaft,'": 1},
#  'aegmnr': {'german': 110},
#  "''.acmnopy": {"'company.'": 1},
#  'acmorstuy': {'customary': 16},
#  'accinnoortt': {'contraction': 35},
#  'eikl': {'like': 850},
#  "''.co": {"'co.'": 1},
#  "'',p": {"'p,'": 1},
#  ',ceorsu': {'course,': 56},
#  "''.aeippr": {"'papier.'": 1},
#  "''.eg": {"'eg.'": 1},
#  'elt': {'let': 396},
#  'acegln': {'glance': 64},
#  'aceilnnnott': {'continental': 33},
#  '".aeeegrttz': {'gazetteer."': 1},
#  'koot': {'took': 499},
#  'aehvy': {'heavy': 102},
#  'bnorw': {'brown': 39},
#  'elmouv': {'volume': 20},
#  '.eehlssv': {'shelves.': 1},
#  '",eglow': {'"eglow,': 1},
#  '--eeeghilnortz': {'eglonitz--here': 1},
#  ',aer': {'are,': 49, 'ear,': 11, 'era,': 1},
#  '.aegir': {'egria.': 1},
#  '-aaeeggikmnnprs': {'german-speaking': 1},
#  '--cinnortuy': {'country--in': 1},
#  ',abehimo': {'bohemia,': 5},
#  'afr': {'far': 328},
#  '.aabcdlrs': {'carlsbad.': 1},
#  "'aabeeklmrr": {"'remarkable": 1},
#  'begin': {'being': 741, 'begin': 64},
#  'ceens': {'scene': 33},
#  'adeht': {'death': 152, 'hated': 16},
#  ',aeeillnnstw': {'wallenstein,': 1},
#  'ist': {'its': 1371, 'sit': 68, 'ist': 1},
#  'emnorsuu': {'numerous': 35},
#  '-aacefgilorssst': {'glass-factories': 1},
#  "'-.aeillmpprs": {"paper-mills.'": 1},
#  ',ah': {'ha,': 18, 'ah,': 25},
#  ',boy': {'boy,': 31},
#  ',adeklprs': {'sparkled,': 1},
#  'enst': {'sent': 257, 'nest': 4, 'tens': 15, 'nets': 1},
#  'aegrt': {'great': 611, 'grate': 4},
#  'ahimnprttu': {'triumphant': 10},
#  '\n\n".aceeeghirttt': {'cigarette.\n\n"the': 1},
#  'adem': {'made': 835, 'mead': 1, 'dame': 1},
#  '",abehimo': {'bohemia,"': 1},
#  '\n\n"..acdeeiilprssy': {'said.\n\n"precisely.': 1},
#  '.aegmnr': {'german.': 5},
#  'aceilpru': {'peculiar': 67},
#  'ccinnoorsttu': {'construction': 16},
#  "'--ceeehinnsstt": {"sentence--'this": 1},
#  "'.cdeeeirv": {"received.'": 1},
#  'acefhmnnr': {'frenchman': 54},
#  'ainrssu': {'russian': 330},
#  '.ahtt': {'that.': 48},
#  'cenoorstuuu': {'uncourteous': 1},
#  '.bersv': {'verbs.': 1},
#  'lnoy': {'only': 1541, 'lyon': 2},
#  ',aeimnrs': {'remains,': 5, 'marines,': 2},
#  ',eeefhorrt': {'therefore,': 40},
#  'cdeiorsv': {'discover': 24},
#  'adentw': {'wanted': 159},
#  'eirstw': {'writes': 12},
#  'eefprrs': {'prefers': 1},
#  'aeginrw': {'wearing': 68},
#  'akms': {'mask': 7},
#  'ghinosw': {'showing': 78},
#  '.acef': {'face.': 68},
#  'eehr': {'here': 313},
#  ',cemos': {'comes,': 3},
#  ',aeikmnst': {'mistaken,': 6},
#  'eelorsv': {'resolve': 11},
#  '\n\n".abdosstu': {'doubts."\n\nas': 2},
#  'ahprs': {'sharp': 58},
#  'dnosu': {'sound': 160},
#  "'ehorss": {"horses'": 11, "horse's": 15},
#  'fhoos': {'hoofs': 14},
#  'agginrt': {'grating': 7},
#  'eehlsw': {'wheels': 30},
#  ',bcru': {'curb,': 1},
#  'deflloow': {'followed': 255},
#  'llpu': {'pull': 15},
#  '.bell': {'bell.': 6},
#  '\n\n".adehilstw': {'whistled.\n\n"a': 1},
#  ',aipr': {'pair,': 1},
#  '",dnosu': {'sound,"': 1},
#  '"",esy': {'"yes,"': 3},
#  ',cdeinnotu': {'continued,': 41, 'unnoticed,': 2},
#  'acggilnn': {'glancing': 83, 'clanging': 1},
#  '.dinoww': {'window.': 17},
#  'cein': {'nice': 29},
#  'abghmoru': {'brougham': 3},
#  'aipr': {'pair': 35},
#  '.abeeistu': {'beauties.': 1},
#  'ddehnru': {'hundred': 174},
#  'ffity': {'fifty': 46},
#  'aeginsu': {'guineas': 2},
#  '.aceeip': {'apiece.': 4},
#  "'eehrst": {"there's": 67},
#  'emnoy': {'money': 186},
#  ',aces': {'case,': 47},
#  'ghinnot': {'nothing': 405},
#  '\n\n"".eeils': {'else."\n\n"i': 3},
#  'hiknt': {'think': 414},
#  'beertt': {'better': 189},
#  ',go': {'go,': 54},
#  '\n\n"".ehlmnoost': {'holmes."\n\n"not': 2},
#  ',bit': {'bit,': 15},
#  '.cdoort': {'doctor.': 6},
#  'asty': {'stay': 56},
#  '.aer': {'are.': 16, 'ear.': 6, 'era.': 1},
#  'lost': {'lost': 134, 'lots': 4},
#  '.bellosw': {'boswell.': 1},
#  'eimoprss': {'promises': 13},
#  '.eegiinnrstt': {'interesting.': 7},
#  'ipty': {'pity': 48},
#  'imss': {'miss': 93},
#  '\n\n"".bittu': {'it."\n\n"but': 5},
#  '\n\n""--ceeeilnnrtv': {'client--"\n\n"never': 1},
#  'antw': {'want': 249},
#  ',ehlp': {'help,': 11},
#  '.cemos': {'comes.': 1},
#  ',cdoort': {'doctor,': 35},
#  'best': {'best': 204, 'bets': 1},
#  '\n\n".aaeinnottt': {'attention."\n\na': 1},
#  'losw': {'slow': 43, 'lows': 1},
#  ',epst': {'step,': 17},
#  'airsst': {'stairs': 13},
#  ',aaegpss': {'passage,': 16},
#  'adepsu': {'paused': 33},
#  'adeeiilmmty': {'immediately': 109},
#  'deiostu': {'outside': 70, 'tedious': 5},
#  '.door': {'door.': 53},
#  'dlou': {'loud': 43},
#  'aaehiiortttuv': {'authoritative': 2},
#  '\n\n".acemopt': {'tap.\n\n"come': 1},
#  '!"in': {'in!"': 4},
#  '\n\n.aehlmos': {'holmes.\n\na': 2},
#  'deeenrt': {'entered': 197},
#  'elss': {'less': 304},
#  'eeft': {'feet': 100, 'fete': 6},
#  'cehins': {'inches': 12},
#  ',eghhit': {'height,': 7},
#  'bilms': {'limbs': 35},
#  '.ceehlrsu': {'hercules.': 1},
#  'derss': {'dress': 66},
#  'chir': {'rich': 62},
#  'cehinrss': {'richness': 1},
#  ',dlouw': {'would,': 15},
#  ',adeglnn': {'england,': 60},
#  'abd': {'bad': 93},
#  '.aestt': {'taste.': 2, 'state.': 25},
#  'abdns': {'bands': 16},
#  'aaahknrst': {'astrakhan': 1},
#  'adehlss': {'slashed': 3},
#  'eeelssv': {'sleeves': 20},
#  'fnorst': {'fronts': 1},
#  '-abbddeeelorstu': {'double-breasted': 1},
#  ',acot': {'coat,': 36},
#  'deep': {'deep': 150},
#  'acklo': {'cloak': 23},
#  'hnortw': {'thrown': 78},
#  'dehlorssu': {'shoulders': 48},
#  'deiln': {'lined': 20},
#  '-acdeefllmooru': {'flame-coloured': 2},
#  'ikls': {'silk': 25},
#  'cdeersu': {'secured': 35, 'rescued': 7, 'reduces': 2},
#  'cekn': {'neck': 88},
#  'bchoor': {'brooch': 1},
#  'cdeinosst': {'consisted': 34},
#  'egilns': {'single': 132, 'genlis': 2},
#  'afgilmn': {'flaming': 7},
#  '.belry': {'beryl.': 1},
#  'boost': {'boots': 39},
#  'ddeeentx': {'extended': 45},
#  'aafhlwy': {'halfway': 15},
#  ',acelsv': {'calves,': 1},
#  'deimmrt': {'trimmed': 3},
#  'opst': {'tops': 3, 'post': 60, 'stop': 59, 'spot': 46, 'pots': 1},
#  ',fru': {'fur,': 4},
#  'cdeelmopt': {'completed': 15},
#  'eiimnoprss': {'impression': 54, 'permission': 27},
#  ...}
