# %%
## Word Count Using Dictionary

### Explanation:

When you have a huge block of text, sometimes you want to know how many times each word appears. 
For example, in a book or an article, some words occur many times (like *the*, *and*), 
while others occur only once.

We can solve this problem by using a **dictionary** in Python:

* The *keys* of the dictionary will be the words.
* The *values* will be how many times each word appears in the text.

For example, in the text `"hello world hello"`,
the dictionary would look like:
`{"hello": 2, "world": 1}`

This is called a **word count**.

### Exercise:

Write a function `word_count(text)` that:

* Takes a string `text` as input.
* Splits the text into words (you can use `split()`).
* Counts how many times each word appears using a dictionary.
* Returns the dictionary of word counts.

💡 **Hint**: You can test your function using the large file provided:

```python
txt = open('/cxldata/big.txt').read()
```

### Example:

```python
word_count("hello world hello")
# Output: {'hello': 2, 'world': 1}

word_count("apple orange apple banana orange")
# Output: {'apple': 2, 'orange': 2, 'banana': 1}
```
---

# %%
def word_count(text):
    dictionary = {}
    
    word_list = text.split(" ")
    for w in word_list:
        if w in dictionary:
            dictionary[w] = dictionary[w] + 1
        else:
            dictionary[w] = 1
            
    return dictionary

# %%
word_count("hello world hello")
# Out:
# {'hello': 2, 'world': 1}

# %%
word_count("apple orange apple banana orange")
# Out:
# {'apple': 2, 'orange': 2, 'banana': 1}

# %%
txt = open('/cxldata/big.txt').read()
word_count(txt)
# Out:
# {'The': 3793,
#  'Project': 157,
#  'Gutenberg': 64,
#  'EBook': 5,
#  'of': 34754,
#  'Adventures': 2,
#  'Sherlock': 69,
#  'Holmes\nby': 1,
#  'Sir': 30,
#  'Arthur': 16,
#  'Conan': 3,
#  'Doyle\n(#15': 1,
#  'in': 17459,
#  'our': 848,
#  'series': 79,
#  'by': 5597,
#  'Doyle)\n\nCopyright': 1,
#  'laws': 141,
#  'are': 2948,
#  'changing': 32,
#  'all': 2951,
#  'over': 1021,
#  'the': 61197,
#  'world.': 36,
#  'Be': 18,
#  'sure': 92,
#  'to': 24888,
#  'check': 28,
#  'the\ncopyright': 2,
#  'for': 5634,
#  'your': 1021,
#  'country': 191,
#  'before': 872,
#  'downloading': 3,
#  'or': 4478,
#  'redistributing\nthis': 2,
#  'any': 984,
#  'other': 1088,
#  'eBook.\n\nThis': 2,
#  'header': 5,
#  'should': 1077,
#  'be': 5192,
#  'first': 889,
#  'thing': 186,
#  'seen': 329,
#  'when': 1675,
#  'viewing': 4,
#  'this': 2547,
#  'Project\nGutenberg': 8,
#  'file.': 4,
#  '': 34449,
#  'Please': 12,
#  'do': 1012,
#  'not': 5464,
#  'remove': 41,
#  'it.': 462,
#  'Do': 73,
#  'change': 102,
#  'edit': 3,
#  'the\nheader': 2,
#  'without': 741,
#  'written': 88,
#  'permission.\n\nPlease': 2,
#  'read': 157,
#  '"legal': 2,
#  'small': 371,
#  'print,"': 2,
#  'and': 30996,
#  'information': 38,
#  'about': 1162,
#  'the\neBook': 2,
#  'at': 5636,
#  'bottom': 20,
#  'Included': 2,
#  'is\nimportant': 4,
#  'specific': 24,
#  'rights': 88,
#  'restrictions': 17,
#  'in\nhow': 2,
#  'file': 12,
#  'may': 2176,
#  'used.': 9,
#  'You': 369,
#  'can': 726,
#  'also': 578,
#  'find': 253,
#  'out': 1526,
#  'how': 786,
#  'make': 429,
#  'a\ndonation': 2,
#  'Gutenberg,': 2,
#  'get': 401,
#  'involved.\n\n\n**Welcome': 2,
#  'To': 266,
#  'World': 47,
#  'Free': 13,
#  'Plain': 3,
#  'Vanilla': 6,
#  'Electronic': 2,
#  'Texts**\n\n**eBooks': 2,
#  'Readable': 2,
#  'By': 139,
#  'Both': 34,
#  'Humans': 2,
#  'Computers,': 2,
#  'Since': 19,
#  '1971**\n\n*****These': 2,
#  'eBooks': 28,
#  'Were': 8,
#  'Prepared': 4,
#  'Thousands': 10,
#  'Volunteers!*****\n\n\nTitle:': 2,
#  'Holmes\n\nAuthor:': 1,
#  'Doyle\n\nRelease': 1,
#  'Date:': 4,
#  'March,': 20,
#  '1999': 3,
#  '[EBook': 4,
#  '#1661]\n[Most': 1,
#  'recently': 22,
#  'updated:': 2,
#  'November': 12,
#  '29,': 5,
#  '2002]\n\nEdition:': 1,
#  '12\n\nLanguage:': 1,
#  'English\n\nCharacter': 4,
#  'set': 261,
#  'encoding:': 4,
#  'ASCII\n\n***': 1,
#  'START': 4,
#  'OF': 200,
#  'THE': 178,
#  'PROJECT': 23,
#  'GUTENBERG': 11,
#  'EBOOK,': 4,
#  'ADVENTURES': 3,
#  'SHERLOCK': 4,
#  'HOLMES': 2,
#  '***\n\n\n\n\n(Additional': 1,
#  'editing': 4,
#  'Jose': 1,
#  'Menendez)\n\n\n\nTHE': 1,
#  'OF\nSHERLOCK': 1,
#  'HOLMES\n\nBY\n\nSIR': 1,
#  'ARTHUR': 1,
#  'CONAN': 1,
#  'DOYLE\n\nCONTENTS\n\nI.\tA': 1,
#  'Scandal': 2,
#  'Bohemia\nII.\tThe': 1,
#  'Red-Headed': 1,
#  'League\nIII.\tA': 1,
#  'Case': 1,
#  'Identity\nIV.\tThe': 1,
#  'Boscombe': 14,
#  'Valley': 27,
#  'Mystery\nV.\tThe': 1,
#  'Five': 13,
#  'Orange': 1,
#  'Pips\nVI.\tThe': 1,
#  'Man': 3,
#  'with': 8122,
#  'Twisted': 1,
#  'Lip\nVII.\tThe': 1,
#  'Adventure': 6,
#  'Blue': 2,
#  'Carbuncle\nVIII.\tThe': 1,
#  'Speckled': 1,
#  'Band\nIX.\tThe': 1,
#  "Engineer's": 1,
#  'Thumb\nX.\tThe': 1,
#  'Noble': 1,
#  'Bachelor\nXI.\tThe': 1,
#  'Beryl': 2,
#  'Coronet\nXII.\tThe': 1,
#  'Copper': 8,
#  'Beeches\n\n\nADVENTURE': 1,
#  'I.': 28,
#  'A': 537,
#  'SCANDAL': 1,
#  'IN': 48,
#  'BOHEMIA\n\nI.\n\n\nTo': 1,
#  'Holmes': 173,
#  'she': 2521,
#  'is': 8260,
#  'always': 481,
#  'woman.': 22,
#  'I': 5463,
#  'have': 3030,
#  'seldom': 62,
#  'heard': 483,
#  'him': 2737,
#  'mention': 27,
#  'her': 3751,
#  'under': 744,
#  'name.': 8,
#  'In': 1234,
#  'his': 8220,
#  'eyes': 499,
#  'eclipses': 2,
#  'predominates': 1,
#  'whole': 585,
#  'sex.': 2,
#  'It': 1301,
#  'was': 9753,
#  'that': 9842,
#  'he': 8366,
#  'felt': 566,
#  'emotion': 12,
#  'akin': 12,
#  'love': 312,
#  'Irene': 13,
#  'Adler.': 2,
#  'All': 222,
#  'emotions,': 2,
#  'one': 2379,
#  'particularly,': 3,
#  'were': 3547,
#  'abhorrent': 1,
#  'cold,': 45,
#  'precise': 8,
#  'but': 3654,
#  'admirably': 6,
#  'balanced': 3,
#  'mind.': 31,
#  'He': 1632,
#  'was,': 91,
#  'take': 507,
#  'it,': 441,
#  'most': 715,
#  'perfect': 26,
#  'reasoning': 18,
#  'observing': 14,
#  'machine': 25,
#  'world': 116,
#  'has': 1376,
#  'seen,': 13,
#  'as': 6592,
#  'a': 17581,
#  'lover': 11,
#  'would': 1651,
#  'placed': 153,
#  'himself': 673,
#  'false': 37,
#  'position.': 29,
#  'never': 459,
#  'spoke': 162,
#  'softer': 6,
#  'passions,': 5,
#  'save': 93,
#  'gibe': 1,
#  'sneer.': 2,
#  'They': 579,
#  'admirable': 8,
#  'things': 194,
#  'observer--excellent': 1,
#  'drawing': 187,
#  'veil': 10,
#  'from': 4664,
#  "men's": 23,
#  'motives': 10,
#  'actions.': 5,
#  'But': 705,
#  'trained': 16,
#  'reasoner': 3,
#  'admit': 50,
#  'such': 1146,
#  'intrusions': 1,
#  'into': 1833,
#  'own': 596,
#  'delicate': 35,
#  'finely': 8,
#  'adjusted': 14,
#  'temperament': 2,
#  'introduce': 18,
#  'distracting': 1,
#  'factor': 31,
#  'which': 3898,
#  'might': 444,
#  'throw': 39,
#  'doubt': 105,
#  'upon': 999,
#  'mental': 28,
#  'results.': 17,
#  'Grit': 1,
#  'sensitive': 18,
#  'instrument,': 2,
#  'crack': 10,
#  'high-power': 1,
#  'lenses,': 1,
#  'more': 1500,
#  'disturbing': 8,
#  'than': 1031,
#  'strong': 116,
#  'nature': 113,
#  'his.': 5,
#  'And': 669,
#  'yet': 339,
#  'there': 1621,
#  'woman': 139,
#  'him,': 677,
#  'late': 85,
#  'Adler,': 5,
#  'dubious': 1,
#  'questionable': 2,
#  'memory.\n\nI': 1,
#  'had': 6325,
#  'little': 804,
#  'lately.': 5,
#  'My': 92,
#  'marriage': 49,
#  'drifted': 5,
#  'us': 426,
#  'away': 472,
#  'each': 306,
#  'other.': 38,
#  'complete': 81,
#  'happiness,': 15,
#  'home-centred': 1,
#  'interests': 57,
#  'rise': 172,
#  'up': 1736,
#  'around': 175,
#  'man': 965,
#  'who': 2371,
#  'finds': 19,
#  'master': 44,
#  'establishment,': 1,
#  'sufficient': 54,
#  'absorb': 2,
#  'my': 1868,
#  'attention,': 12,
#  'while': 497,
#  'Holmes,': 123,
#  'loathed': 1,
#  'every': 474,
#  'form': 382,
#  'society': 68,
#  'Bohemian': 6,
#  'soul,': 13,
#  'remained': 171,
#  'lodgings': 8,
#  'Baker': 34,
#  'Street,': 23,
#  'buried': 17,
#  'among': 330,
#  'old': 888,
#  'books,': 12,
#  'alternating': 2,
#  'week': 54,
#  'between': 512,
#  'cocaine': 4,
#  'ambition,': 2,
#  'drowsiness': 2,
#  'drug,': 5,
#  'fierce': 10,
#  'energy': 23,
#  'keen': 22,
#  'nature.': 10,
#  'still,': 17,
#  'ever,': 13,
#  'deeply': 50,
#  'attracted': 26,
#  'study': 75,
#  'crime,': 7,
#  'occupied': 88,
#  'immense': 59,
#  'faculties': 7,
#  'extraordinary': 49,
#  'powers': 97,
#  'observation': 22,
#  'following': 149,
#  'those': 921,
#  'clues,': 1,
#  'clearing': 20,
#  'mysteries': 4,
#  'been': 2187,
#  'abandoned': 42,
#  'hopeless': 11,
#  'official': 64,
#  'police.': 8,
#  'From': 147,
#  'time': 942,
#  'some': 1200,
#  'vague': 32,
#  'account': 114,
#  'doings:': 1,
#  'summons': 7,
#  'Odessa': 1,
#  'case': 275,
#  'Trepoff': 1,
#  'murder,': 4,
#  'singular': 34,
#  'tragedy': 4,
#  'Atkinson': 1,
#  'brothers': 7,
#  'Trincomalee,': 1,
#  'finally': 87,
#  'mission': 18,
#  'accomplished': 19,
#  'so': 2082,
#  'delicately': 3,
#  'successfully': 12,
#  'reigning': 3,
#  'family': 100,
#  'Holland.': 1,
#  'Beyond': 13,
#  'these': 791,
#  'signs': 77,
#  'activity,': 16,
#  'however,': 286,
#  'merely': 158,
#  'shared': 18,
#  'readers': 4,
#  'daily': 30,
#  'press,': 13,
#  'knew': 410,
#  'former': 129,
#  'friend': 115,
#  'companion.\n\nOne': 1,
#  'night--it': 2,
#  'on': 5082,
#  'twentieth': 14,
#  '1888--I': 1,
#  'returning': 57,
#  'journey': 31,
#  'patient': 244,
#  '(for': 10,
#  'now': 939,
#  'returned': 150,
#  'civil': 64,
#  'practice),': 1,
#  'way': 547,
#  'led': 181,
#  'me': 1015,
#  'through': 660,
#  'Street.': 12,
#  'As': 356,
#  'passed': 288,
#  'well-remembered': 1,
#  'door,': 76,
#  'must': 842,
#  'associated': 147,
#  'mind': 187,
#  'wooing,': 1,
#  'dark': 113,
#  'incidents': 8,
#  'Study': 4,
#  'Scarlet,': 3,
#  'seized': 95,
#  'desire': 73,
#  'see': 741,
#  'again,': 92,
#  'know': 686,
#  'employing': 4,
#  'powers.': 8,
#  'His': 304,
#  'rooms': 43,
#  'brilliantly': 3,
#  'lit,': 3,
#  'and,': 491,
#  'even': 697,
#  'looked': 658,
#  'up,': 159,
#  'saw': 528,
#  'tall,': 24,
#  'spare': 20,
#  'figure': 68,
#  'pass': 101,
#  'twice': 53,
#  'silhouette': 1,
#  'against': 525,
#  'blind.': 3,
#  'pacing': 22,
#  'room': 393,
#  'swiftly,': 4,
#  'eagerly,': 4,
#  'head': 415,
#  'sunk': 21,
#  'chest': 44,
#  'hands': 234,
#  'clasped': 11,
#  'behind': 279,
#  'him.': 508,
#  'me,': 241,
#  'mood': 35,
#  'habit,': 11,
#  'attitude': 41,
#  'manner': 75,
#  'told': 414,
#  'their': 2328,
#  'story.': 12,
#  'work': 221,
#  'again.': 51,
#  'risen': 23,
#  'drug-created': 1,
#  'dreams': 11,
#  'hot': 63,
#  'scent': 10,
#  'new': 586,
#  'problem.': 5,
#  'rang': 24,
#  'bell': 25,
#  'shown': 94,
#  'chamber': 19,
#  'formerly': 42,
#  'part': 518,
#  'own.\n\nHis': 1,
#  'effusive.': 1,
#  'was;': 2,
#  'glad,': 9,
#  'think,': 56,
#  'me.': 142,
#  'With': 137,
#  'hardly': 144,
#  'word': 193,
#  'spoken,': 4,
#  'kindly': 47,
#  'eye,': 11,
#  'waved': 28,
#  'an': 2803,
#  'armchair,': 14,
#  'threw': 87,
#  'across': 180,
#  'cigars,': 3,
#  'indicated': 49,
#  'spirit': 100,
#  'gasogene': 1,
#  'corner.': 9,
#  'Then': 217,
#  'stood': 314,
#  'fire': 131,
#  'introspective': 2,
#  'fashion.\n\n"Wedlock': 1,
#  'suits': 8,
#  'you,"': 90,
#  'remarked.': 14,
#  '"I': 412,
#  'Watson,': 40,
#  'you': 3316,
#  'put': 380,
#  'seven': 87,
#  'half': 203,
#  'pounds': 14,
#  'since': 187,
#  'you."\n\n"Seven!"': 1,
#  'answered.\n\n"Indeed,': 1,
#  'thought': 616,
#  'more.': 42,
#  'Just': 54,
#  'trifle': 7,
#  'more,': 44,
#  'fancy,': 6,
#  'Watson.': 10,
#  'practice': 60,
#  'observe.': 3,
#  'did': 1604,
#  'tell': 396,
#  'intended': 45,
#  'go': 581,
#  'harness."\n\n"Then,': 1,
#  'know?"\n\n"I': 2,
#  'deduce': 13,
#  'How': 183,
#  'getting': 72,
#  'yourself': 83,
#  'very': 1112,
#  'wet': 39,
#  'lately,': 5,
#  'clumsy': 4,
#  'careless': 9,
#  'servant': 30,
#  'girl?"\n\n"My': 1,
#  'dear': 259,
#  'Holmes,"': 11,
#  'said': 2682,
#  'I,': 68,
#  '"this': 10,
#  'too': 315,
#  'much.': 17,
#  'certainly': 79,
#  'burned,': 10,
#  'lived': 89,
#  'few': 381,
#  'centuries': 11,
#  'ago.': 19,
#  'true': 107,
#  'walk': 47,
#  'Thursday': 2,
#  'came': 856,
#  'home': 159,
#  'dreadful': 44,
#  'mess,': 1,
#  'changed': 95,
#  'clothes': 31,
#  "can't": 159,
#  'imagine': 60,
#  'Mary': 372,
#  'Jane,': 1,
#  'incorrigible,': 1,
#  'wife': 161,
#  'given': 282,
#  'notice,': 7,
#  'there,': 110,
#  'fail': 24,
#  'it': 5882,
#  'out."\n\nHe': 3,
#  'chuckled': 6,
#  'rubbed': 28,
#  'long,': 41,
#  'nervous': 36,
#  'together.\n\n"It': 1,
#  'simplicity': 11,
#  'itself,"': 2,
#  'he;': 11,
#  '"my': 14,
#  'inside': 28,
#  'left': 621,
#  'shoe,': 2,
#  'just': 557,
#  'where': 695,
#  'firelight': 2,
#  'strikes': 10,
#  'leather': 18,
#  'scored': 3,
#  'six': 117,
#  'almost': 240,
#  'parallel': 12,
#  'cuts.': 1,
#  'Obviously': 3,
#  'they': 2547,
#  'caused': 86,
#  'someone': 98,
#  'carelessly': 6,
#  'scraped': 11,
#  'round': 390,
#  'edges': 47,
#  'sole': 49,
#  'order': 249,
#  'crusted': 2,
#  'mud': 13,
#  'Hence,': 2,
#  'see,': 65,
#  'double': 34,
#  'deduction': 8,
#  'vile': 8,
#  'weather,': 6,
#  'particularly': 118,
#  'malignant': 44,
#  'boot-slitting': 1,
#  'specimen': 7,
#  'London': 33,
#  'slavey.': 1,
#  'practice,': 7,
#  'if': 1461,
#  'gentleman': 49,
#  'walks': 7,
#  'smelling': 2,
#  'iodoform,': 2,
#  'black': 144,
#  'mark': 22,
#  'nitrate': 7,
#  'silver': 75,
#  'right': 396,
#  'forefinger,': 3,
#  'bulge': 2,
#  'side': 323,
#  'top-hat': 3,
#  'show': 165,
#  'secreted': 2,
#  'stethoscope,': 1,
#  'dull,': 14,
#  'indeed,': 21,
#  'pronounce': 7,
#  'active': 57,
#  'member': 38,
#  'medical': 17,
#  'profession."\n\nI': 1,
#  'could': 1470,
#  'help': 171,
#  'laughing': 50,
#  'ease': 18,
#  'explained': 46,
#  'process': 160,
#  'deduction.': 1,
#  '"When': 12,
#  'hear': 148,
#  'give': 402,
#  'reasons,"': 1,
#  'remarked,': 23,
#  '"the': 142,
#  'appears': 84,
#  'ridiculously': 1,
#  'simple': 82,
#  'easily': 76,
#  'myself,': 23,
#  'though': 390,
#  'successive': 11,
#  'instance': 13,
#  'am': 652,
#  'baffled': 5,
#  'until': 265,
#  'explain': 73,
#  'process.': 9,
#  'believe': 139,
#  'good': 402,
#  'yours."\n\n"Quite': 1,
#  'so,"': 19,
#  'answered,': 15,
#  'lighting': 12,
#  'cigarette,': 1,
#  'throwing': 36,
#  'down': 834,
#  'armchair.': 3,
#  '"You': 110,
#  'distinction': 13,
#  'clear.': 8,
#  'For': 173,
#  'example,': 163,
#  'frequently': 153,
#  'steps': 125,
#  'lead': 102,
#  'hall': 38,
#  'room."\n\n"Frequently."\n\n"How': 1,
#  'often?"\n\n"Well,': 1,
#  'hundreds': 35,
#  'times."\n\n"Then': 1,
#  'many': 453,
#  'there?"\n\n"How': 1,
#  'many?': 1,
#  "don't": 374,
#  'know."\n\n"Quite': 1,
#  'so!': 6,
#  'observed.': 8,
#  'seen.': 25,
#  'That': 189,
#  'point.': 18,
#  'Now,': 33,
#  'seventeen': 7,
#  'steps,': 17,
#  'because': 469,
#  'both': 382,
#  'way,': 102,
#  'interested': 42,
#  'problems,': 7,
#  'enough': 110,
#  'chronicle': 4,
#  'two': 802,
#  'trifling': 8,
#  'experiences,': 1,
#  'this."': 4,
#  'sheet': 23,
#  'thick,': 9,
#  'pink-tinted': 1,
#  'notepaper': 1,
#  'lying': 91,
#  'open': 203,
#  'table.': 40,
#  '"It': 93,
#  'last': 424,
#  'post,"': 1,
#  'he.': 105,
#  '"Read': 1,
#  'aloud."\n\nThe': 1,
#  'note': 62,
#  'undated,': 1,
#  'either': 218,
#  'signature': 7,
#  'address.\n\n"There': 1,
#  'will': 1258,
#  'call': 153,
#  'to-night,': 5,
#  'quarter': 32,
#  'eight': 70,
#  'o\'clock,"': 2,
#  'said,': 258,
#  '"a': 44,
#  'desires': 11,
#  'consult': 15,
#  'matter': 205,
#  'deepest': 14,
#  'moment.': 33,
#  'Your': 74,
#  'recent': 40,
#  'services': 19,
#  'royal': 68,
#  'houses': 46,
#  'Europe': 64,
#  'safely': 9,
#  'trusted': 12,
#  'matters': 68,
#  'importance': 59,
#  'exaggerated.': 2,
#  'This': 448,
#  'we': 1201,
#  'quarters': 35,
#  'received.': 5,
#  'then': 738,
#  'hour,': 18,
#  'amiss': 4,
#  'visitor': 33,
#  'wear': 23,
#  'mask."\n\n"This': 1,
#  'indeed': 36,
#  'mystery,"': 2,
#  '"What': 88,
#  'means?"\n\n"I': 1,
#  'no': 1557,
#  'data': 4,
#  'yet.': 10,
#  'capital': 83,
#  'mistake': 22,
#  'theorise': 1,
#  'data.': 4,
#  'Insensibly': 1,
#  'begins': 33,
#  'twist': 10,
#  'facts': 46,
#  'suit': 21,
#  'theories,': 2,
#  'instead': 97,
#  'theories': 10,
#  'facts.': 5,
#  'itself.': 22,
#  'What': 412,
#  'it?"\n\nI': 1,
#  'carefully': 50,
#  'examined': 37,
#  'writing,': 7,
#  'paper': 108,
#  'written.\n\n"The': 1,
#  'wrote': 116,
#  'presumably': 6,
#  'well': 381,
#  'do,"': 12,
#  'endeavouring': 8,
#  'imitate': 4,
#  "companion's": 6,
#  'processes.': 3,
#  '"Such': 5,
#  'bought': 43,
#  'crown': 23,
#  'packet.': 2,
#  'peculiarly': 9,
#  'stiff."\n\n"Peculiar--that': 1,
#  'word,"': 3,
#  'Holmes.': 53,
#  'English': 137,
#  'all.': 72,
#  'Hold': 1,
#  'light."\n\nI': 1,
#  'so,': 76,
#  'large': 369,
#  '"E"': 1,
#  '"g,"': 1,
#  '"P,"': 1,
#  '"G"': 1,
#  '"t"': 1,
#  'woven': 4,
#  'texture': 4,
#  'paper.\n\n"What': 1,
#  'that?"': 25,
#  'asked': 548,
#  'Holmes.\n\n"The': 1,
#  'name': 163,
#  'maker,': 1,
#  'doubt;': 1,
#  'monogram,': 1,
#  'rather."\n\n"Not': 1,
#  "'G'": 1,
#  "'t'": 1,
#  'stands': 17,
#  "'Gesellschaft,'": 1,
#  'German': 108,
#  "'Company.'": 1,
#  'customary': 16,
#  'contraction': 33,
#  'like': 824,
#  "'Co.'": 1,
#  "'P,'": 1,
#  'course,': 56,
#  "'Papier.'": 1,
#  'Now': 96,
#  "'Eg.'": 1,
#  'Let': 61,
#  'glance': 64,
#  'Continental': 20,
#  'Gazetteer."': 1,
#  'took': 499,
#  'heavy': 98,
#  'brown': 35,
#  'volume': 18,
#  'shelves.': 1,
#  '"Eglow,': 1,
#  'Eglonitz--here': 1,
#  'are,': 49,
#  'Egria.': 1,
#  'German-speaking': 1,
#  'country--in': 1,
#  'Bohemia,': 5,
#  'far': 290,
#  'Carlsbad.': 1,
#  "'Remarkable": 1,
#  'being': 737,
#  'scene': 33,
#  'death': 146,
#  'Wallenstein,': 1,
#  'its': 1323,
#  'numerous': 35,
#  'glass-factories': 1,
#  "paper-mills.'": 1,
#  'Ha,': 8,
#  'ha,': 10,
#  'boy,': 31,
#  'what': 1786,
#  'sparkled,': 1,
#  'sent': 256,
#  'great': 505,
#  'blue': 83,
#  'triumphant': 10,
#  'cloud': 20,
#  'cigarette.\n\n"The': 1,
#  'made': 833,
#  'Bohemia,"': 1,
#  'said.\n\n"Precisely.': 1,
#  'German.': 5,
#  'peculiar': 67,
#  'construction': 15,
#  "sentence--'This": 1,
#  "received.'": 1,
#  'Frenchman': 53,
#  'Russian': 329,
#  'that.': 48,
#  'uncourteous': 1,
#  'verbs.': 1,
#  'only': 1445,
#  'remains,': 5,
#  'therefore,': 39,
#  'discover': 24,
#  'wanted': 159,
#  'writes': 12,
#  'prefers': 1,
#  'wearing': 68,
#  'mask': 7,
#  'showing': 77,
#  'face.': 68,
#  'here': 265,
#  'comes,': 3,
#  'mistaken,': 6,
#  'resolve': 11,
#  'doubts."\n\nAs': 2,
#  'sharp': 58,
#  'sound': 157,
#  "horses'": 11,
#  'hoofs': 14,
#  'grating': 7,
#  'wheels': 29,
#  'curb,': 1,
#  'followed': 254,
#  'pull': 13,
#  'bell.': 5,
#  'whistled.\n\n"A': 1,
#  'pair,': 1,
#  'sound,"': 1,
#  '"Yes,"': 3,
#  'continued,': 41,
#  'glancing': 81,
#  'window.': 17,
#  '"A': 24,
#  'nice': 29,
#  'brougham': 3,
#  'pair': 35,
#  'beauties.': 1,
#  'hundred': 174,
#  'fifty': 45,
#  'guineas': 2,
#  'apiece.': 4,
#  "There's": 17,
#  'money': 180,
#  'case,': 47,
#  'nothing': 384,
#  'else."\n\n"I': 3,
#  'think': 408,
#  'better': 186,
#  'go,': 51,
#  'Holmes."\n\n"Not': 2,
#  'bit,': 15,
#  'Doctor.': 1,
#  'Stay': 1,
#  'are.': 16,
#  'lost': 133,
#  'Boswell.': 1,
#  'promises': 13,
#  'interesting.': 7,
#  'pity': 47,
#  'miss': 13,
#  'it."\n\n"But': 5,
#  'client--"\n\n"Never': 1,
#  'want': 249,
#  'help,': 11,
#  'Here': 48,
#  ...}

# %%
## Find Anagrams in a Text

### Explanation:

An **anagram** is a word formed by rearranging the letters of another word.
For example:

* `"listen"` and `"silent"` are anagrams.
* `"evil"` and `"vile"` are also anagrams.

To find anagrams in a large text, one useful trick is to use a **dictionary (hash map)**:

* We can sort the letters of each word to form a *key*.

  * Example: `"listen"` → `"eilnst"`, `"silent"` → `"eilnst"`.
* All words that share the same sorted key are anagrams of each other.
* We group words together in the dictionary using these keys.

This method is very efficient, even for huge texts.

---

### Exercise:

Write a function `find_anagrams(text)` that:

1. Splits the given text into words.
2. Uses a dictionary to group words that are anagrams of each other.
3. Returns a dictionary where:

   * The key is the sorted letters (like `"eilnst"`).
   * The value is a list of words that are anagrams.

You can test your function using a big text file:

```python
txt = open('/cxldata/big.txt').read()
```

---

### Example:

```python
find_anagrams("listen silent enlist inlets hello world")
# Possible Output:
# {
#   'eilnst': ['listen', 'silent', 'enlist', 'inlets'],
#   'ehllo': ['hello'],
#   'dlorw': ['world']
# }
```

```python
find_anagrams("evil vile live veil")
# Output:
# {
#   'eilv': ['evil', 'vile', 'live', 'veil']
# }
```

---

# %%
def find_anagrams(text):
    dictionary = {}
    
    word_list = text.split(" ")
    for w in word_list:
        sorted_w = "".join(sorted(w))
        if sorted_w in dictionary:
            list_word = dictionary[sorted_w]
            if w not in list_word:
                list_word.append(w)
            dictionary[sorted_w] = list_word
        else:
            dictionary[sorted_w] = [w]
            
    return dictionary

# %%
find_anagrams("listen silent enlist inlets hello world")
# Out:
# {'eilnst': ['listen', 'silent', 'enlist', 'inlets'],
#  'ehllo': ['hello'],
#  'dlorw': ['world']}

# %%
find_anagrams("evil vile live veil")
# Out:
# {'eilv': ['evil', 'vile', 'live', 'veil']}

# %%
txt = open('/cxldata/big.txt').read()
find_anagrams(txt)
# Out:
# {'Teh': ['The'],
#  'Pcejort': ['Project'],
#  'Gbeegnrtu': ['Gutenberg'],
#  'BEkoo': ['EBook'],
#  'fo': ['of'],
#  'Adeenrstuv': ['Adventures'],
#  'Scehklor': ['Sherlock'],
#  '\nHbelmosy': ['Holmes\nby'],
#  'Sir': ['Sir'],
#  'Ahrrtu': ['Arthur'],
#  'Canno': ['Conan'],
#  '\n#(15Deloy': ['Doyle\n(#15'],
#  'in': ['in', 'ni'],
#  'oru': ['our'],
#  'eeirss': ['series'],
#  'by': ['by'],
#  '\n\n)CDeghilooprtyy': ['Doyle)\n\nCopyright'],
#  'alsw': ['laws'],
#  'aer': ['are', 'ear', 'era'],
#  'acgghinn': ['changing'],
#  'all': ['all'],
#  'eorv': ['over'],
#  'eht': ['the'],
#  '.dlorw': ['world.'],
#  'Be': ['Be'],
#  'ersu': ['sure', 'ruse', 'user'],
#  'ot': ['to'],
#  'ccehk': ['check'],
#  '\nceghhioprtty': ['the\ncopyright'],
#  'for': ['for', 'fro'],
#  'oruy': ['your'],
#  'cnortuy': ['country'],
#  'beefor': ['before'],
#  'addgilnnoow': ['downloading'],
#  'or': ['or'],
#  '\nbdeghiiiinrrsstttu': ['redistributing\nthis'],
#  'any': ['any'],
#  'ehort': ['other'],
#  '\n\n.BTehikoos': ['eBook.\n\nThis'],
#  'adeehr': ['header', 'adhere'],
#  'dhlosu': ['should'],
#  'be': ['be'],
#  'first': ['first', 'rifts'],
#  'ghint': ['thing', 'night'],
#  'eens': ['seen'],
#  'ehnw': ['when', 'hewn'],
#  'egiinvw': ['viewing'],
#  'hist': ['this', 'hits'],
#  '\nGPbceeegjnorrttu': ['Project\nGutenberg'],
#  '.efil': ['file.', 'life.'],
#  '': [''],
#  'Paeels': ['Please'],
#  'do': ['do'],
#  'not': ['not', 'ton', 'ont'],
#  'eemorv': ['remove'],
#  '.it': ['it.'],
#  'Do': ['Do'],
#  'aceghn': ['change'],
#  'deit': ['edit', 'tide', 'tied', 'diet'],
#  '\nadeeehhrt': ['the\nheader'],
#  'hiottuw': ['without'],
#  'einrttw': ['written'],
#  '\n\n.Paeeeiilmnoprsss': ['permission.\n\nPlease'],
#  'ader': ['read', 'dear', 'dare'],
#  '"aegll': ['"legal'],
#  'allms': ['small'],
#  '",inprt': ['print,"'],
#  'adn': ['and', 'dan'],
#  'afiimnnoort': ['information'],
#  'abotu': ['about'],
#  '\nBeehkoot': ['the\neBook'],
#  'at': ['at', 'ta'],
#  'bmoott': ['bottom'],
#  'Icddelnu': ['Included'],
#  '\naiimnoprstt': ['is\nimportant'],
#  'ccefiips': ['specific'],
#  'ghirst': ['rights', 'girths'],
#  'ceiinorrsstt': ['restrictions'],
#  '\nhinow': ['in\nhow'],
#  'efil': ['file', 'life'],
#  'amy': ['may', 'amy'],
#  '.desu': ['used.', 'dues.'],
#  'You': ['You'],
#  'acn': ['can'],
#  'alos': ['also'],
#  'dfin': ['find'],
#  'otu': ['out'],
#  'how': ['how', 'who'],
#  'aekm': ['make'],
#  '\naadinnoot': ['a\ndonation'],
#  ',Gbeegnrtu': ['Gutenberg,'],
#  'egt': ['get'],
#  '\n\n\n**.Wcdeeeillmnoovv': ['involved.\n\n\n**Welcome'],
#  'To': ['To'],
#  'Wdlor': ['World'],
#  'Feer': ['Free'],
#  'Pailn': ['Plain'],
#  'Vaailln': ['Vanilla'],
#  'Ecceilnort': ['Electronic'],
#  '\n\n****BTeekoosstx': ['Texts**\n\n**eBooks'],
#  'Raabdeel': ['Readable'],
#  'By': ['By'],
#  'Bhot': ['Both'],
#  'Hamnsu': ['Humans'],
#  ',Cemoprstu': ['Computers,'],
#  'Scein': ['Since'],
#  '\n\n*******1179Teehs': ['1971**\n\n*****These'],
#  'Bekoos': ['eBooks'],
#  'Weer': ['Were'],
#  'Padeeprr': ['Prepared'],
#  'Tadhnossu': ['Thousands'],
#  '\n\n\n!*****:TVeeeillnorsttu': ['Volunteers!*****\n\n\nTitle:'],
#  '\n\n:AHehlmoorstu': ['Holmes\n\nAuthor:'],
#  '\n\nDRaeeeellosy': ['Doyle\n\nRelease'],
#  ':Daet': ['Date:'],
#  ',Machr': ['March,'],
#  '1999': ['1999'],
#  'BE[koo': ['[EBook'],
#  '\n#1166M[]ost': ['#1661]\n[Most'],
#  'ceelnrty': ['recently'],
#  ':addeptu': ['updated:'],
#  'Nbeemorv': ['November'],
#  ',29': ['29,', '92,'],
#  '\n\n0022:E]diinot': ['2002]\n\nEdition:'],
#  '\n\n12:Laaeggnu': ['12\n\nLanguage:'],
#  '\n\nCEaaceghhilnrrst': ['English\n\nCharacter'],
#  'est': ['set', 'est'],
#  ':cdeginno': ['encoding:'],
#  '\n\n***ACIIS': ['ASCII\n\n***'],
#  'ARSTT': ['START'],
#  'FO': ['OF'],
#  'EHT': ['THE'],
#  'CEJOPRT': ['PROJECT'],
#  'BEEGGNRTU': ['GUTENBERG'],
#  ',BEKOO': ['EBOOK,'],
#  'ADEENRSTUV': ['ADVENTURES'],
#  'CEHKLORS': ['SHERLOCK'],
#  'EHLMOS': ['HOLMES'],
#  '\n\n\n\n\n(***Aaddiilnot': ['***\n\n\n\n\n(Additional'],
#  'degiint': ['editing'],
#  'Jeos': ['Jose'],
#  '\n\n\n\n)EHMTdeeennz': ['Menendez)\n\n\n\nTHE'],
#  '\nCEFHKLOORS': ['OF\nSHERLOCK'],
#  '\n\n\n\nBEHILMORSSY': ['HOLMES\n\nBY\n\nSIR'],
#  'AHRRTU': ['ARTHUR'],
#  'ACNNO': ['CONAN'],
#  '\t\n\n\n\n.ACDEEILNNOOSTTY': ['DOYLE\n\nCONTENTS\n\nI.\tA'],
#  'Saacdln': ['Scandal'],
#  '\t\n.BIITaeehhimo': ['Bohemia\nII.\tThe'],
#  '-HRadddeee': ['Red-Headed'],
#  '\t\n.AIIILaeegu': ['League\nIII.\tA'],
#  'Caes': ['Case'],
#  '\t\n.IITVdeehintty': ['Identity\nIV.\tThe'],
#  'Bbcemoos': ['Boscombe'],
#  'Vaelly': ['Valley'],
#  '\t\n.MTVeehrstyy': ['Mystery\nV.\tThe'],
#  'Feiv': ['Five'],
#  'Oaegnr': ['Orange'],
#  '\t\n.IPTVehips': ['Pips\nVI.\tThe'],
#  'Man': ['Man'],
#  'hitw': ['with', 'whit'],
#  'Tdeistw': ['Twisted'],
#  '\t\n.IILTVehip': ['Lip\nVII.\tThe'],
#  'Adeenrtuv': ['Adventure'],
#  'Belu': ['Blue'],
#  '\t\n.CIIITVabceehlnru': ['Carbuncle\nVIII.\tThe'],
#  'Scdeeklp': ['Speckled'],
#  '\t\n.BITXadehn': ['Band\nIX.\tThe'],
#  "'Eeeginnrs": ["Engineer's"],
#  '\t\n.TTXbehhmu': ['Thumb\nX.\tThe'],
#  'Nbelo': ['Noble'],
#  '\t\n.BITXaceehhlor': ['Bachelor\nXI.\tThe'],
#  'Belry': ['Beryl'],
#  '\t\n.CIITXeehnoort': ['Coronet\nXII.\tThe'],
#  'Ceoppr': ['Copper'],
#  '\n\n\nABDEENRTUVceeehs': ['Beeches\n\n\nADVENTURE'],
#  '.I': ['I.'],
#  'A': ['A'],
#  'AACDLNS': ['SCANDAL'],
#  'IN': ['IN'],
#  '\n\n\n\n\n.ABEHIIMOTo': ['BOHEMIA\n\nI.\n\n\nTo'],
#  'Helmos': ['Holmes'],
#  'ehs': ['she'],
#  'is': ['is', 'si'],
#  'aalswy': ['always'],
#  '.amnow': ['woman.'],
#  'I': ['I'],
#  'aehv': ['have'],
#  'delmos': ['seldom'],
#  'adehr': ['heard'],
#  'him': ['him'],
#  'eimnnot': ['mention'],
#  'ehr': ['her'],
#  'denru': ['under'],
#  '.aemn': ['name.', 'mean.'],
#  'In': ['In'],
#  'his': ['his'],
#  'eesy': ['eyes'],
#  'ceeilpss': ['eclipses'],
#  'adeeimnoprst': ['predominates'],
#  'ehlow': ['whole'],
#  '.esx': ['sex.'],
#  'It': ['It'],
#  'asw': ['was', 'saw'],
#  'ahtt': ['that'],
#  'eh': ['he', 'eh'],
#  'eflt': ['felt', 'left'],
#  'eimnoot': ['emotion'],
#  'aikn': ['akin'],
#  'elov': ['love'],
#  'Ieenr': ['Irene'],
#  '.Adelr': ['Adler.'],
#  'All': ['All'],
#  ',eimnoost': ['emotions,'],
#  'eno': ['one'],
#  ',aacillprrtuy': ['particularly,'],
#  'eerw': ['were'],
#  'abehnorrt': ['abhorrent'],
#  ',cdlo': ['cold,'],
#  'ceeiprs': ['precise'],
#  'btu': ['but', 'tub'],
#  'aabdilmry': ['admirably'],
#  'aabcdeln': ['balanced'],
#  '.dimn': ['mind.'],
#  'He': ['He'],
#  ',asw': ['was,', 'saw,'],
#  'aekt': ['take', 'kate'],
#  ',it': ['it,'],
#  'most': ['most'],
#  'ceefprt': ['perfect', 'prefect'],
#  'aeginnors': ['reasoning'],
#  'beginorsv': ['observing'],
#  'acehimn': ['machine'],
#  'dlorw': ['world'],
#  'ahs': ['has', 'ash'],
#  ',eens': ['seen,'],
#  'as': ['as', 'sa'],
#  'a': ['a'],
#  'elorv': ['lover'],
#  'dlouw': ['would'],
#  'acdelp': ['placed'],
#  'efhilms': ['himself'],
#  'aefls': ['false', 'fleas'],
#  '.iinoopst': ['position.'],
#  'eenrv': ['never', 'nerve'],
#  'ekops': ['spoke'],
#  'eforst': ['softer', 'foster', 'forest'],
#  ',ainopsss': ['passions,'],
#  'aesv': ['save', 'vase'],
#  'begi': ['gibe'],
#  '.eenrs': ['sneer.'],
#  'Tehy': ['They'],
#  'aabdeilmr': ['admirable'],
#  'ghinst': ['things', 'nights'],
#  '--bceeeeellnorrstvx': ['observer--excellent'],
#  'adginrw': ['drawing', 'warding'],
#  'eilv': ['veil', 'vile', 'evil', 'live'],
#  'fmor': ['from', 'form'],
#  "'emns": ["men's"],
#  'eimostv': ['motives'],
#  '.acinost': ['actions.'],
#  'Btu': ['But'],
#  'adeinrt': ['trained'],
#  'aeenorrs': ['reasoner'],
#  'adimt': ['admit'],
#  'chsu': ['such'],
#  'iinnorsstu': ['intrusions'],
#  'inot': ['into'],
#  'now': ['own', 'now', 'won'],
#  'acdeeilt': ['delicate'],
#  'efilny': ['finely'],
#  'addejstu': ['adjusted'],
#  'aeeemmnprtt': ['temperament'],
#  'cdeinortu': ['introduce', 'reduction'],
#  'acdgiinrstt': ['distracting'],
#  'acfort': ['factor'],
#  'chhiw': ['which'],
#  'ghimt': ['might'],
#  'hortw': ['throw', 'worth'],
#  'bdotu': ['doubt'],
#  'nopu': ['upon'],
#  'aelmnt': ['mental', 'lament', 'mantle'],
#  '.elrsstu': ['results.', 'sutlers.'],
#  'Girt': ['Grit'],
#  'eeiinsstv': ['sensitive'],
#  ',eimnnrsttu': ['instrument,'],
#  'acckr': ['crack'],
#  '-eghhioprw': ['high-power'],
#  ',eelnss': ['lenses,'],
#  'emor': ['more', 'rome'],
#  'bdgiinrstu': ['disturbing'],
#  'ahnt': ['than'],
#  'gnorst': ['strong'],
#  'aenrtu': ['nature'],
#  '.his': ['his.'],
#  'Adn': ['And'],
#  'ety': ['yet', 'ety'],
#  'eehrt': ['there', 'three', 'ether'],
#  'amnow': ['woman'],
#  ',him': ['him,'],
#  'aelt': ['late', 'tale', 'alte'],
#  ',Adelr': ['Adler,'],
#  'bdiosuu': ['dubious'],
#  'abeeilnoqstu': ['questionable'],
#  '\n\n.Iemmory': ['memory.\n\nI'],
#  'adh': ['had'],
#  'eilltt': ['little'],
#  '.aellty': ['lately.'],
#  'My': ['My'],
#  'aaegimrr': ['marriage'],
#  'ddefirt': ['drifted'],
#  'su': ['us'],
#  'aawy': ['away'],
#  'aceh': ['each', 'ache'],
#  '.ehort': ['other.'],
#  'ceelmopt': ['complete'],
#  ',aehinppss': ['happiness,'],
#  '-cdeeehmnort': ['home-centred'],
#  'eeinrsstt': ['interests'],
#  'eirs': ['rise', 'sire'],
#  'pu': ['up'],
#  'adnoru': ['around'],
#  'amn': ['man'],
#  'dfins': ['finds'],
#  'aemrst': ['master', 'stream'],
#  ',abeehilmnsstt': ['establishment,'],
#  'ceffiinstu': ['sufficient'],
#  'abbors': ['absorb'],
#  'my': ['my'],
#  ',aeinnottt': ['attention,'],
#  'ehilw': ['while'],
#  ',Helmos': ['Holmes,'],
#  'adehlot': ['loathed'],
#  'eervy': ['every'],
#  'ceiosty': ['society'],
#  'Baehimno': ['Bohemian'],
#  ',losu': ['soul,'],
#  'adeeimnr': ['remained'],
#  'dggilnos': ['lodgings'],
#  'Baekr': ['Baker'],
#  ',Seertt': ['Street,'],
#  'bdeiru': ['buried'],
#  'agmno': ['among'],
#  'dlo': ['old'],
#  ',bkoos': ['books,'],
#  'aaegilnnrtt': ['alternating'],
#  'eekw': ['week'],
#  'beeentw': ['between'],
#  'acceino': ['cocaine'],
#  ',abiimnot': ['ambition,'],
#  'deinorsssw': ['drowsiness'],
#  ',dgru': ['drug,'],
#  'ceefir': ['fierce'],
#  'eegnry': ['energy'],
#  'eekn': ['keen', 'knee'],
#  '.aenrtu': ['nature.'],
#  ',illst': ['still,'],
#  ',eerv': ['ever,'],
#  'deelpy': ['deeply'],
#  'aacderttt': ['attracted'],
#  'dstuy': ['study', 'dusty'],
#  ',ceimr': ['crime,', 'merci,'],
#  'ccdeiopu': ['occupied'],
#  'eeimmns': ['immense'],
#  'acefilstu': ['faculties'],
#  'aadeinorrrtxy': ['extraordinary'],
#  'eoprsw': ['powers'],
#  'abeinoorstv': ['observation'],
#  'fgillnoow': ['following'],
#  'ehost': ['those'],
#  ',celsu': ['clues,'],
#  'acegilnr': ['clearing'],
#  'eeimrssty': ['mysteries'],
#  'been': ['been'],
#  'aabddenno': ['abandoned'],
#  'eehlopss': ['hopeless'],
#  'acffiilo': ['official'],
#  '.ceilop': ['police.'],
#  'Fmor': ['From', 'Form'],
#  'eimt': ['time', 'item', 'emit'],
#  'emos': ['some'],
#  'aeguv': ['vague'],
#  'accnotu': ['account'],
#  ':dginos': ['doings:'],
#  'mmnossu': ['summons'],
#  'Oadess': ['Odessa'],
#  'aces': ['case'],
#  'Teffopr': ['Trepoff'],
#  ',demrru': ['murder,'],
#  'agilnrsu': ['singular'],
#  'adegrty': ['tragedy'],
#  'Aiknnost': ['Atkinson'],
#  'behorrst': ['brothers'],
#  ',Taceeilmnor': ['Trincomalee,'],
#  'afillny': ['finally'],
#  'iimnoss': ['mission'],
#  'accdehilmops': ['accomplished'],
#  'os': ['so', 'os'],
#  'acdeeillty': ['delicately'],
#  'ccefllsssuuy': ['successfully'],
#  'eggiinnr': ['reigning'],
#  'afilmy': ['family'],
#  '.Hadllno': ['Holland.'],
#  'Bdenoy': ['Beyond'],
#  'eehst': ['these', 'sheet'],
#  'ginss': ['signs', 'sings'],
#  ',aciittvy': ['activity,'],
#  ',eehorvw': ['however,'],
#  'eelmry': ['merely'],
#  'adehrs': ['shared'],
#  'adeerrs': ['readers'],
#  'adily': ['daily', 'lydia'],
#  ',eprss': ['press,'],
#  'eknw': ['knew'],
#  'efmorr': ['former', 'reform'],
#  'definr': ['friend', 'finder'],
#  '\n\n.Oaceimnnnoop': ['companion.\n\nOne'],
#  '--ghiintt': ['night--it'],
#  'no': ['on', 'no'],
#  'eehintttw': ['twentieth'],
#  '--1888I': ['1888--I'],
#  'eginnrrtu': ['returning'],
#  'ejnoruy': ['journey'],
#  'aeinptt': ['patient'],
#  '(for': ['(for'],
#  'deenrrtu': ['returned'],
#  'ciilv': ['civil'],
#  '),acceiprt': ['practice),'],
#  'awy': ['way'],
#  'del': ['led', 'del'],
#  'em': ['me'],
#  'ghhortu': ['through'],
#  '.Seertt': ['Street.'],
#  'As': ['As'],
#  'adepss': ['passed', 'spades'],
#  '-bdeeeeellmmrrw': ['well-remembered'],
#  ',door': ['door,'],
#  'mstu': ['must'],
#  'aacdeiosst': ['associated'],
#  'dimn': ['mind'],
#  ',ginoow': ['wooing,'],
#  'adkr': ['dark'],
#  'cdeiinnst': ['incidents'],
#  'Sdtuy': ['Study'],
#  ',Sacelrt': ['Scarlet,'],
#  'deeisz': ['seized'],
#  'deeirs': ['desire', 'reside'],
#  'ees': ['see'],
#  ',aagin': ['again,'],
#  'know': ['know'],
#  'egilmnopy': ['employing'],
#  '.eoprsw': ['powers.'],
#  'His': ['His'],
#  'moors': ['rooms'],
#  'abiilllnrty': ['brilliantly'],
#  ',ilt': ['lit,'],
#  ',adn': ['and,'],
#  'eenv': ['even'],
#  'dekloo': ['looked'],
#  ',pu': ['up,'],
#  ',allt': ['tall,'],
#  'aeprs': ['spare', 'spear'],
#  'efgiru': ['figure'],
#  'apss': ['pass', 'spas'],
#  'ceitw': ['twice'],
#  'eehilosttu': ['silhouette'],
#  'aaginst': ['against'],
#  '.bdiln': ['blind.'],
#  'acginp': ['pacing'],
#  'moor': ['room', 'moor'],
#  ',filstwy': ['swiftly,'],
#  ',aeeglry': ['eagerly,'],
#  'adeh': ['head', 'deah', 'dahe'],
#  'knsu': ['sunk'],
#  'cehst': ['chest'],
#  'adhns': ['hands'],
#  'acdelps': ['clasped'],
#  'bdehin': ['behind'],
#  '.him': ['him.'],
#  ',em': ['me,'],
#  'dmoo': ['mood', 'doom'],
#  ',abhit': ['habit,'],
#  'adeitttu': ['attitude'],
#  'aemnnr': ['manner'],
#  'dlot': ['told'],
#  'ehirt': ['their'],
#  '.orsty': ['story.'],
#  'korw': ['work'],
#  '.aagin': ['again.'],
#  'einrs': ['risen', 'reins'],
#  '-acddeegrrtu': ['drug-created'],
#  'ademrs': ['dreams'],
#  'hot': ['hot'],
#  'censt': ['scent', 'cents'],
#  'enw': ['new', 'wen'],
#  '.belmopr': ['problem.'],
#  'agnr': ['rang'],
#  'bell': ['bell'],
#  'hnosw': ['shown'],
#  'abcehmr': ['chamber'],
#  'eflmorry': ['formerly'],
#  'aprt': ['part', 'trap', 'rapt'],
#  '\n\n.Hinosw': ['own.\n\nHis'],
#  '.eeffisuv': ['effusive.'],
#  ';asw': ['was;'],
#  ',adgl': ['glad,'],
#  ',hiknt': ['think,'],
#  '.em': ['me.'],
#  'Whit': ['With'],
#  'adhlry': ['hardly'],
#  'dorw': ['word'],
#  ',eknops': ['spoken,'],
#  'diklny': ['kindly'],
#  ',eey': ['eye,'],
#  'adevw': ['waved'],
#  'an': ['an', 'na'],
#  ',aachimrr': ['armchair,'],
#  'ehrtw': ['threw'],
#  'acorss': ['across'],
#  ',acgirs': ['cigars,'],
#  'acddeiint': ['indicated'],
#  'iiprst': ['spirit'],
#  'aeeggnos': ['gasogene'],
#  '.cenorr': ['corner.'],
#  'Tehn': ['Then'],
#  'doost': ['stood'],
#  'efir': ['fire', 'rife'],
#  'ceeiinoprsttv': ['introspective'],
#  '\n\n".Wacdefhiklnoos': ['fashion.\n\n"Wedlock'],
#  'isstu': ['suits'],
#  '",ouy': ['you,"'],
#  '.adeekmrr': ['remarked.'],
#  '"I': ['"I', 'I"'],
#  ',Wanost': ['Watson,'],
#  'ouy': ['you'],
#  'ptu': ['put'],
#  'eensv': ['seven'],
#  'afhl': ['half'],
#  'dnopsu': ['pounds'],
#  'ceins': ['since'],
#  '\n\n!""".Seenouvy': ['you."\n\n"Seven!"'],
#  '\n\n",.Iadddeeeennrsw': ['answered.\n\n"Indeed,'],
#  'ghhottu': ['thought'],
#  '.emor': ['more.'],
#  'Jstu': ['Just'],
#  'efilrt': ['trifle', 'filter'],
#  ',emor': ['more,'],
#  ',acfny': ['fancy,'],
#  '.Wanost': ['Watson.'],
#  'acceiprt': ['practice'],
#  '.beeorsv': ['observe.'],
#  'ddi': ['did'],
#  'ellt': ['tell'],
#  'ddeeinnt': ['intended'],
#  'go': ['go'],
#  '\n\n"",.Taeehhnnrss': ['harness."\n\n"Then,'],
#  '\n\n""?Iknow': ['know?"\n\n"I'],
#  'cddeeu': ['deduce'],
#  'How': ['How'],
#  'eggintt': ['getting'],
#  'eflorsuy': ['yourself'],
#  'ervy': ['very'],
#  'etw': ['wet'],
#  ',aellty': ['lately,'],
#  'clmsuy': ['clumsy'],
#  'aceelrss': ['careless'],
#  'aenrstv': ['servant', 'taverns'],
#  '\n\n""?Mgilry': ['girl?"\n\n"My'],
#  '",Helmos': ['Holmes,"'],
#  'adis': ['said', 'aids'],
#  ',I': ['I,'],
#  '"hist': ['"this'],
#  'oot': ['too'],
#  '.chmu': ['much.'],
#  'aceilnrty': ['certainly'],
#  ',bdenru': ['burned,', 'burden,'],
#  'deilv': ['lived', 'devil'],
#  'efw': ['few'],
#  'ceeinrstu': ['centuries'],
#  '.ago': ['ago.'],
#  'ertu': ['true'],
#  'aklw': ['walk'],
#  'Tadhrsuy': ['Thursday'],
#  'acem': ['came', 'acme'],
#  'ehmo': ['home'],
#  'addeflru': ['dreadful'],
#  ',emss': ['mess,'],
#  'acdeghn': ['changed'],
#  'cehlost': ['clothes'],
#  "'acnt": ["can't"],
#  'aegiimn': ['imagine'],
#  'Mary': ['Mary'],
#  ',Jaen': ['Jane,'],
#  ',bcegiiilnorr': ['incorrigible,'],
#  'efiw': ['wife', 'fiew'],
#  'eginv': ['given'],
#  ',ceinot': ['notice,'],
#  ',eehrt': ['there,', 'three,', 'ether,'],
#  'afil': ['fail'],
#  'it': ['it', 'ti'],
#  '\n\n".Heotu': ['out."\n\nHe'],
#  'ccdehklu': ['chuckled'],
#  'bbderu': ['rubbed'],
#  ',glno': ['long,'],
#  'enorsuv': ['nervous'],
#  '\n\n".Ieeghorttt': ['together.\n\n"It'],
#  'ciiilmpsty': ['simplicity'],
#  '",efilst': ['itself,"'],
#  ';eh': ['he;'],
#  '"my': ['"my'],
#  'deiins': ['inside', 'indies'],
#  ',ehos': ['shoe,'],
#  'jstu': ['just'],
#  'eehrw': ['where'],
#  'efghiilrt': ['firelight'],
#  'eikrsst': ['strikes'],
#  'aeehlrt': ['leather'],
#  'cdeors': ['scored'],
#  'isx': ['six'],
#  'almost': ['almost'],
#  'aaelllpr': ['parallel'],
#  '.cstu': ['cuts.'],
#  'Obilosuvy': ['Obviously'],
#  'ehty': ['they'],
#  'acdesu': ['caused'],
#  'eemnoos': ['someone'],
#  'aceellrssy': ['carelessly'],
#  'acdeprs': ['scraped'],
#  'dnoru': ['round'],
#  'deegs': ['edges'],
#  'elos': ['sole', 'lose'],
#  'deorr': ['order', 'ordre'],
#  'cderstu': ['crusted', 'crudest'],
#  'dmu': ['mud'],
#  ',Hceen': ['Hence,'],
#  ',ees': ['see,'],
#  'bdelou': ['double'],
#  'cddeinotu': ['deduction'],
#  ',aeehrtw': ['weather,'],
#  'aacillprrtuy': ['particularly'],
#  'aagilmnnt': ['malignant'],
#  '-bgiilnoosttt': ['boot-slitting'],
#  'ceeimnps': ['specimen'],
#  'Ldnnoo': ['London'],
#  '.aelsvy': ['slavey.'],
#  ',acceiprt': ['practice,'],
#  'fi': ['if'],
#  'aeeglmnnt': ['gentleman'],
#  'aklsw': ['walks'],
#  'egillmns': ['smelling'],
#  ',dfimooor': ['iodoform,'],
#  'abckl': ['black'],
#  'akmr': ['mark'],
#  'aeinrtt': ['nitrate'],
#  'eilrsv': ['silver'],
#  'ghirt': ['right', 'girth'],
#  ',eeffginorr': ['forefinger,'],
#  'beglu': ['bulge', 'bugle'],
#  'deis': ['side', 'dies'],
#  '-ahoptt': ['top-hat'],
#  'hosw': ['show'],
#  'cdeeerst': ['secreted', 'resected'],
#  ',ceehoopsstt': ['stethoscope,'],
#  ',dllu': ['dull,'],
#  ',ddeein': ['indeed,'],
#  'cennoopru': ['pronounce'],
#  'aceitv': ['active'],
#  'beemmr': ['member'],
#  'acdeilm': ['medical', 'claimed'],
#  '\n\n".Iefinooprss': ['profession."\n\nI'],
#  'cdlou': ['could', 'cloud'],
#  'ehlp': ['help'],
#  'agghilnu': ['laughing'],
#  'aees': ['ease'],
#  'adeeilnpx': ['explained'],
#  'ceoprss': ['process', 'corpses'],
#  '.cddeinotu': ['deduction.'],
#  '"Wehn': ['"When'],
#  'aehr': ['hear', 'hare'],
#  'egiv': ['give'],
#  '",aenorss': ['reasons,"'],
#  ',adeekmrr': ['remarked,'],
#  '"eht': ['"the'],
#  'aaepprs': ['appears'],
#  'cdiillorsuuy': ['ridiculously'],
#  'eilmps': ['simple', 'impels'],
#  'aeilsy': ['easily'],
#  ',eflmsy': ['myself,'],
#  'ghhotu': ['though'],
#  'cceeisssuv': ['successive'],
#  'aceinnst': ['instance', 'ancients'],
#  'am': ['am', 'ma'],
#  'abdeffl': ['baffled'],
#  'ilntu': ['until'],
#  'aeilnpx': ['explain'],
#  '.ceoprss': ['process.'],
#  'beeeilv': ['believe'],
#  'dgoo': ['good'],
#  '\n\n"".Qeiorstuuy': ['yours."\n\n"Quite'],
#  '",os': ['so,"'],
#  ',adeenrsw': ['answered,'],
#  'gghiilnt': ['lighting'],
#  ',aceegirtt': ['cigarette,'],
#  'ghinortw': ['throwing', 'ingrowth'],
#  'dnow': ['down'],
#  '.aachimrr': ['armchair.'],
#  '"You': ['"You'],
#  'cdiiinnostt': ['distinction'],
#  '.acelr': ['clear.'],
#  'For': ['For'],
#  ',aeelmpx': ['example,'],
#  'eeflnqrtuy': ['frequently'],
#  'epsst': ['steps'],
#  'adel': ['lead', 'deal'],
#  'ahll': ['hall'],
#  '\n\n\n\n""""..FHeelmnoooqrrtuwy': ['room."\n\n"Frequently."\n\n"How'],
#  '\n\n"",?Weefllnot': ['often?"\n\n"Well,'],
#  'ddehnrsu': ['hundreds'],
#  '\n\n"".Teehimnst': ['times."\n\n"Then'],
#  'amny': ['many'],
#  '\n\n""?Heehortw': ['there?"\n\n"How'],
#  '?amny': ['many?'],
#  "'dnot": ["don't"],
#  '\n\n"".Qeiknotuw': ['know."\n\n"Quite'],
#  '!os': ['so!'],
#  '.bdeeorsv': ['observed.'],
#  '.eens': ['seen.'],
#  'Taht': ['That'],
#  '.inopt': ['point.'],
#  ',Now': ['Now,'],
#  'eeeennstv': ['seventeen'],
#  ',epsst': ['steps,'],
#  'abceesu': ['because'],
#  'bhot': ['both'],
#  ',awy': ['way,'],
#  'deeeinrstt': ['interested'],
#  ',belmoprs': ['problems,'],
#  'eghnou': ['enough'],
#  'ccehilnor': ['chronicle'],
#  'otw': ['two', 'tow'],
#  'fgiilnrt': ['trifling', 'flirting'],
#  ',ceeeeinprsx': ['experiences,'],
#  '".hist': ['this."'],
#  ',chikt': ['thick,'],
#  '-deiiknnptt': ['pink-tinted'],
#  'aeenopprt': ['notepaper'],
#  'gilny': ['lying'],
#  'enop': ['open'],
#  '.abelt': ['table.'],
#  '"It': ['"It'],
#  'alst': ['last', 'salt'],
#  '",opst': ['post,"', 'spot,"'],
#  '.eh': ['he.'],
#  '"Rade': ['"Read'],
#  '\n\n".Tadehlou': ['aloud."\n\nThe'],
#  'enot': ['note', 'tone'],
#  ',addentu': ['undated,'],
#  'eehirt': ['either'],
#  'aeginrstu': ['signature'],
#  '\n\n".Taddeeehrrss': ['address.\n\n"There'],
#  'illw': ['will'],
#  'acll': ['call'],
#  ',-ghinott': ['to-night,'],
#  'aeqrrtu': ['quarter'],
#  'eghit': ['eight'],
#  '"\',cckloo': ['o\'clock,"'],
#  ',adis': ['said,'],
#  '"a': ['"a'],
#  'deeirss': ['desires'],
#  'clnostu': ['consult'],
#  'aemrtt': ['matter'],
#  'deeepst': ['deepest'],
#  '.emmnot': ['moment.'],
#  'Yoru': ['Your'],
#  'ceenrt': ['recent', 'centre', 'center'],
#  'ceeirssv': ['services'],
#  'alory': ['royal'],
#  'ehossu': ['houses'],
#  'Eeopru': ['Europe'],
#  'aeflsy': ['safely'],
#  'dersttu': ['trusted'],
#  'aemrstt': ['matters'],
#  'aceimnoprt': ['importance'],
#  '.aadeeeggrtx': ['exaggerated.'],
#  'This': ['This'],
#  'ew': ['we'],
#  'aeqrrstu': ['quarters'],
#  '.cdeeeirv': ['received.'],
#  'ehnt': ['then'],
#  ',horu': ['hour,'],
#  'aimss': ['amiss'],
#  'iiorstv': ['visitor'],
#  'aerw': ['wear', 'ware'],
#  '\n\n"".Tahikmss': ['mask."\n\n"This'],
#  'ddeein': ['indeed', 'denied'],
#  '",emrstyy': ['mystery,"'],
#  '"Waht': ['"What'],
#  '\n\n""?Iaemns': ['means?"\n\n"I'],
#  'aadt': ['data'],
#  '.ety': ['yet.'],
#  'aacilpt': ['capital'],
#  'aeikmst': ['mistake'],
#  'eehiorst': ['theorise', 'theories'],
#  '.aadt': ['data.'],
#  'Ibeilnnssy': ['Insensibly'],
#  'begins': ['begins', 'beings'],
#  'isttw': ['twist'],
#  'acfst': ['facts'],
#  'istu': ['suit'],
#  ',eehiorst': ['theories,'],
#  'adeinst': ['instead', 'stained'],
#  '.acfst': ['facts.'],
#  '.efilst': ['itself.'],
#  'Waht': ['What'],
#  '\n\n"?Iit': ['it?"\n\nI'],
#  'acefllruy': ['carefully'],
#  'adeeimnx': ['examined'],
#  ',giinrtw': ['writing,'],
#  'aeppr': ['paper'],
#  '\n\n".Teehinrttw': ['written.\n\n"The'],
#  'eortw': ['wrote', 'tower'],
#  'abelmprsuy': ['presumably'],
#  'ellw': ['well'],
#  '",do': ['do,"'],
#  'adeeginnoruv': ['endeavouring'],
#  'aeiimtt': ['imitate'],
#  "'acimnnoops": ["companion's", "companions'"],
#  '.ceeoprsss': ['processes.'],
#  '"Schu': ['"Such'],
#  'bghotu': ['bought'],
#  'cnorw': ['crown'],
#  '.acekpt': ['packet.'],
#  'aceillpruy': ['peculiarly'],
#  '\n\n""--.Paaceffhiilrstttu': ['stiff."\n\n"Peculiar--that'],
#  '",dorw': ['word,"'],
#  '.Helmos': ['Holmes.'],
#  'Eghilns': ['English'],
#  '.all': ['all.'],
#  'Hdlo': ['Hold'],
#  '\n\n".Ighilt': ['light."\n\nI'],
#  ',os': ['so,'],
#  'aeglr': ['large', 'glare', 'regal'],
#  '""E': ['"E"'],
#  '"",g': ['"g,"'],
#  '"",P': ['"P,"'],
#  '""G': ['"G"'],
#  '""t': ['"t"'],
#  'enovw': ['woven'],
#  'eerttux': ['texture'],
#  '\n\n".Waaehpprt': ['paper.\n\n"What'],
#  '"?ahtt': ['that?"'],
#  'adeks': ['asked'],
#  '\n\n".HTeehlmos': ['Holmes.\n\n"The'],
#  'aemn': ['name', 'mean', 'mane'],
#  ',aekmr': ['maker,'],
#  ';bdotu': ['doubt;'],
#  ',agmmnoor': ['monogram,'],
#  '\n\n"".Naehorrtt': ['rather."\n\n"Not'],
#  "''G": ["'G'"],
#  "''t": ["'t'"],
#  'adnsst': ['stands'],
#  "'',Gaceefhllsst": ["'Gesellschaft,'"],
#  'Gaemnr': ['German'],
#  "''.Camnopy": ["'Company.'"],
#  'acmorstuy': ['customary'],
#  'accinnoortt': ['contraction'],
#  'eikl': ['like'],
#  "''.Co": ["'Co.'"],
#  "'',P": ["'P,'"],
#  ',ceorsu': ['course,'],
#  "''.Paeipr": ["'Papier.'"],
#  'Now': ['Now'],
#  "''.Eg": ["'Eg.'"],
#  'Let': ['Let'],
#  'acegln': ['glance'],
#  'Caeilnnnott': ['Continental'],
#  '".Gaeeerttz': ['Gazetteer."'],
#  'koot': ['took'],
#  'aehvy': ['heavy'],
#  'bnorw': ['brown'],
#  'elmouv': ['volume'],
#  '.eehlssv': ['shelves.'],
#  '",Eglow': ['"Eglow,'],
#  '--Eeeghilnortz': ['Eglonitz--here'],
#  ',aer': ['are,', 'ear,', 'era,'],
#  '.Eagir': ['Egria.'],
#  '-Gaaeegikmnnprs': ['German-speaking'],
#  '--cinnortuy': ['country--in'],
#  ',Baehimo': ['Bohemia,'],
#  'afr': ['far'],
#  '.Caabdlrs': ['Carlsbad.'],
#  "'Raabeeklmr": ["'Remarkable"],
#  'begin': ['being', 'begin'],
#  'ceens': ['scene'],
#  'adeht': ['death', 'hated'],
#  ',Waeeillnnst': ['Wallenstein,'],
#  'ist': ['its', 'sit', 'ist'],
#  'emnorsuu': ['numerous'],
#  '-aacefgilorssst': ['glass-factories'],
#  "'-.aeillmpprs": ["paper-mills.'"],
#  ',Ha': ['Ha,'],
#  ',ah': ['ha,', 'ah,'],
#  ',boy': ['boy,'],
#  'ahtw': ['what', 'thaw'],
#  ',adeklprs': ['sparkled,'],
#  'enst': ['sent', 'nest', 'tens', 'nets'],
#  'aegrt': ['great', 'grate'],
#  'belu': ['blue'],
#  'ahimnprttu': ['triumphant'],
#  '\n\n".Taceeeghirtt': ['cigarette.\n\n"The'],
#  'adem': ['made', 'mead', 'dame'],
#  '",Baehimo': ['Bohemia,"'],
#  '\n\n"..Pacdeeiilrssy': ['said.\n\n"Precisely.'],
#  '.Gaemnr': ['German.'],
#  'aceilpru': ['peculiar'],
#  'ccinnoorsttu': ['construction'],
#  "'--Tceeehinnsst": ["sentence--'This"],
#  "'.cdeeeirv": ["received.'"],
#  'Facehmnnr': ['Frenchman'],
#  'Rainssu': ['Russian'],
#  '.ahtt': ['that.'],
#  'cenoorstuuu': ['uncourteous'],
#  '.bersv': ['verbs.'],
#  'lnoy': ['only'],
#  ',aeimnrs': ['remains,', 'marines,'],
#  ',eeefhorrt': ['therefore,'],
#  'cdeiorsv': ['discover'],
#  'adentw': ['wanted'],
#  'eirstw': ['writes'],
#  'eefprrs': ['prefers'],
#  'aeginrw': ['wearing'],
#  'akms': ['mask'],
#  'ghinosw': ['showing'],
#  '.acef': ['face.'],
#  'eehr': ['here'],
#  ',cemos': ['comes,'],
#  ',aeikmnst': ['mistaken,'],
#  'eelorsv': ['resolve'],
#  '\n\n".Abdosstu': ['doubts."\n\nAs'],
#  'ahprs': ['sharp'],
#  'dnosu': ['sound'],
#  "'ehorss": ["horses'", "horse's"],
#  'fhoos': ['hoofs'],
#  'agginrt': ['grating'],
#  'eehlsw': ['wheels'],
#  ',bcru': ['curb,'],
#  'deflloow': ['followed'],
#  'llpu': ['pull'],
#  '.bell': ['bell.'],
#  '\n\n".Adehilstw': ['whistled.\n\n"A'],
#  ',aipr': ['pair,'],
#  '",dnosu': ['sound,"'],
#  '"",Yes': ['"Yes,"'],
#  ',cdeinnotu': ['continued,', 'unnoticed,'],
#  'acggilnn': ['glancing', 'clanging'],
#  '.dinoww': ['window.'],
#  '"A': ['"A'],
#  'cein': ['nice'],
#  'abghmoru': ['brougham'],
#  'aipr': ['pair'],
#  '.abeeistu': ['beauties.'],
#  'ddehnru': ['hundred'],
#  'ffity': ['fifty'],
#  'aeginsu': ['guineas'],
#  '.aceeip': ['apiece.'],
#  "'Teehrs": ["There's"],
#  'emnoy': ['money'],
#  ',aces': ['case,'],
#  'ghinnot': ['nothing'],
#  '\n\n"".Ieels': ['else."\n\n"I'],
#  'hiknt': ['think'],
#  'beertt': ['better'],
#  ',go': ['go,'],
#  '\n\n"".HNelmoost': ['Holmes."\n\n"Not'],
#  ',bit': ['bit,'],
#  '.Dcoort': ['Doctor.'],
#  'Saty': ['Stay'],
#  '.aer': ['are.', 'ear.', 'era.'],
#  'lost': ['lost', 'lots'],
#  '.Bellosw': ['Boswell.'],
#  'eimoprss': ['promises'],
#  '.eegiinnrstt': ['interesting.'],
#  'ipty': ['pity'],
#  'imss': ['miss'],
#  '\n\n"".Bittu': ['it."\n\n"But'],
#  '\n\n""--Nceeeilnrtv': ['client--"\n\n"Never'],
#  'antw': ['want'],
#  ',ehlp': ['help,'],
#  'Heer': ['Here'],
#  '.cemos': ['comes.'],
#  'Sit': ['Sit'],
#  ',Dcoort': ['Doctor,'],
#  'best': ['best', 'bets'],
#  '\n\n".Aaeinnottt': ['attention."\n\nA'],
#  'losw': ['slow'],
#  ',epst': ['step,'],
#  'airsst': ['stairs'],
#  ',aaegpss': ['passage,'],
#  'adepsu': ['paused'],
#  'adeeiilmmty': ['immediately'],
#  ...}

# %%
## Build an Expense Tracker

### Explanation:

When you spend money, you usually want to keep track of **where the money is going**. 
For example, you might spend on *food*, *rent*, *travel*, and so on. An **expense tracker** 
helps you organize your spending by category (also called *expense head*).

We can build a simple tracker using a **dictionary**:

* The *keys* will be the expense heads (like `"food"`, `"rent"`, `"travel"`).
* The *values* will be the total amount spent under that head.

We will write **two functions**:

1. `update_expenses(expense_list, expenses_dict)` → updates the dictionary with new expenses.

   * `expense_list` is a list of tuples like `[("food", 200), ("rent", 1000)]`.
   * `expenses_dict` is the dictionary where totals are stored.

2. `print_expenses(expenses_dict)` → prints the overall expenses under each head in a clean way.

---

### Exercise:

Write the following functions:

```python
def update_expenses(expense_list, expenses_dict):
    """
    Updates the dictionary with expenses from the list.
    Each element of expense_list is a tuple: (expense_head, amount).
    If the head already exists, add to its total.
    Otherwise, create a new entry.
    """
    pass


def print_expenses(expenses_dict):
    """
    Prints all expense heads and their total amounts.
    Example format:
    food : 500
    rent : 1000
    """
    pass
```

---

### Example Usage:

```python
expenses = {}

update_expenses([("food", 200), ("rent", 1000)], expenses)
update_expenses([("food", 300), ("travel", 150)], expenses)

print_expenses(expenses)
```

**Expected Output:**

```
food : 500
rent : 1000
travel : 150
```

---

# %%
def update_expenses(expense_list, expenses_dict):
    
    for e in expense_list:
        item,cost = e
        if item in expenses_dict:
            expenses_dict[item] = expenses_dict[item] - cost
     
    
    return expenses_dict

def print_expenses(expenses_dict):
    
    for key, value in expenses_dict.items():
        print (key, " : ", value)
    
    
    return

# %%
expenses = {"food": 600, "rent": 1050, "travel":200}

update_expenses([("food", 200), ("rent", 1000)], expenses)
update_expenses([("food", 300), ("travel", 150)], expenses)

print_expenses(expenses)
# Out:
# food  :  100
# rent  :  50
# travel  :  50
